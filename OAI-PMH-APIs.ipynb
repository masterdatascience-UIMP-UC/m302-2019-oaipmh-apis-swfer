# %% [markdown]
# # OAI-PMH
#
# La documentación del protocolo la podéis encontrar aquí:
#
# https://www.openarchives.org/OAI/openarchivesprotocol.html
#
# ### Librerías necesarias para la práctica
#
# ```python
# import xml.etree.ElementTree as ET
# import requests
# ```

# %% [markdown]
# ### Identify
#
# This verb is used to retrieve information about a repository. Some of the information returned is required as part of the OAI-PMH. Repositories may also employ the Identify verb to return additional descriptive information.

# %%
import xml.etree.ElementTree as ET
import requests

oai = requests.get('https://zenodo.org/oai2d?verb=Identify') #Peticion al servidor

#Para crear el arbol XML
xmlTree = ET.ElementTree(ET.fromstring(oai.text))
root = xmlTree.getroot()

iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag+": "+elem.text)
    
elementos = xmlTree.findall('//{http://www.openarchives.org/OAI/2.0/}baseURL')
for e in elementos:
    print("BaseURL:", e.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH:
#
# {http://www.openarchives.org/OAI/2.0/}responseDate: 2017-12-14T08:00:18Z
# {http://www.openarchives.org/OAI/2.0/}request: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}Identify:
#
# {http://www.openarchives.org/OAI/2.0/}repositoryName: Zenodo
# {http://www.openarchives.org/OAI/2.0/}baseURL: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}protocolVersion: 2.0
# {http://www.openarchives.org/OAI/2.0/}adminEmail: info@zenodo.org
# {http://www.openarchives.org/OAI/2.0/}earliestDatestamp: 2013-05-06T23:27:15Z
# {http://www.openarchives.org/OAI/2.0/}deletedRecord: no
# {http://www.openarchives.org/OAI/2.0/}granularity: YYYY-MM-DDThh:mm:ssZ
# BaseURL: https://zenodo.org/oai2d
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:12: FutureWarning: This search is broken in 1.3 and earlier, and will be fixed in a future version.  If you rely on the current behaviour, change it to './/{http://www.openarchives.org/OAI/2.0/}baseURL'

# %% [markdown]
# ### Listar tipos de metadatos
#
# ListMetadataFormats
#
# This verb is used to retrieve the metadata formats available from a repository. An optional argument restricts the request to the formats available for a specific item.

# %%
import xml.etree.ElementTree as ET
import requests

oai = requests.get('https://zenodo.org/oai2d?verb=ListMetadataFormats') #Peticion al servidor

#Para crear el arbol XML
xmlTree = ET.ElementTree(ET.fromstring(oai.text))

iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag+": "+elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH:
#
# {http://www.openarchives.org/OAI/2.0/}responseDate: 2017-12-14T08:05:11Z
# {http://www.openarchives.org/OAI/2.0/}request: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListMetadataFormats:
#
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_dc
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.openarchives.org/OAI/2.0/oai_dc.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://www.openarchives.org/OAI/2.0/oai_dc/
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-3
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marc21
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://www.loc.gov/MARC21/slim
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-3
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marcxml
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://www.loc.gov/MARC21/slim
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-3
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-3

# %% [markdown]
# Podemos capturar sólo la información relevante

# %%
iterator = xmlTree.iter()
for elem in iterator:
    if (elem.tag == '{http://www.openarchives.org/OAI/2.0/}metadataPrefix') or (elem.tag == '{http://www.openarchives.org/OAI/2.0/}schema'):
        print(elem.tag+": "+elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_dc
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.openarchives.org/OAI/2.0/oai_dc.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marc21
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marcxml
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd

# %% [markdown]
# O de forma más "elegante"

# %%
for e in xmlTree.findall('//{http://www.openarchives.org/OAI/2.0/}metadataFormat'):
    metadataPrefix = e.find('{http://www.openarchives.org/OAI/2.0/}metadataPrefix').text
    schema = e.find('{http://www.openarchives.org/OAI/2.0/}schema').text
    print(metadataPrefix, ':', schema)
# Out:
# oai_dc : http://www.openarchives.org/OAI/2.0/oai_dc.xsd
# oai_datacite3 : http://schema.datacite.org/meta/kernel-3/metadata.xsd
# marc21 : http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# datacite : http://schema.datacite.org/meta/kernel-3/metadata.xsd
# marcxml : http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# datacite3 : http://schema.datacite.org/meta/kernel-3/metadata.xsd
# oai_datacite : http://schema.datacite.org/meta/kernel-3/metadata.xsd
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:1: FutureWarning: This search is broken in 1.3 and earlier, and will be fixed in a future version.  If you rely on the current behaviour, change it to './/{http://www.openarchives.org/OAI/2.0/}metadataFormat'
#   if __name__ == '__main__':

# %% [markdown]
# Podemos describir el último schema

# %%
oai_datacite = requests.get('http://schema.datacite.org/meta/kernel-3/metadata.xsd') #Peticion al servidor
print(oai_datacite.text)
#Para crear el arbol XML
xmlTree = ET.ElementTree(ET.fromstring(oai_datacite.text))

iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <!-- Revision history
#      2010-08-26   Complete revision according to new common specification by the metadata work group after review. AJH, DTIC
# 	 2010-11-17 Revised to current state of kernel review, FZ, TIB
# 	 2011-01-17 Complete revsion after community review. FZ, TIB
# 	 2011-03-17 Release of v2.1: added a namespace; mandatory properties got minLength; changes in the definitions of relationTypes
# 	 IsDocumentedBy/Documents and isCompiledBy/Compiles; changes type of property "Date" from xs:date to xs:string. FZ, TIB
# 	 2011-06-27 v2.2: namespace: kernel-2.2, additions to controlled lists "resourceType", "contributorType", "relatedIdentifierType", and "descriptionType". Removal of intermediate include-files.
#      2013-05 v3.0: namespace: kernel-3.0; delete LastMetadataUpdate & MetadateVersionNumber; additions to controlled lists "contributorType", "dateType", "descriptionType", "relationType", "relatedIdentifierType" & "resourceType"; deletion of "StartDate" & "EndDate" from list "dateType" and "Film" from "resourceType";  allow arbitrary order of elements; allow optional wrapper elements to be empty; include xml:lang attribute for title, subject & description; include attribute schemeURI for nameIdentifier of creator, contributor & subject; added new attributes "relatedMetadataScheme", "schemeURI" & "schemeType" to relatedIdentifier; included new property "geoLocation"
# 	 2014-08-20 v3.1: additions to controlled lists "relationType", contributorType" and "relatedIdentifierType"; introduction of new child element "affiliation" to "creator" and "contributor"-->
# <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns="http://datacite.org/schema/kernel-3" targetNamespace="http://datacite.org/schema/kernel-3" elementFormDefault="qualified" xml:lang="EN">
# 	<xs:import namespace="http://www.w3.org/XML/1998/namespace" schemaLocation="http://www.w3.org/2009/01/xml.xsd"/>
# 	<xs:include schemaLocation="include/datacite-titleType-v3.xsd"/>
# 	<xs:include schemaLocation="include/datacite-contributorType-v3.1.xsd"/>
# 	<xs:include schemaLocation="include/datacite-dateType-v3.xsd"/>
# 	<xs:include schemaLocation="include/datacite-resourceType-v3.xsd"/>
# 	<xs:include schemaLocation="include/datacite-relationType-v3.1.xsd"/>
# 	<xs:include schemaLocation="include/datacite-relatedIdentifierType-v3.1.xsd"/>
# 	<xs:include schemaLocation="include/datacite-descriptionType-v3.xsd"/>
# 	<xs:element name="resource">
# 		<xs:annotation>
# 			<xs:documentation>
# 	Root element of a single record. This wrapper element is for XML implementation only and is not defined in the DataCite DOI standard.
#         Note: This is the case for all wrapper elements within this schema!</xs:documentation>
# 			<xs:documentation>No content in this wrapper element.</xs:documentation>
# 		</xs:annotation>
# 		<xs:complexType>
# 			<xs:all>
# 				<!--REQUIRED FIELDS-->
# 				<xs:element name="identifier">
# 					<xs:annotation>
# 						<xs:documentation>A persistent identifier that identifies a resource.</xs:documentation>
# 						<xs:documentation>Currently, only DOI is allowed.</xs:documentation>
# 					</xs:annotation>
# 					<xs:complexType>
# 						<xs:simpleContent>
# 							<xs:extension base="doiType">
# 								<xs:attribute name="identifierType" use="required" fixed="DOI"/>
# 							</xs:extension>
# 						</xs:simpleContent>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="creators">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="creator" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>The main researchers involved working on the data, or the authors of the publication in priority order. May be a corporate/institutional or personal name.</xs:documentation>
# 									<xs:documentation>Format: Family, Given.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:sequence>
# 										<xs:element name="creatorName">
# 											<xs:simpleType>
# 												<xs:restriction base="nonemptycontentStringType"/>
# 											</xs:simpleType>
# 										</xs:element>
# 										<xs:element name="nameIdentifier" minOccurs="0">
# 											<xs:complexType>
# 												<xs:simpleContent>
# 													<xs:extension base="nonemptycontentStringType">
# 														<xs:attribute name="nameIdentifierScheme" use="required"/>
# 														<xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
# 													</xs:extension>
# 												</xs:simpleContent>
# 											</xs:complexType>
# 										</xs:element>
# 										<xs:element name="affiliation" minOccurs="0" maxOccurs="unbounded"/>
# 									</xs:sequence>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="titles">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="title" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>A name or title by which a resource is known.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="nonemptycontentStringType">
# 											<xs:attribute name="titleType" type="titleType" use="optional"/>
# 											<xs:attribute ref="xml:lang"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="publisher">
# 					<xs:annotation>
# 						<xs:documentation>The name of the entity that holds, archives, publishes prints, distributes, releases, issues, or produces the resource. This property will be used to formulate the citation, so consider the prominence of the role.</xs:documentation>
# 						<xs:documentation>In the case of datasets, "publish" is understood to mean making the data available to the community of researchers.</xs:documentation>
# 					</xs:annotation>
# 					<xs:simpleType>
# 						<xs:restriction base="nonemptycontentStringType"/>
# 					</xs:simpleType>
# 				</xs:element>
# 				<xs:element name="publicationYear">
# 					<xs:annotation>
# 						<xs:documentation>Year when the data is made publicly available. If an embargo period has been in effect, use the date when the embargo period ends.</xs:documentation>
# 						<xs:documentation>In the case of datasets, "publish" is understood to mean making the data available on a specific date to the community of researchers. If there is no standard publication year value, use the date that would be preferred from a citation perspective.</xs:documentation>
# 						<xs:documentation>YYYY</xs:documentation>
# 					</xs:annotation>
# 					<xs:simpleType>
# 						<xs:restriction base="yearType"/>
# 					</xs:simpleType>
# 				</xs:element>
# 				<!--OPTIONAL FIELDS-->
# 				<xs:element name="subjects" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="subject" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Subject, keywords, classification codes, or key phrases describing the resource.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="subjectScheme" use="optional"/>
# 											<xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
# 											<xs:attribute ref="xml:lang"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="contributors" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="contributor" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>The institution or person responsible for collecting, creating, or otherwise contributing to the developement of the dataset.</xs:documentation>
# 									<xs:documentation>The personal name format should be: Family, Given.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:sequence>
# 										<xs:element name="contributorName">
# 											<xs:simpleType>
# 												<xs:restriction base="xs:string">
# 													<xs:minLength value="1"/>
# 												</xs:restriction>
# 											</xs:simpleType>
# 										</xs:element>
# 										<xs:element name="nameIdentifier" minOccurs="0">
# 											<xs:complexType>
# 												<xs:simpleContent>
# 													<xs:extension base="xs:string">
# 														<xs:attribute name="nameIdentifierScheme" use="required"/>
# 														<xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
# 													</xs:extension>
# 												</xs:simpleContent>
# 											</xs:complexType>
# 										</xs:element>
# 										<xs:element name="affiliation" minOccurs="0" maxOccurs="unbounded"/>
# 									</xs:sequence>
# 									<xs:attribute name="contributorType" type="contributorType" use="required"/>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="dates" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="date" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Different dates relevant to the work.</xs:documentation>
# 									<xs:documentation>YYYY,YYYY-MM-DD, YYYY-MM-DDThh:mm:ssTZD or any other format or level of granularity described in W3CDTF. Use RKMS-ISO8601 standard for depicting date ranges.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="dateType" type="dateType" use="required"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="language" type="xs:language" minOccurs="0">
# 					<xs:annotation>
# 						<xs:documentation>Primary language of the resource. Allowed values are taken from  IETF BCP 47, ISO 639-1 language codes.</xs:documentation>
# 					</xs:annotation>
# 				</xs:element>
# 				<xs:element name="resourceType" minOccurs="0">
# 					<xs:annotation>
# 						<xs:documentation>The type of a resource. You may enter an additional free text description.</xs:documentation>
# 						<xs:documentation>The format is open, but the preferred format is a single term of some detail so that a pair can be formed with the sub-property.</xs:documentation>
# 					</xs:annotation>
# 					<xs:complexType>
# 						<xs:simpleContent>
# 							<xs:extension base="xs:string">
# 								<xs:attribute name="resourceTypeGeneral" type="resourceType" use="required"/>
# 							</xs:extension>
# 						</xs:simpleContent>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="alternateIdentifiers" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="alternateIdentifier" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>An identifier or identifiers other than the primary Identifier applied to the resource being registered. This may be any alphanumeric string which is unique within its domain of issue. May be used for local identifiers. AlternateIdentifier should be used for another identifier of the same instance (same location, same file).</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="alternateIdentifierType" use="required"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="relatedIdentifiers" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="relatedIdentifier" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Identifiers of related resources. Use this property to indicate subsets of properties, as appropriate.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="relatedIdentifierType" type="relatedIdentifierType" use="required"/>
# 											<xs:attribute name="relationType" type="relationType" use="required"/>
# 											<xs:attribute name="relatedMetadataScheme" use="optional"/>
# 											<xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
# 											<xs:attribute name="schemeType" use="optional"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="sizes" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="size" type="xs:string" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Unstructures size information about the resource.</xs:documentation>
# 								</xs:annotation>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="formats" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="format" type="xs:string" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Technical format of the resource.</xs:documentation>
# 									<xs:documentation>Use file extension or MIME type where possible.</xs:documentation>
# 								</xs:annotation>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="version" type="xs:string" minOccurs="0">
# 					<xs:annotation>
# 						<xs:documentation>Version number of the resource. If the primary resource has changed the version number increases.</xs:documentation>
# 						<xs:documentation>Register a new identifier for a major version change. Individual stewards need to determine which are major vs. minor versions. May be used in conjunction with properties 11 and 12 (AlternateIdentifier and RelatedIdentifier) to indicate various information updates. May be used in conjunction with property 17 (Description) to indicate the nature and file/record range of version.</xs:documentation>
# 					</xs:annotation>
# 				</xs:element>
# 				<xs:element name="rightsList" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="rights" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Any rights information for this resource. Provide a rights management statement for the resource or reference a service providing such information. Include embargo information if applicable.
# Use the complete title of a license and include version information if applicable.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="rightsURI" type="xs:anyURI" use="optional"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="descriptions" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="description" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>All additional information that does not fit in any of the other categories. May be used for technical information. It is a best practice to supply a description.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType mixed="true">
# 									<xs:choice>
# 										<xs:element name="br" minOccurs="0" maxOccurs="unbounded">
# 											<xs:simpleType>
# 												<xs:restriction base="xs:string">
# 													<xs:length value="0"/>
# 												</xs:restriction>
# 											</xs:simpleType>
# 										</xs:element>
# 									</xs:choice>
# 									<xs:attribute name="descriptionType" type="descriptionType" use="required"/>
# 									<xs:attribute ref="xml:lang"/>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="geoLocations" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="geoLocation" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Spatial region or named place where the data was gathered or about which the data is focused.</xs:documentation>
# 									<xs:documentation>A point contains a single latitude-longitude pair, separated by whitespace.</xs:documentation>
# 									<xs:documentation>A box contains two white space separated latitude-longitude pairs, with each pair separated by whitespace. The first pair is the lower corner, the second is the upper corner.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:sequence>
# 										<xs:element name="geoLocationPoint" type="point" minOccurs="0"/>
# 										<xs:element name="geoLocationBox" type="box" minOccurs="0"/>
# 										<xs:element name="geoLocationPlace" minOccurs="0"/>
# 									</xs:sequence>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 			</xs:all>
# 		</xs:complexType>
# 	</xs:element>
# 	<!-- TYPE DECLARATIONS -->
# 	<!-- defines the value for a DOI: DOI must start with "10."  -->
# 	<xs:simpleType name="doiType">
# 		<xs:restriction base="xs:token">
# 			<xs:pattern value="10\..+/.+"/>
# 		</xs:restriction>
# 	</xs:simpleType>
# 	<!-- defines value for mandatory fields -->
# 	<xs:simpleType name="nonemptycontentStringType">
# 		<xs:restriction base="xs:string">
# 			<xs:minLength value="1"/>
# 		</xs:restriction>
# 	</xs:simpleType>
# 	<xs:attributeGroup name="nameId">
# 		<xs:attribute name="nameIdentifier" type="xs:string" use="optional"/>
# 		<xs:attribute name="nameIdentifierScheme" type="xs:string" use="optional"/>
# 	</xs:attributeGroup>
# 	<!-- defines the value for a year -->
# 	<xs:simpleType name="yearType">
# 		<xs:restriction base="xs:token">
# 			<xs:pattern value="[\d]{4}"/>
# 		</xs:restriction>
# 		<!-- definitions for geoLocation -->
# 	</xs:simpleType>
# 	<xs:simpleType name="point">
# 		<xs:restriction base="listOfDoubles">
# 			<xs:minLength value="2"/>
# 			<xs:maxLength value="2"/>
# 		</xs:restriction>
# 	</xs:simpleType>
# 	<xs:simpleType name="box">
# 		<xs:restriction base="listOfDoubles">
# 			<xs:minLength value="4"/>
# 			<xs:maxLength value="4"/>
# 		</xs:restriction>
# 	</xs:simpleType>
# 	<xs:simpleType name="listOfDoubles">
# 		<xs:list itemType="xs:double"/>
# 	</xs:simpleType>
# </xs:schema>
#
# {http://www.w3.org/2001/XMLSchema}schema
# {http://www.w3.org/2001/XMLSchema}import
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}all
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minLength
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}choice
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}length
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}pattern
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minLength
# {http://www.w3.org/2001/XMLSchema}attributeGroup
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}pattern
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minLength
# {http://www.w3.org/2001/XMLSchema}maxLength
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minLength
# {http://www.w3.org/2001/XMLSchema}maxLength
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}list

# %% [markdown]
# Si analizamos la descripción del estándar, vemos que las etiquetas de los metadatos están almacenados en la etiqueta "element", en el atributo "name". Podemos obetener un listado de lo que esperamos encontrar

# %%
namespaces = {'xs' : 'http://www.w3.org/2001/XMLSchema'}
for tags in xmlTree.findall('//xs:element',namespaces):
    print ('Metadato: ',tags.attrib['name'])
# Out:
# Metadato:  resource
# Metadato:  identifier
# Metadato:  creators
# Metadato:  creator
# Metadato:  creatorName
# Metadato:  nameIdentifier
# Metadato:  affiliation
# Metadato:  titles
# Metadato:  title
# Metadato:  publisher
# Metadato:  publicationYear
# Metadato:  subjects
# Metadato:  subject
# Metadato:  contributors
# Metadato:  contributor
# Metadato:  contributorName
# Metadato:  nameIdentifier
# Metadato:  affiliation
# Metadato:  dates
# Metadato:  date
# Metadato:  language
# Metadato:  resourceType
# Metadato:  alternateIdentifiers
# Metadato:  alternateIdentifier
# Metadato:  relatedIdentifiers
# Metadato:  relatedIdentifier
# Metadato:  sizes
# Metadato:  size
# Metadato:  formats
# Metadato:  format
# Metadato:  version
# Metadato:  rightsList
# Metadato:  rights
# Metadato:  descriptions
# Metadato:  description
# Metadato:  br
# Metadato:  geoLocations
# Metadato:  geoLocation
# Metadato:  geoLocationPoint
# Metadato:  geoLocationBox
# Metadato:  geoLocationPlace
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:2: FutureWarning: This search is broken in 1.3 and earlier, and will be fixed in a future version.  If you rely on the current behaviour, change it to './/xs:element'
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### ListIdentifiers
#
# This verb is an abbreviated form of ListRecords, retrieving only headers rather than records. Optional arguments permit selective harvesting of headers based on set membership and/or datestamp. Depending on the repository's support for deletions, a returned header may have a status attribute of "deleted" if a record matching the arguments specified in the request has been deleted.
#
# Devuelve la cabecera de los registros, para conocer la información esencial.
#
# Necesita el prefijo del formato de metadatos

# %%
#prefijo: oai_datacite
oai = requests.get('https://zenodo.org/oai2d?verb=ListIdentifiers&metadataPrefix=oai_datacite')
xmlTree = ET.ElementTree(ET.fromstring(oai.text))

iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag+": "+elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH:
#
# {http://www.openarchives.org/OAI/2.0/}responseDate: 2017-12-14T08:34:44Z
# {http://www.openarchives.org/OAI/2.0/}request: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListIdentifiers:
#
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:164231
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:54:31Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252141
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:01:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252977
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:01:47Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252363
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:01:48Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:251947
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:01:56Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:164760
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:55:02Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:185043
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:55:01Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:165228
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:55:09Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:160751
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:55:12Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire_data
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-ecfunded
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252670
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:01:57Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252388
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:01:55Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-icsu_wds
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:165623
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:55:15Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:165112
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:55:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:165647
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:55:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252214
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:02Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:165379
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:55:22Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:166025
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:55:22Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: software
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-bioinformatics
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-sing
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252381
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:02Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252113
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:01:59Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:165347
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:55:29Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:166183
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:55:45Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252110
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:09Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:165500
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:55:48Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire_data
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-geohazards-exploitation-platform
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:185039
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:55:58Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:165879
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:56:02Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:165948
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:56:08Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:185659
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:56:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:185485
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:56:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:166139
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:56:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:166253
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:56:18Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252359
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:14Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:186345
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:56:29Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252298
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:21Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252664
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:21Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:166319
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:56:44Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-sing
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:8742
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:38:38Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:166361
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:56:51Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252992
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:26Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252822
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:36Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:186028
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:57:23Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252921
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:39Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:187128
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:57:29Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252989
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:39Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:186217
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:57:34Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:253100
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:41Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:252659
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:42Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:186946
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:57:50Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:166897
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:57:55Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:253128
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:51Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:166942
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:58:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:186624
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:58:10Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:187389
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:58:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:166904
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:58:13Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:253146
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:52Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:187392
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:58:18Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:188225
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:58:28Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:167153
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:58:37Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:167122
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:58:38Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-opuscula-zoologica
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:253661
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:02:58Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:167263
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:58:45Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:167710
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:58:45Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:253071
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:03:01Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:167117
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T02:33:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: software
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:167713
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:58:57Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:167280
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T03:58:59Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire_data
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-hulib
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-zenodo
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:253222
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:03:07Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:253494
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:03:07Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:253514
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:03:19Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:189748
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:00:10Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:189714
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:00:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:196467
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:00:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:168046
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:00:22Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-ecfunded
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:168104
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:00:24Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:254028
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:03:37Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:168068
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:00:41Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:254710
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:03:36Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:168297
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:00:51Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:189833
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:00:54Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:276481
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:03:39Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:189704
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:00:59Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:189532
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:01:06Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:254130
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:03:45Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:254027
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:03:41Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:254115
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:03:44Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:190859
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:01:24Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:254451
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:03:48Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:254830
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:03:53Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:168568
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:01:40Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:189690
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:01:47Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:189831
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:01:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:168687
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:01:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:189985
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:01:51Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:190078
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:01:52Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:190871
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:01:57Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:169067
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:02:09Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:254687
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:03:58Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:190187
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:02:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:169132
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T04:02:16Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: openaire
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:254758
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:04:05Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:251614
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2017-05-30T05:00:52Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}resumptionToken: .eJwVj01vgjAAQP9Lz2RpAfnwtgUwJmsZ2BblYmpBhhQl0gWs8b8Pr--9y3uCsa4rsIYfjuv6Plp5yPVQGKzClQVGeb8pdWwXD-SeK3lVTGz4X95zeLAbn0SjTS6xi6ODd2LKiGuS4UKxCoZLXTqkIEO5CaaMjialsSGXzMNvRpP81KGcdgSVTulkBZt4InVlxjmNmpkYBtMemV2S2XsUzKyFj4wyfTD5zJ3ttIOxj2njYioRoYOW8JcRFZ4x32rcxei7wFDy6oFj_ZWaTx9YYBBNDda2BbpJ3JsRrJ-gr7WohBY_9_rczsviTbTHN5CtrsHr9Q_HLlxy.DRPJJA.KubBIe0ZIwhM2vTYM1AbjHROEVw

# %% [markdown]
# ### ListRecords
#
# Listar los registros
#
# This verb is used to harvest records from a repository. Optional arguments permit selective harvesting of records based on set membership and/or datestamp. Depending on the repository's support for deletions, a returned header may have a status attribute of "deleted" if a record matching the arguments specified in the request has been deleted. No metadata will be present for records with deleted status.

# %%
import xml.etree.ElementTree as ET
import requests

oai = requests.get('https://zenodo.org/oai2d?verb=ListRecords&metadataPrefix=oai_datacite')
xmlTree = ET.ElementTree(ET.fromstring(oai.text))
iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag)
    print(elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH
#
#
# {http://www.openarchives.org/OAI/2.0/}responseDate
# 2017-12-14T08:39:09Z
# {http://www.openarchives.org/OAI/2.0/}request
# https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListRecords
#
#
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:164231
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:54:31Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.164231
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shear, William A.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Warfel, Joseph G.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figures 58 – 63. Taracus Marchingtoni. Fig. 58 In The Harvestman Genus Taracus Simon 1879, And The New Genus Oskoron (Opiliones: Ischyropsalidoidea: Taracidae)
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Lepidoptera
# {http://datacite.org/schema/kernel-3}subject
# Lycaenidae
# {http://datacite.org/schema/kernel-3}subject
# Taracus
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039D941BFFFDFFF4D6EAFE22FCC3D94A
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4180.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFA4EC63FFDEFFD3D67DFFF3FFA0DB52
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039D941BFFFDFFF4D6EAFE22FCC3D94A
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4180.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFA4EC63FFDEFFD3D67DFFF3FFA0DB52
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURES 58 – 63. Taracus marchingtoni. Fig. 58, female, dorsal view. Fig. 59, penis. Fig. 60, glans penis. Fig. 61, female, lateral view. Fig. 62, male, dorsal view. Fig. 63, male, lateral view.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252141
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252141
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Mah, Christopher L.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Foltz, David W.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 7. Poraniomorpha Spp. A. Usnm E 16102 In New Taxa And Taxonomic Revisions To The Poraniidae (Valvatacea; Asteroidea) With Comments On Feeding Biology
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Echinodermata
# {http://datacite.org/schema/kernel-3}subject
# Asteroidea
# {http://datacite.org/schema/kernel-3}subject
# Valvatida
# {http://datacite.org/schema/kernel-3}subject
# Poraniidae
# {http://datacite.org/schema/kernel-3}subject
# Poraniomorpha
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039F453C9541873BFF0BFD0EFC76FBB2
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039F453C954E873BFF0BFB5EFDE6F974
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039F453C954C873EFF0BFDFDFD88FDE7
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039F453C954B873EFF0BFD6DFE5FF981
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3795.3.7
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFA63D4495568723FF9CFFD9FFA3FF87
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 7. Poraniomorpha spp. A. USNM E 16102 Poraniomorpha abyssicola, abactinal (R = 4.4). B. Actinal surface. C. Actinal close up showing furrow spines, actinal spination. D. USNM E 05361 Poraniomorpha tumidus, abactinal surface (R = 3.6). E. Actinal surface. F. Close up of papillate spinules on surface of Poraniomorpha abyssicola (USNM E 16102). Scale Bar = 0.5 cm. G. Close up of spinule distribution on P. tumida (USNM E 05361). Scale Bar = 0.5 cm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252977
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:47Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252977
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Harzhauser, Mathias
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Landau, Bernard
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 13 A 1 – A 5 In A Revision Of The Neogene Conidae And Conorbidae (Gastropoda) Of The Paratethys Sea
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Kalloconus
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDCFFCDFF5FA9D9FC3046B3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFCAFF5FA8E1FA0B4762
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFC8FF5FAE2DFDC5443D
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4210.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:CB06FFAFFF9FFF8EFFC8A876FF89416A
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDCFFCDFF5FA9D9FC3046B3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFCAFF5FA8E1FA0B4762
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFC8FF5FAE2DFDC5443D
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4210.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:CB06FFAFFF9FFF8EFFC8A876FF89416A
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 13 A 1 – A 5. Kalloconus ponderovagus (Sacco, 1893), Niederkreuzstetten (Austria), NHMW 1849 / 0004 / 0016, holotype. 13 B 1 – B 3. Niederkreuzstetten (Austria), NHMW A 991. 13 C 1 – C 4. Kalloconus pseudohungaricus nov. sp., Lăpugiu de Sus (Romania), NHMW 1868 / 0001 / 0380 a, paratype. 13 D. Lăpugiu de Sus (Romania), Kalloconus pseudohungaricus nov. sp., NHMW 1868 / 0001 / 0380 d, paratype. 13 E 1 – E 3. Kalloconus pseudohungaricus nov. sp., Lăpugiu de Sus (Romania), NHMW 1868 / 0001 / 0380 b, holotype. 13 F 1 – F 2. Lăpugiu de Sus (Romania), Kalloconus pseudohungaricus nov. sp., NHMW 1868 / 0001 / 0380 c, paratype. 13 G 1 – G 5. Kalloconus tietzei (Hoernes &amp; Auinger, 1879), NHMW 1847 / 0046 / 0004, Szob (Hungary), holotype.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252363
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:48Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252363
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Veijalainen, Anu
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Broad, Gavin R.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Sääksjärvi, Ilari E.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 1 In Twenty Seven New Species Of Orthocentrus (Hymenoptera: Ichneumonidae; Orthocentrinae) With A Key To The Neotropical Species Of The Genus
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Hymenoptera
# {http://datacite.org/schema/kernel-3}subject
# Ichneumonidae
# {http://datacite.org/schema/kernel-3}subject
# Orthocentrus
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F19B14030BBFDC25468381F
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F1AB14130BBFE4C543C3BAF
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F1BB14E30BBFC9C54B13D22
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F14B14F30BBFB1A56F23C5B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F15B14C30BBFA8F57663DFF
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F16B14D30BBFB2C54D53D07
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3768.3.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFC05E3A8F1CB146302CFFD8556D395F
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 1. Lateral views: Orthocentrus shieldsi species-group (in part). A: anguillae, B: pentagonum, C: concrispus, D: hispidus, E: quercus, F: shieldsi. Scale 0.5 mm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:251947
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:56Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.251947
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Belousov, Igor A.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Kabak, Ilya I.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figures 23 – 26 In A Taxonomic Review Of The Genus Junnanotrechus Uéno & Yin, 1993 (Coleoptera: Carabidae: Trechinae), With Description Of Six New Species
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Coleoptera
# {http://datacite.org/schema/kernel-3}subject
# Carabidae
# {http://datacite.org/schema/kernel-3}subject
# Junnanotrechus
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03ADED456B73FFC7FF06FCF9DD1CA1FB
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03ADED456B64FFE2FF06FCA2DAC7A2DB
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03ADED456B50FFE3FF06FF25DDB5A288
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3811.4.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FF94953D6B71FFC2FF91FFBDD82EA53E
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURES 23 – 26. Male genitalia of Junnanotrechus koroleviellus sp. n.: a—lateral view, b—dorsal view, c—parameres, d—genital segment.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:164760
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:02Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.164760
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Clulow, Simon
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Anstis, Marion
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Keogh, J. Scott
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Catullo, Renee A.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 4 In A New Species Of Australian Frog (Myobatrachidae: Uperoleia) From The New South Wales Mid-North Coast Sandplains
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Chordata
# {http://datacite.org/schema/kernel-3}subject
# Amphibia
# {http://datacite.org/schema/kernel-3}subject
# Anura
# {http://datacite.org/schema/kernel-3}subject
# Myobatrachidae
# {http://datacite.org/schema/kernel-3}subject
# Uperoleia
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/D15DE063FFF7B210FF47F9C9FC815520
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4184.2.3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:2D64981BFFF1B21EFFD0FFDBFFC05208
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/D15DE063FFF7B210FF47F9C9FC815520
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4184.2.3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:2D64981BFFF1B21EFFD0FFDBFFC05208
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 4. Uperoleia mahonyi sp. nov. demonstrating the range of variation in dorsal colour and patterning observed in life. (A) female AMS R 185700, Wyrrabalong National Park NSW, and (B) same specimen in dark phase (photographs S. Clulow); (C) calling male with vocal sac extended, specimen not collected, type locality (photograph S. Mahony); (D) female AMS R 185700 showing groin colour patch, Wyrrabalong National Park NSW (photograph S. Clulow); (E) male and female in amplexus, specimens not collected, type locality (photograph S. Mahony); (F) male, specimen not collected, Norah Head NSW (photograph J. Mulder).
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:185043
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:01Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.185043
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Marin, Ivan
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 25 In Crinoid-Associated Shrimps Of The Genus Laomenes A. H. Clark, 1919 (Caridea: Palaemonidae: Pontoniinae): New Species And Probable Diversity
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2009
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Malacostraca
# {http://datacite.org/schema/kernel-3}subject
# Decapoda
# {http://datacite.org/schema/kernel-3}subject
# Palaemonidae
# {http://datacite.org/schema/kernel-3}subject
# Laomenes
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2009-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03DC87A39559F605F1D42CF6FDB4206C
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.185020
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFE5FFDB9579F623F1432864FFF42206
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Zero - CC0 1.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 25. Laomenes ceratophthalmus (Borradaile, 1915). A, ovigerous female, B, male. Scale 1 mm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:165228
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:09Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.165228
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Arai, Hisao P.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Smith, John W.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 26 In Guide To The Parasites Of Fishes Of Canada Part V: Nematoda
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Nematoda
# {http://datacite.org/schema/kernel-3}subject
# Secernentea
# {http://datacite.org/schema/kernel-3}subject
# Spirurida
# {http://datacite.org/schema/kernel-3}subject
# Anguillicolidae
# {http://datacite.org/schema/kernel-3}subject
# Anguillicola
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/038FB248FF95FF9289B9C4DD228698DA
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4185.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFB6CA30FFB1FFB6892EC613204A9E70
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Zero - CC0 1.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 26. Anguillicola crassus Kuwahara, Niimi &amp; Itagaki, 1974. A. female, buccal capsule; B. male, anterior end; C. female, tail; D. male, tail with five rather than the usual six caudal papillae; E. vulva; F. egg containing 2 nd - stage larva. (Redrawn from Moravec 2013)
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:160751
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:12Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire_data
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-ecfunded
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.160751
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Wierstorf, Hagen
# {http://datacite.org/schema/kernel-3}affiliation
# Technische Universität Ilmenau
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Geier, Matthias
# {http://datacite.org/schema/kernel-3}affiliation
# Universität Rostock
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Binaural Room Impulse Responses Recorded With Kemar In A Small Meeting Room
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# BRIR
# {http://datacite.org/schema/kernel-3}subject
# KEMAR
# {http://datacite.org/schema/kernel-3}subject
# binaural simulatio
# {http://datacite.org/schema/kernel-3}contributors
#
#
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/618075/
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-10-14
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>The binaural room impulse responses (BRIRs) were measured in the small meeting room Spirit at the<br>
# Telefunken-building of TU Berlin. They were measured for three different loudspeaker positions placed around a table. The head of the dummy head was rotated with a resolution of 1° ranging from -90° to 90°. The measurement equipment was the same as described in Wierstorf et al. [1]</p>
#
# <p>[1] Wierstorf, H., Geier, M., Raake, A., Spors, S. (2011) “A Free Database of Head-Related Impulse Response Measurements in the Horizontal Plane with Multiple Distances,” 130th AES Convention, eBrief 6</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252670
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:57Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252670
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Chani-Posse, Mariana
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 11 In An Illustrated Key To The New World Genera Of Philonthina Kirby (Coleoptera: Staphylinidae), With Morphological, Taxonomical And Distributional Notes
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Coleoptera
# {http://datacite.org/schema/kernel-3}subject
# Staphylinidae
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03EF879CFFAFFFBDFF37FA6191A71384
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3755.1.3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFD6FFE4FFA3FFB3FFA0FFFA943C1748
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 11. (A – J) Habitus: (A) Atopocentrum mirabile, (B) Belonuchus aluticollis (Bernhauer), (C) Cafius xantholoma, (D) Chroaptomus mexicanus Chani-Posse &amp; Navarrete-Heredia, (E) Delgadobius amazonensis Chani-Posse &amp; Couturier, (F) Ecitophytes coniceps Wasmann, (G) Flohria subcoerulea (LeConte), (H) Gabrius nidicola (Bernhauer), (I) Gabronthus maritimus (Motschulsky), (J), Hesperus fasciatus (Sharp).
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252388
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:55Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-icsu_wds
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252388
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Mustapha Mokrane
# {http://datacite.org/schema/kernel-3}affiliation
# ICSU World Data System
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Lesley Rickards
# {http://datacite.org/schema/kernel-3}affiliation
# BODC
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Sandra Harrison
# {http://datacite.org/schema/kernel-3}affiliation
# University of Reading
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Legacy And Future Of The World Data System Certification Of Data Services And Networks
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Trustworthy Data Repositories
# {http://datacite.org/schema/kernel-3}subject
# Data Management
# {http://datacite.org/schema/kernel-3}subject
# Certification
# {http://datacite.org/schema/kernel-3}subject
# World Data System
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-09-12
# {http://datacite.org/schema/kernel-3}resourceType
# Conference paper
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>The World Data System (WDS) was created in October 2008 as an Interdisciplinary Body of the International Council for Science (ICSU), building on the 50+ year legacy of the World Data Centres and Federation of Astronomical and Geophysical data analysis Services established by ICSU to manage data generated from the International Geophysical Year (1957–1958). ICSU-WDS is striving to build worldwide ‘communities of excellence’ for scientific data services by certifying holders and providers of data or data products—and networks of these—from wide-ranging scientific domains using internationally recognized standards. Certification criteria and a procedure for evaluating candidates for membership were developed by the WDS Scientific Committee (WDS-SC) to ensure the trustworthiness of WDS Members in terms of authenticity, integrity, confidentiality, and availability of data and services. Certification is important because it promotes confidence in the usability and persistence of shared data resources. It also helps data services improve their practices and procedures.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:165623
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:15Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.165623
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# S.A. Yatsenko
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Поминально-Погребальные Памятники, Малая Скифия, Сюжеты, Иконография, Региональная Специфика, Религия Иранских Народов / Funeral And Memorial Monuments, Scythia Minor, Subjects, Iconography, Regional Features, Religion Of Iranian-Speaking Peoples
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# поминально-погребальные  памятники,  Малая  Скифия,  сюжеты,  иконография, региональная специфика, религия иранских народов / funeral and memorial monuments, Scythia Minor, subjects, iconography, regional  features, religion of Iranian-speaking peoples
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Journal article
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Рассмотрены изображения на поминально-погребальных памятниках трех районов крымской Малой Скифии I — начала III вв. н. э., выявлено много новых важных деталей. Их иконография и семантика получают объяснение из религиозных доисламских верований иранских и индоиранских народов, преимущественно — алано-осетинской традиции. / The series of depictions on the Funeral and Memorial monuments in three regions of Crimean Scythia Minor in the 1st — early 3rd cc. AD were examined, many new important local details were came to light. Their iconography and semantics may be explained on a religious pre-Islamic believes of Iranian and Indo-Iranian peoples, first of all — on Alanian-Ossetian traditions.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:165112
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.165112
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# L. A. Radomska
# {http://datacite.org/schema/kernel-3}affiliation
# Vinnytsia National Technical University
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Terminological Noun-Juxtapositions With Correlative Relations
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# terminological noun-juxtaposition
# {http://datacite.org/schema/kernel-3}subject
# correlative relations
# {http://datacite.org/schema/kernel-3}subject
# unequal semantic and equal semantic components
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-11-07
# {http://datacite.org/schema/kernel-3}resourceType
# Journal article
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>The aim of the research is to analyze the correlative relations in the structure of terminological nounjuxtapositions.<br>
# Its actuality is connected with the need of complex analysis of the structure and<br>
# semantics of these specific lexical units, clarifying with a wide range of semantic relations between<br>
# their components compared to the relations between the one-word terms. The purpose of the work is<br>
# to find out the specifics of establishment of correlative relations between components terminological<br>
# noun-juxtapositions (TNJ). The achievement of this goal involves the following tasks: 1) to determine<br>
# the size of the concept JUXTAPOSITION; 2) to set types of TNJ by semantic criterion; 3) to<br>
# describe the specific structure and lexical-semantic groups of TNJ with correlative components.<br>
# The status of noun-juxtapositions as independent lexical and grammatical units is motivated<br>
# by such criteria as: constant nomination, semantic integrity, idiomatic lexical meaning, integrity of<br>
# design. It is determined that noun-juxtapositions with correlative relations are formed on the base<br>
# of overlapping semantics of their components: mutual meaning specification (the first component,<br>
# as a second, the second component a first) or complementary of meanings (and the meaning of the<br>
# first component and the meaning of the second component).</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:165647
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.165647
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Felix, Rob P. W. H.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Massa, Bruno
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 19 In Orthoptera (Insecta: Tettigonioidea, Pyrgomorphoidea, Acridoidea) Of Kafa Biosphere Reserve, Bale Mountains National Park And Other Areas Of Conservation Interest In Ethiopia
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Orthoptera
# {http://datacite.org/schema/kernel-3}subject
# Phaneropteridae
# {http://datacite.org/schema/kernel-3}subject
# Peropyrrhicia
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB6DFF9AC4FCFEAEFBDAD08E
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB6CFF86C4FCFADEFCA9D636
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB71FF87C4FCFE39FB4CD473
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB70FF85C4FCFCE7FC91D64E
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB72FF85C4FCFEFCFA6CD19B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB75FF81C4FCF96DFC0FD64F
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB7AFF88C4FCF8E1FDE9D1D8
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# ...
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURES 23 – 30. Encarsia huangi sp. nov., holotype ♀: 23, head, frontal view; 24, antenna; 25, mesosoma; 26, fore wing with stigmal vein enlarged; 27, mid tibial spur and tarsi; 28, mesosoma and metasoma; 29, sculpture on petiole; 30, ovipositor. Scale bars = 50 µm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:190187
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T04:02:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.190187
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Riedel, Alexander
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figures 41 – 43 In Revision Of The Genus Penthoscapha Heller (Coleoptera, Curculionoidea, Entiminae, Eupholini) With Notes On The Genera Of Eupholini From New Guinea
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2009
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Coleoptera
# {http://datacite.org/schema/kernel-3}subject
# Curculionidae
# {http://datacite.org/schema/kernel-3}subject
# Penthoscapha
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2009-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C4FD16A03FD2A25FC7AFC5E
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C48D16A03FD2B8AFA1AF93F
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C5CD17A03FD28F7FC77F899
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.190177
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:741DFF894C4CD16E036A2860FF86FFCE
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C4FD16A03FD2A25FC7AFC5E
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C48D16A03FD2B8AFA1AF93F
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C5CD17A03FD28F7FC77F899
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.190177
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:741DFF894C4CD16E036A2860FF86FFCE
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURES 41 – 43. Penthoscapha lorentzi, lectotype: (41) aedeagus, dorsal aspect; (42) aedeagus, lateral aspect; (43) endophallus with transfer apparatus.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:169132
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T04:02:16Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.169132
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Trivedi, Dahryn
# {http://datacite.org/schema/kernel-3}affiliation
# Trivedi Global Inc.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Branton, Alice
# {http://datacite.org/schema/kernel-3}affiliation
# Trivedi Global Inc.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Trivedi, Mahendra Kumar
# {http://datacite.org/schema/kernel-3}affiliation
# Trivedi Global Inc.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Nayak, Gopal
# {http://datacite.org/schema/kernel-3}affiliation
# Trivedi Global Inc.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Use Of Energy Healing Medicine Against Escherichia Coli For Antimicrobial Susceptibility, Biochemical Reaction And Biotyping
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2015
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Escherichia Coli Infections
# {http://datacite.org/schema/kernel-3}subject
# Escherichia Coli Urinary Tract Infections
# {http://datacite.org/schema/kernel-3}subject
# Escherichia Coli Infections in Urine
# {http://datacite.org/schema/kernel-3}subject
# Clinical Isolates of E. Coli
# {http://datacite.org/schema/kernel-3}subject
# Antimicrobial Sensitivity of E. Coli
# {http://datacite.org/schema/kernel-3}subject
# Pathogenic Isolates of E. Coli
# {http://datacite.org/schema/kernel-3}subject
# MDR Isolates of E. Coli
# {http://datacite.org/schema/kernel-3}subject
# Antimicrobial Susceptibility Assay/Test of E. Coli
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2015-11-09
# {http://datacite.org/schema/kernel-3}resourceType
# Journal article
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution Share-Alike 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Escherichia coli (E. coli) infections are the major health concern, as it causes infections in human mainly in urinary tract, ear, and wound infections. The present study evaluates the impact of biofield energy treatment on E. coli regarding antimicrobial sensitivity assay, biochemical study and biotype number. Four multidrug resistant (MDR) clinical lab isolates (LSs) of E. coli (LS 12, LS 13, LS 42, and LS 51) were taken in two groups i.e. control and treated. After treatment, above mentioned parameter were evaluated on day 10 in control and treated samples using MicroScan Walk-Away® system. The antimicrobial sensitivity assay was reported with 46.67% alteration (14 out of 30 tested antimicrobials) in treated group of MDR E. coli isolates. The minimum inhibitory concentration (MIC) study showed the alteration in MIC values of about 34.37% (11 out of 32) tested antimicrobials, after biofield treatment in clinical isolates of E. coli. Piperacillin/tazobactam was reported with improved sensitivity and four-fold decrease in the MIC value (64 to ≤16 μg/mL) in LS 42, as compared with the control. Amoxicillin/kclavulanate reported with improved sensitivity pattern from resistance to susceptible, with two-fold decrease in MIC value (&gt;16/8 to ≤8/4 μg/mL) in biofield treated LS 51. Further, biochemical study showed 24.24% alteration (8 out of 33) in tested biochemical reactions after treatment among four isolates of E. coli as compared to the control. A change in biotype number (7774 4272) was reported as compared to the control, (7311 4012), with new organism identified as Klebsiella pneumoniae in biofield treated LS 13 with respect to the control organism, E. coli. Overall, data suggested that Mr. Trivedi’s biofield energy treatment can be applied to alter the antimicrobial sensitivity, biochemical reactions and biotype number of E. coli.</p>
# {http://datacite.org/schema/kernel-3}description
# Mahendra Kumar Trivedi, Alice Branton, Dahryn Trivedi, Gopal Nayak, Mayank Gangwar, Snehasis Jana. Use of Energy Healing Medicine Against Escherichia coli for Antimicrobial Susceptibility, Biochemical Reaction and Biotyping. American Journal of Bioscience and Bioengineering. Vol. 3, No. 5, 2015, pp. 99-105. doi: 10.11648/j.bio.20150305.23
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:254758
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:04:05Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.254758
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Hamada, N.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Silva, J. O.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Pedroza, M. K.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figures 16 – 21. Enderleina Bifasciata N In A New Species Of Enderleina Jewett (Plecoptera, Perlidae) From Amazonas State, Brazil
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Plecoptera
# {http://datacite.org/schema/kernel-3}subject
# Perlidae
# {http://datacite.org/schema/kernel-3}subject
# Enderleina
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/FF4387CEFFE82775F5CBC21FFEDAFB02
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4098.2.11
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:037AFFB6FFE92772F55CC418FF81FF81
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/FF4387CEFFE82775F5CBC21FFEDAFB02
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4098.2.11
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:037AFFB6FFE92772F55CC418FF81FF81
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURES 16 – 21. Enderleina bifasciata n. sp., male. 16. Abdomen distal region, in ventral view. 17. Abdomen, distal region, in dorsal view. 18. Abdomen distal region, in lateral view. 19. Tergite X, lateral region of posterior margin; arrow indicates the sensilla basiconica. 20. Paraprocts, in postero-lateral view. 21. Paraprocto, lateral view, arrow indicates the subbasal spine.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:251614
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:00:52Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.251614
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Gupta, Ankita
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Fernández-Triana, José L.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 118 In Diversity, Host Association, And Cocoon Variability Of Reared Indian Microgastrinae (Hymenoptera: Braconidae)
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3800.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:F64ACE0DA870FFEE4178FFA6FFE78148
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 118. Apanteles tachardiae (female, Punjab) — E. Profile view F. Fore wing G. Metasoma in lateral view.
# {http://www.openarchives.org/OAI/2.0/}resumptionToken
# .eJyFj8sOgjAURP_lrokpBSuSsBOMC6oQHsqG1FIJUh-hmBqM_y4kunYxmzMnk8wLlBAVuGiG5yYmGDkOWdqYEGQZoHh3k7Jsxh74PpP8KlO2zh7xJUMHXC_oSmF69u1wCMkxlQO7BlGYy7RCy9EuLJrTe7F2dJSoYZv4Y2oSTiwJ4mNrxklLzcIqrChPdRbwvhp-e9G_va-3-efprfY8MODOagEuNqDVrKsVuC-4iJ5VrGe7Tpya53jxxppyArzpBbzfH-HqXNM.DRPKLQ.80DKdzyuSCB4Cnbs7QpM5DF6JPU

# %% [markdown]
# Muestra sólo el identificador y las palabras clave (subject)

# %% [markdown]
# Registros entre dos fechas

# %%
import xml.etree.ElementTree as ET

bounds = "&from='2017-01-01'&until='2017-12-31'" #Para filtrar por fechas
oai = requests.get('https://zenodo.org/oai2d?verb=ListRecords&metadataPrefix=oai_datacite'+bounds)
xmlTree = ET.ElementTree(ET.fromstring(oai.text))
iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag)
    print(elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH
#
#
# {http://www.openarchives.org/OAI/2.0/}responseDate
# 2017-12-14T08:39:36Z
# {http://www.openarchives.org/OAI/2.0/}request
# https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListRecords
#
#
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:164231
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:54:31Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.164231
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shear, William A.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Warfel, Joseph G.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figures 58 – 63. Taracus Marchingtoni. Fig. 58 In The Harvestman Genus Taracus Simon 1879, And The New Genus Oskoron (Opiliones: Ischyropsalidoidea: Taracidae)
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Lepidoptera
# {http://datacite.org/schema/kernel-3}subject
# Lycaenidae
# {http://datacite.org/schema/kernel-3}subject
# Taracus
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039D941BFFFDFFF4D6EAFE22FCC3D94A
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4180.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFA4EC63FFDEFFD3D67DFFF3FFA0DB52
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039D941BFFFDFFF4D6EAFE22FCC3D94A
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4180.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFA4EC63FFDEFFD3D67DFFF3FFA0DB52
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURES 58 – 63. Taracus marchingtoni. Fig. 58, female, dorsal view. Fig. 59, penis. Fig. 60, glans penis. Fig. 61, female, lateral view. Fig. 62, male, dorsal view. Fig. 63, male, lateral view.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252141
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252141
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Mah, Christopher L.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Foltz, David W.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 7. Poraniomorpha Spp. A. Usnm E 16102 In New Taxa And Taxonomic Revisions To The Poraniidae (Valvatacea; Asteroidea) With Comments On Feeding Biology
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Echinodermata
# {http://datacite.org/schema/kernel-3}subject
# Asteroidea
# {http://datacite.org/schema/kernel-3}subject
# Valvatida
# {http://datacite.org/schema/kernel-3}subject
# Poraniidae
# {http://datacite.org/schema/kernel-3}subject
# Poraniomorpha
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039F453C9541873BFF0BFD0EFC76FBB2
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039F453C954E873BFF0BFB5EFDE6F974
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039F453C954C873EFF0BFDFDFD88FDE7
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039F453C954B873EFF0BFD6DFE5FF981
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3795.3.7
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFA63D4495568723FF9CFFD9FFA3FF87
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 7. Poraniomorpha spp. A. USNM E 16102 Poraniomorpha abyssicola, abactinal (R = 4.4). B. Actinal surface. C. Actinal close up showing furrow spines, actinal spination. D. USNM E 05361 Poraniomorpha tumidus, abactinal surface (R = 3.6). E. Actinal surface. F. Close up of papillate spinules on surface of Poraniomorpha abyssicola (USNM E 16102). Scale Bar = 0.5 cm. G. Close up of spinule distribution on P. tumida (USNM E 05361). Scale Bar = 0.5 cm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252977
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:47Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252977
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Harzhauser, Mathias
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Landau, Bernard
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 13 A 1 – A 5 In A Revision Of The Neogene Conidae And Conorbidae (Gastropoda) Of The Paratethys Sea
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Kalloconus
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDCFFCDFF5FA9D9FC3046B3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFCAFF5FA8E1FA0B4762
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFC8FF5FAE2DFDC5443D
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4210.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:CB06FFAFFF9FFF8EFFC8A876FF89416A
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDCFFCDFF5FA9D9FC3046B3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFCAFF5FA8E1FA0B4762
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFC8FF5FAE2DFDC5443D
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4210.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:CB06FFAFFF9FFF8EFFC8A876FF89416A
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 13 A 1 – A 5. Kalloconus ponderovagus (Sacco, 1893), Niederkreuzstetten (Austria), NHMW 1849 / 0004 / 0016, holotype. 13 B 1 – B 3. Niederkreuzstetten (Austria), NHMW A 991. 13 C 1 – C 4. Kalloconus pseudohungaricus nov. sp., Lăpugiu de Sus (Romania), NHMW 1868 / 0001 / 0380 a, paratype. 13 D. Lăpugiu de Sus (Romania), Kalloconus pseudohungaricus nov. sp., NHMW 1868 / 0001 / 0380 d, paratype. 13 E 1 – E 3. Kalloconus pseudohungaricus nov. sp., Lăpugiu de Sus (Romania), NHMW 1868 / 0001 / 0380 b, holotype. 13 F 1 – F 2. Lăpugiu de Sus (Romania), Kalloconus pseudohungaricus nov. sp., NHMW 1868 / 0001 / 0380 c, paratype. 13 G 1 – G 5. Kalloconus tietzei (Hoernes &amp; Auinger, 1879), NHMW 1847 / 0046 / 0004, Szob (Hungary), holotype.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252363
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:48Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252363
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Veijalainen, Anu
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Broad, Gavin R.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Sääksjärvi, Ilari E.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 1 In Twenty Seven New Species Of Orthocentrus (Hymenoptera: Ichneumonidae; Orthocentrinae) With A Key To The Neotropical Species Of The Genus
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Hymenoptera
# {http://datacite.org/schema/kernel-3}subject
# Ichneumonidae
# {http://datacite.org/schema/kernel-3}subject
# Orthocentrus
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F19B14030BBFDC25468381F
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F1AB14130BBFE4C543C3BAF
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F1BB14E30BBFC9C54B13D22
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F14B14F30BBFB1A56F23C5B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F15B14C30BBFA8F57663DFF
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F16B14D30BBFB2C54D53D07
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3768.3.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFC05E3A8F1CB146302CFFD8556D395F
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 1. Lateral views: Orthocentrus shieldsi species-group (in part). A: anguillae, B: pentagonum, C: concrispus, D: hispidus, E: quercus, F: shieldsi. Scale 0.5 mm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:251947
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:56Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.251947
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Belousov, Igor A.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Kabak, Ilya I.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figures 23 – 26 In A Taxonomic Review Of The Genus Junnanotrechus Uéno & Yin, 1993 (Coleoptera: Carabidae: Trechinae), With Description Of Six New Species
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Coleoptera
# {http://datacite.org/schema/kernel-3}subject
# Carabidae
# {http://datacite.org/schema/kernel-3}subject
# Junnanotrechus
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03ADED456B73FFC7FF06FCF9DD1CA1FB
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03ADED456B64FFE2FF06FCA2DAC7A2DB
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03ADED456B50FFE3FF06FF25DDB5A288
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3811.4.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FF94953D6B71FFC2FF91FFBDD82EA53E
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURES 23 – 26. Male genitalia of Junnanotrechus koroleviellus sp. n.: a—lateral view, b—dorsal view, c—parameres, d—genital segment.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:164760
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:02Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.164760
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Clulow, Simon
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Anstis, Marion
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Keogh, J. Scott
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Catullo, Renee A.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 4 In A New Species Of Australian Frog (Myobatrachidae: Uperoleia) From The New South Wales Mid-North Coast Sandplains
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Chordata
# {http://datacite.org/schema/kernel-3}subject
# Amphibia
# {http://datacite.org/schema/kernel-3}subject
# Anura
# {http://datacite.org/schema/kernel-3}subject
# Myobatrachidae
# {http://datacite.org/schema/kernel-3}subject
# Uperoleia
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/D15DE063FFF7B210FF47F9C9FC815520
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4184.2.3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:2D64981BFFF1B21EFFD0FFDBFFC05208
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/D15DE063FFF7B210FF47F9C9FC815520
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4184.2.3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:2D64981BFFF1B21EFFD0FFDBFFC05208
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 4. Uperoleia mahonyi sp. nov. demonstrating the range of variation in dorsal colour and patterning observed in life. (A) female AMS R 185700, Wyrrabalong National Park NSW, and (B) same specimen in dark phase (photographs S. Clulow); (C) calling male with vocal sac extended, specimen not collected, type locality (photograph S. Mahony); (D) female AMS R 185700 showing groin colour patch, Wyrrabalong National Park NSW (photograph S. Clulow); (E) male and female in amplexus, specimens not collected, type locality (photograph S. Mahony); (F) male, specimen not collected, Norah Head NSW (photograph J. Mulder).
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:185043
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:01Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.185043
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Marin, Ivan
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 25 In Crinoid-Associated Shrimps Of The Genus Laomenes A. H. Clark, 1919 (Caridea: Palaemonidae: Pontoniinae): New Species And Probable Diversity
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2009
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Malacostraca
# {http://datacite.org/schema/kernel-3}subject
# Decapoda
# {http://datacite.org/schema/kernel-3}subject
# Palaemonidae
# {http://datacite.org/schema/kernel-3}subject
# Laomenes
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2009-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03DC87A39559F605F1D42CF6FDB4206C
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.185020
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFE5FFDB9579F623F1432864FFF42206
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Zero - CC0 1.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 25. Laomenes ceratophthalmus (Borradaile, 1915). A, ovigerous female, B, male. Scale 1 mm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:165228
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:09Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.165228
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Arai, Hisao P.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Smith, John W.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 26 In Guide To The Parasites Of Fishes Of Canada Part V: Nematoda
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Nematoda
# {http://datacite.org/schema/kernel-3}subject
# Secernentea
# {http://datacite.org/schema/kernel-3}subject
# Spirurida
# {http://datacite.org/schema/kernel-3}subject
# Anguillicolidae
# {http://datacite.org/schema/kernel-3}subject
# Anguillicola
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/038FB248FF95FF9289B9C4DD228698DA
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4185.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFB6CA30FFB1FFB6892EC613204A9E70
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Zero - CC0 1.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 26. Anguillicola crassus Kuwahara, Niimi &amp; Itagaki, 1974. A. female, buccal capsule; B. male, anterior end; C. female, tail; D. male, tail with five rather than the usual six caudal papillae; E. vulva; F. egg containing 2 nd - stage larva. (Redrawn from Moravec 2013)
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:160751
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:12Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire_data
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-ecfunded
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.160751
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Wierstorf, Hagen
# {http://datacite.org/schema/kernel-3}affiliation
# Technische Universität Ilmenau
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Geier, Matthias
# {http://datacite.org/schema/kernel-3}affiliation
# Universität Rostock
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Binaural Room Impulse Responses Recorded With Kemar In A Small Meeting Room
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# BRIR
# {http://datacite.org/schema/kernel-3}subject
# KEMAR
# {http://datacite.org/schema/kernel-3}subject
# binaural simulatio
# {http://datacite.org/schema/kernel-3}contributors
#
#
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/618075/
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-10-14
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>The binaural room impulse responses (BRIRs) were measured in the small meeting room Spirit at the<br>
# Telefunken-building of TU Berlin. They were measured for three different loudspeaker positions placed around a table. The head of the dummy head was rotated with a resolution of 1° ranging from -90° to 90°. The measurement equipment was the same as described in Wierstorf et al. [1]</p>
#
# <p>[1] Wierstorf, H., Geier, M., Raake, A., Spors, S. (2011) “A Free Database of Head-Related Impulse Response Measurements in the Horizontal Plane with Multiple Distances,” 130th AES Convention, eBrief 6</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252670
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:57Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252670
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Chani-Posse, Mariana
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 11 In An Illustrated Key To The New World Genera Of Philonthina Kirby (Coleoptera: Staphylinidae), With Morphological, Taxonomical And Distributional Notes
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Coleoptera
# {http://datacite.org/schema/kernel-3}subject
# Staphylinidae
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03EF879CFFAFFFBDFF37FA6191A71384
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3755.1.3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFD6FFE4FFA3FFB3FFA0FFFA943C1748
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 11. (A – J) Habitus: (A) Atopocentrum mirabile, (B) Belonuchus aluticollis (Bernhauer), (C) Cafius xantholoma, (D) Chroaptomus mexicanus Chani-Posse &amp; Navarrete-Heredia, (E) Delgadobius amazonensis Chani-Posse &amp; Couturier, (F) Ecitophytes coniceps Wasmann, (G) Flohria subcoerulea (LeConte), (H) Gabrius nidicola (Bernhauer), (I) Gabronthus maritimus (Motschulsky), (J), Hesperus fasciatus (Sharp).
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252388
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:55Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-icsu_wds
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252388
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Mustapha Mokrane
# {http://datacite.org/schema/kernel-3}affiliation
# ICSU World Data System
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Lesley Rickards
# {http://datacite.org/schema/kernel-3}affiliation
# BODC
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Sandra Harrison
# {http://datacite.org/schema/kernel-3}affiliation
# University of Reading
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Legacy And Future Of The World Data System Certification Of Data Services And Networks
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Trustworthy Data Repositories
# {http://datacite.org/schema/kernel-3}subject
# Data Management
# {http://datacite.org/schema/kernel-3}subject
# Certification
# {http://datacite.org/schema/kernel-3}subject
# World Data System
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-09-12
# {http://datacite.org/schema/kernel-3}resourceType
# Conference paper
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>The World Data System (WDS) was created in October 2008 as an Interdisciplinary Body of the International Council for Science (ICSU), building on the 50+ year legacy of the World Data Centres and Federation of Astronomical and Geophysical data analysis Services established by ICSU to manage data generated from the International Geophysical Year (1957–1958). ICSU-WDS is striving to build worldwide ‘communities of excellence’ for scientific data services by certifying holders and providers of data or data products—and networks of these—from wide-ranging scientific domains using internationally recognized standards. Certification criteria and a procedure for evaluating candidates for membership were developed by the WDS Scientific Committee (WDS-SC) to ensure the trustworthiness of WDS Members in terms of authenticity, integrity, confidentiality, and availability of data and services. Certification is important because it promotes confidence in the usability and persistence of shared data resources. It also helps data services improve their practices and procedures.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:165623
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:15Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.165623
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# S.A. Yatsenko
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Поминально-Погребальные Памятники, Малая Скифия, Сюжеты, Иконография, Региональная Специфика, Религия Иранских Народов / Funeral And Memorial Monuments, Scythia Minor, Subjects, Iconography, Regional Features, Religion Of Iranian-Speaking Peoples
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# поминально-погребальные  памятники,  Малая  Скифия,  сюжеты,  иконография, региональная специфика, религия иранских народов / funeral and memorial monuments, Scythia Minor, subjects, iconography, regional  features, religion of Iranian-speaking peoples
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Journal article
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Рассмотрены изображения на поминально-погребальных памятниках трех районов крымской Малой Скифии I — начала III вв. н. э., выявлено много новых важных деталей. Их иконография и семантика получают объяснение из религиозных доисламских верований иранских и индоиранских народов, преимущественно — алано-осетинской традиции. / The series of depictions on the Funeral and Memorial monuments in three regions of Crimean Scythia Minor in the 1st — early 3rd cc. AD were examined, many new important local details were came to light. Their iconography and semantics may be explained on a religious pre-Islamic believes of Iranian and Indo-Iranian peoples, first of all — on Alanian-Ossetian traditions.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:165112
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.165112
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# L. A. Radomska
# {http://datacite.org/schema/kernel-3}affiliation
# Vinnytsia National Technical University
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Terminological Noun-Juxtapositions With Correlative Relations
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# terminological noun-juxtaposition
# {http://datacite.org/schema/kernel-3}subject
# correlative relations
# {http://datacite.org/schema/kernel-3}subject
# unequal semantic and equal semantic components
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-11-07
# {http://datacite.org/schema/kernel-3}resourceType
# Journal article
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>The aim of the research is to analyze the correlative relations in the structure of terminological nounjuxtapositions.<br>
# Its actuality is connected with the need of complex analysis of the structure and<br>
# semantics of these specific lexical units, clarifying with a wide range of semantic relations between<br>
# their components compared to the relations between the one-word terms. The purpose of the work is<br>
# to find out the specifics of establishment of correlative relations between components terminological<br>
# noun-juxtapositions (TNJ). The achievement of this goal involves the following tasks: 1) to determine<br>
# the size of the concept JUXTAPOSITION; 2) to set types of TNJ by semantic criterion; 3) to<br>
# describe the specific structure and lexical-semantic groups of TNJ with correlative components.<br>
# The status of noun-juxtapositions as independent lexical and grammatical units is motivated<br>
# by such criteria as: constant nomination, semantic integrity, idiomatic lexical meaning, integrity of<br>
# design. It is determined that noun-juxtapositions with correlative relations are formed on the base<br>
# of overlapping semantics of their components: mutual meaning specification (the first component,<br>
# as a second, the second component a first) or complementary of meanings (and the meaning of the<br>
# first component and the meaning of the second component).</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:165647
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.165647
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Felix, Rob P. W. H.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Massa, Bruno
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 19 In Orthoptera (Insecta: Tettigonioidea, Pyrgomorphoidea, Acridoidea) Of Kafa Biosphere Reserve, Bale Mountains National Park And Other Areas Of Conservation Interest In Ethiopia
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Orthoptera
# {http://datacite.org/schema/kernel-3}subject
# Phaneropteridae
# {http://datacite.org/schema/kernel-3}subject
# Peropyrrhicia
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB6DFF9AC4FCFEAEFBDAD08E
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB6CFF86C4FCFADEFCA9D636
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB71FF87C4FCFE39FB4CD473
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB70FF85C4FCFCE7FC91D64E
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB72FF85C4FCFEFCFA6CD19B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB75FF81C4FCF96DFC0FD64F
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB7AFF88C4FCF8E1FDE9D1D8
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# ...
# {http://datacite.org/schema/kernel-3}description
# FIGURES 23 – 30. Encarsia huangi sp. nov., holotype ♀: 23, head, frontal view; 24, antenna; 25, mesosoma; 26, fore wing with stigmal vein enlarged; 27, mid tibial spur and tarsi; 28, mesosoma and metasoma; 29, sculpture on petiole; 30, ovipositor. Scale bars = 50 µm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:190187
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T04:02:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.190187
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Riedel, Alexander
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figures 41 – 43 In Revision Of The Genus Penthoscapha Heller (Coleoptera, Curculionoidea, Entiminae, Eupholini) With Notes On The Genera Of Eupholini From New Guinea
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2009
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Coleoptera
# {http://datacite.org/schema/kernel-3}subject
# Curculionidae
# {http://datacite.org/schema/kernel-3}subject
# Penthoscapha
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2009-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C4FD16A03FD2A25FC7AFC5E
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C48D16A03FD2B8AFA1AF93F
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C5CD17A03FD28F7FC77F899
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.190177
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:741DFF894C4CD16E036A2860FF86FFCE
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C4FD16A03FD2A25FC7AFC5E
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C48D16A03FD2B8AFA1AF93F
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C5CD17A03FD28F7FC77F899
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.190177
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:741DFF894C4CD16E036A2860FF86FFCE
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURES 41 – 43. Penthoscapha lorentzi, lectotype: (41) aedeagus, dorsal aspect; (42) aedeagus, lateral aspect; (43) endophallus with transfer apparatus.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:169132
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T04:02:16Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.169132
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Trivedi, Dahryn
# {http://datacite.org/schema/kernel-3}affiliation
# Trivedi Global Inc.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Branton, Alice
# {http://datacite.org/schema/kernel-3}affiliation
# Trivedi Global Inc.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Trivedi, Mahendra Kumar
# {http://datacite.org/schema/kernel-3}affiliation
# Trivedi Global Inc.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Nayak, Gopal
# {http://datacite.org/schema/kernel-3}affiliation
# Trivedi Global Inc.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Use Of Energy Healing Medicine Against Escherichia Coli For Antimicrobial Susceptibility, Biochemical Reaction And Biotyping
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2015
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Escherichia Coli Infections
# {http://datacite.org/schema/kernel-3}subject
# Escherichia Coli Urinary Tract Infections
# {http://datacite.org/schema/kernel-3}subject
# Escherichia Coli Infections in Urine
# {http://datacite.org/schema/kernel-3}subject
# Clinical Isolates of E. Coli
# {http://datacite.org/schema/kernel-3}subject
# Antimicrobial Sensitivity of E. Coli
# {http://datacite.org/schema/kernel-3}subject
# Pathogenic Isolates of E. Coli
# {http://datacite.org/schema/kernel-3}subject
# MDR Isolates of E. Coli
# {http://datacite.org/schema/kernel-3}subject
# Antimicrobial Susceptibility Assay/Test of E. Coli
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2015-11-09
# {http://datacite.org/schema/kernel-3}resourceType
# Journal article
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution Share-Alike 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Escherichia coli (E. coli) infections are the major health concern, as it causes infections in human mainly in urinary tract, ear, and wound infections. The present study evaluates the impact of biofield energy treatment on E. coli regarding antimicrobial sensitivity assay, biochemical study and biotype number. Four multidrug resistant (MDR) clinical lab isolates (LSs) of E. coli (LS 12, LS 13, LS 42, and LS 51) were taken in two groups i.e. control and treated. After treatment, above mentioned parameter were evaluated on day 10 in control and treated samples using MicroScan Walk-Away® system. The antimicrobial sensitivity assay was reported with 46.67% alteration (14 out of 30 tested antimicrobials) in treated group of MDR E. coli isolates. The minimum inhibitory concentration (MIC) study showed the alteration in MIC values of about 34.37% (11 out of 32) tested antimicrobials, after biofield treatment in clinical isolates of E. coli. Piperacillin/tazobactam was reported with improved sensitivity and four-fold decrease in the MIC value (64 to ≤16 μg/mL) in LS 42, as compared with the control. Amoxicillin/kclavulanate reported with improved sensitivity pattern from resistance to susceptible, with two-fold decrease in MIC value (&gt;16/8 to ≤8/4 μg/mL) in biofield treated LS 51. Further, biochemical study showed 24.24% alteration (8 out of 33) in tested biochemical reactions after treatment among four isolates of E. coli as compared to the control. A change in biotype number (7774 4272) was reported as compared to the control, (7311 4012), with new organism identified as Klebsiella pneumoniae in biofield treated LS 13 with respect to the control organism, E. coli. Overall, data suggested that Mr. Trivedi’s biofield energy treatment can be applied to alter the antimicrobial sensitivity, biochemical reactions and biotype number of E. coli.</p>
# {http://datacite.org/schema/kernel-3}description
# Mahendra Kumar Trivedi, Alice Branton, Dahryn Trivedi, Gopal Nayak, Mayank Gangwar, Snehasis Jana. Use of Energy Healing Medicine Against Escherichia coli for Antimicrobial Susceptibility, Biochemical Reaction and Biotyping. American Journal of Bioscience and Bioengineering. Vol. 3, No. 5, 2015, pp. 99-105. doi: 10.11648/j.bio.20150305.23
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:254758
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:04:05Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.254758
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Hamada, N.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Silva, J. O.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Pedroza, M. K.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figures 16 – 21. Enderleina Bifasciata N In A New Species Of Enderleina Jewett (Plecoptera, Perlidae) From Amazonas State, Brazil
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Plecoptera
# {http://datacite.org/schema/kernel-3}subject
# Perlidae
# {http://datacite.org/schema/kernel-3}subject
# Enderleina
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/FF4387CEFFE82775F5CBC21FFEDAFB02
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4098.2.11
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:037AFFB6FFE92772F55CC418FF81FF81
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/FF4387CEFFE82775F5CBC21FFEDAFB02
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4098.2.11
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:037AFFB6FFE92772F55CC418FF81FF81
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURES 16 – 21. Enderleina bifasciata n. sp., male. 16. Abdomen distal region, in ventral view. 17. Abdomen, distal region, in dorsal view. 18. Abdomen distal region, in lateral view. 19. Tergite X, lateral region of posterior margin; arrow indicates the sensilla basiconica. 20. Paraprocts, in postero-lateral view. 21. Paraprocto, lateral view, arrow indicates the subbasal spine.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:251614
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:00:52Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.251614
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Gupta, Ankita
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Fernández-Triana, José L.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 118 In Diversity, Host Association, And Cocoon Variability Of Reared Indian Microgastrinae (Hymenoptera: Braconidae)
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3800.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:F64ACE0DA870FFEE4178FFA6FFE78148
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 118. Apanteles tachardiae (female, Punjab) — E. Profile view F. Fore wing G. Metasoma in lateral view.
# {http://www.openarchives.org/OAI/2.0/}resumptionToken
# .eJxlT01vgjAA_S-9TpcWHDgSDzPA5mLLgFKRi8HyMQTUQA1Y439fZ7LTkpd3eF_Ju4E-zzNgwWdkIt1AmvmqIWM-N14moOfdqWl2lbIBj1nDj02UvrNL0DK41UqT2L30qAOx_WbgDTkn1A32NQpoTVCiJ7q_iQbmcpHJfvTsciSSz7wWydD1tRjNx6iCV59GYiuDkemrIYSOiWk5w5TrRJ4Fh98RaV4LzFYC1w5abzDkLLtiRyw96cw821G52tjHZMXspIilG67p55KE6EA-3Jgflmuf9oM3LBZgAs5pmQNLm4B6SLuyB9YNFN2pVec0iMwpRAoUQuuBpwerVpuLNEtF-tXlRTWq8Cmtdr8Cr0Su_MtRVM3fBtKm-r-N-_0HDN1svQ.DRPKSQ.lZepIWz_tBdbRoCDECQQlUquG8s

# %% [markdown]
# OBtener DOI de un recurso. Pista: Mirar atributos (identifierType="DOI")

# %%
import xml.etree.ElementTree as ET

bounds = "&from='2017-01-01'&until='2017-12-31'" #Para filtrar por fechas
oai = requests.get('https://zenodo.org/oai2d?verb=ListRecords&metadataPrefix=oai_datacite'+bounds)
xmlTree = ET.ElementTree(ET.fromstring(oai.text))
iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag)
    print(elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH
#
#
# {http://www.openarchives.org/OAI/2.0/}responseDate
# 2017-12-14T08:43:21Z
# {http://www.openarchives.org/OAI/2.0/}request
# https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListRecords
#
#
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:164231
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:54:31Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.164231
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shear, William A.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Warfel, Joseph G.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figures 58 – 63. Taracus Marchingtoni. Fig. 58 In The Harvestman Genus Taracus Simon 1879, And The New Genus Oskoron (Opiliones: Ischyropsalidoidea: Taracidae)
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Lepidoptera
# {http://datacite.org/schema/kernel-3}subject
# Lycaenidae
# {http://datacite.org/schema/kernel-3}subject
# Taracus
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039D941BFFFDFFF4D6EAFE22FCC3D94A
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4180.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFA4EC63FFDEFFD3D67DFFF3FFA0DB52
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039D941BFFFDFFF4D6EAFE22FCC3D94A
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4180.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFA4EC63FFDEFFD3D67DFFF3FFA0DB52
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURES 58 – 63. Taracus marchingtoni. Fig. 58, female, dorsal view. Fig. 59, penis. Fig. 60, glans penis. Fig. 61, female, lateral view. Fig. 62, male, dorsal view. Fig. 63, male, lateral view.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252141
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252141
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Mah, Christopher L.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Foltz, David W.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 7. Poraniomorpha Spp. A. Usnm E 16102 In New Taxa And Taxonomic Revisions To The Poraniidae (Valvatacea; Asteroidea) With Comments On Feeding Biology
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Echinodermata
# {http://datacite.org/schema/kernel-3}subject
# Asteroidea
# {http://datacite.org/schema/kernel-3}subject
# Valvatida
# {http://datacite.org/schema/kernel-3}subject
# Poraniidae
# {http://datacite.org/schema/kernel-3}subject
# Poraniomorpha
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039F453C9541873BFF0BFD0EFC76FBB2
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039F453C954E873BFF0BFB5EFDE6F974
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039F453C954C873EFF0BFDFDFD88FDE7
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/039F453C954B873EFF0BFD6DFE5FF981
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3795.3.7
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFA63D4495568723FF9CFFD9FFA3FF87
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 7. Poraniomorpha spp. A. USNM E 16102 Poraniomorpha abyssicola, abactinal (R = 4.4). B. Actinal surface. C. Actinal close up showing furrow spines, actinal spination. D. USNM E 05361 Poraniomorpha tumidus, abactinal surface (R = 3.6). E. Actinal surface. F. Close up of papillate spinules on surface of Poraniomorpha abyssicola (USNM E 16102). Scale Bar = 0.5 cm. G. Close up of spinule distribution on P. tumida (USNM E 05361). Scale Bar = 0.5 cm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252977
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:47Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252977
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Harzhauser, Mathias
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Landau, Bernard
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 13 A 1 – A 5 In A Revision Of The Neogene Conidae And Conorbidae (Gastropoda) Of The Paratethys Sea
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Kalloconus
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDCFFCDFF5FA9D9FC3046B3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFCAFF5FA8E1FA0B4762
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFC8FF5FAE2DFDC5443D
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4210.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:CB06FFAFFF9FFF8EFFC8A876FF89416A
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDCFFCDFF5FA9D9FC3046B3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFCAFF5FA8E1FA0B4762
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFC8FF5FAE2DFDC5443D
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4210.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:CB06FFAFFF9FFF8EFFC8A876FF89416A
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 13 A 1 – A 5. Kalloconus ponderovagus (Sacco, 1893), Niederkreuzstetten (Austria), NHMW 1849 / 0004 / 0016, holotype. 13 B 1 – B 3. Niederkreuzstetten (Austria), NHMW A 991. 13 C 1 – C 4. Kalloconus pseudohungaricus nov. sp., Lăpugiu de Sus (Romania), NHMW 1868 / 0001 / 0380 a, paratype. 13 D. Lăpugiu de Sus (Romania), Kalloconus pseudohungaricus nov. sp., NHMW 1868 / 0001 / 0380 d, paratype. 13 E 1 – E 3. Kalloconus pseudohungaricus nov. sp., Lăpugiu de Sus (Romania), NHMW 1868 / 0001 / 0380 b, holotype. 13 F 1 – F 2. Lăpugiu de Sus (Romania), Kalloconus pseudohungaricus nov. sp., NHMW 1868 / 0001 / 0380 c, paratype. 13 G 1 – G 5. Kalloconus tietzei (Hoernes &amp; Auinger, 1879), NHMW 1847 / 0046 / 0004, Szob (Hungary), holotype.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252363
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:48Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252363
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Veijalainen, Anu
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Broad, Gavin R.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Sääksjärvi, Ilari E.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 1 In Twenty Seven New Species Of Orthocentrus (Hymenoptera: Ichneumonidae; Orthocentrinae) With A Key To The Neotropical Species Of The Genus
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Hymenoptera
# {http://datacite.org/schema/kernel-3}subject
# Ichneumonidae
# {http://datacite.org/schema/kernel-3}subject
# Orthocentrus
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F19B14030BBFDC25468381F
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F1AB14130BBFE4C543C3BAF
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F1BB14E30BBFC9C54B13D22
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F14B14F30BBFB1A56F23C5B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F15B14C30BBFA8F57663DFF
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03F926428F16B14D30BBFB2C54D53D07
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3768.3.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFC05E3A8F1CB146302CFFD8556D395F
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 1. Lateral views: Orthocentrus shieldsi species-group (in part). A: anguillae, B: pentagonum, C: concrispus, D: hispidus, E: quercus, F: shieldsi. Scale 0.5 mm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:251947
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:56Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.251947
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Belousov, Igor A.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Kabak, Ilya I.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figures 23 – 26 In A Taxonomic Review Of The Genus Junnanotrechus Uéno & Yin, 1993 (Coleoptera: Carabidae: Trechinae), With Description Of Six New Species
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Coleoptera
# {http://datacite.org/schema/kernel-3}subject
# Carabidae
# {http://datacite.org/schema/kernel-3}subject
# Junnanotrechus
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03ADED456B73FFC7FF06FCF9DD1CA1FB
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03ADED456B64FFE2FF06FCA2DAC7A2DB
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03ADED456B50FFE3FF06FF25DDB5A288
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3811.4.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FF94953D6B71FFC2FF91FFBDD82EA53E
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURES 23 – 26. Male genitalia of Junnanotrechus koroleviellus sp. n.: a—lateral view, b—dorsal view, c—parameres, d—genital segment.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:164760
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:02Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.164760
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Clulow, Simon
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Anstis, Marion
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Keogh, J. Scott
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Catullo, Renee A.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 4 In A New Species Of Australian Frog (Myobatrachidae: Uperoleia) From The New South Wales Mid-North Coast Sandplains
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Chordata
# {http://datacite.org/schema/kernel-3}subject
# Amphibia
# {http://datacite.org/schema/kernel-3}subject
# Anura
# {http://datacite.org/schema/kernel-3}subject
# Myobatrachidae
# {http://datacite.org/schema/kernel-3}subject
# Uperoleia
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/D15DE063FFF7B210FF47F9C9FC815520
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4184.2.3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:2D64981BFFF1B21EFFD0FFDBFFC05208
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/D15DE063FFF7B210FF47F9C9FC815520
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4184.2.3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:2D64981BFFF1B21EFFD0FFDBFFC05208
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 4. Uperoleia mahonyi sp. nov. demonstrating the range of variation in dorsal colour and patterning observed in life. (A) female AMS R 185700, Wyrrabalong National Park NSW, and (B) same specimen in dark phase (photographs S. Clulow); (C) calling male with vocal sac extended, specimen not collected, type locality (photograph S. Mahony); (D) female AMS R 185700 showing groin colour patch, Wyrrabalong National Park NSW (photograph S. Clulow); (E) male and female in amplexus, specimens not collected, type locality (photograph S. Mahony); (F) male, specimen not collected, Norah Head NSW (photograph J. Mulder).
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:185043
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:01Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.185043
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Marin, Ivan
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 25 In Crinoid-Associated Shrimps Of The Genus Laomenes A. H. Clark, 1919 (Caridea: Palaemonidae: Pontoniinae): New Species And Probable Diversity
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2009
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Malacostraca
# {http://datacite.org/schema/kernel-3}subject
# Decapoda
# {http://datacite.org/schema/kernel-3}subject
# Palaemonidae
# {http://datacite.org/schema/kernel-3}subject
# Laomenes
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2009-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03DC87A39559F605F1D42CF6FDB4206C
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.185020
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFE5FFDB9579F623F1432864FFF42206
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Zero - CC0 1.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 25. Laomenes ceratophthalmus (Borradaile, 1915). A, ovigerous female, B, male. Scale 1 mm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:165228
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:09Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.165228
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Arai, Hisao P.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Smith, John W.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 26 In Guide To The Parasites Of Fishes Of Canada Part V: Nematoda
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Nematoda
# {http://datacite.org/schema/kernel-3}subject
# Secernentea
# {http://datacite.org/schema/kernel-3}subject
# Spirurida
# {http://datacite.org/schema/kernel-3}subject
# Anguillicolidae
# {http://datacite.org/schema/kernel-3}subject
# Anguillicola
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/038FB248FF95FF9289B9C4DD228698DA
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4185.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFB6CA30FFB1FFB6892EC613204A9E70
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Zero - CC0 1.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 26. Anguillicola crassus Kuwahara, Niimi &amp; Itagaki, 1974. A. female, buccal capsule; B. male, anterior end; C. female, tail; D. male, tail with five rather than the usual six caudal papillae; E. vulva; F. egg containing 2 nd - stage larva. (Redrawn from Moravec 2013)
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:160751
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:12Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire_data
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-ecfunded
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.160751
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Wierstorf, Hagen
# {http://datacite.org/schema/kernel-3}affiliation
# Technische Universität Ilmenau
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Geier, Matthias
# {http://datacite.org/schema/kernel-3}affiliation
# Universität Rostock
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Binaural Room Impulse Responses Recorded With Kemar In A Small Meeting Room
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# BRIR
# {http://datacite.org/schema/kernel-3}subject
# KEMAR
# {http://datacite.org/schema/kernel-3}subject
# binaural simulatio
# {http://datacite.org/schema/kernel-3}contributors
#
#
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/618075/
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-10-14
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>The binaural room impulse responses (BRIRs) were measured in the small meeting room Spirit at the<br>
# Telefunken-building of TU Berlin. They were measured for three different loudspeaker positions placed around a table. The head of the dummy head was rotated with a resolution of 1° ranging from -90° to 90°. The measurement equipment was the same as described in Wierstorf et al. [1]</p>
#
# <p>[1] Wierstorf, H., Geier, M., Raake, A., Spors, S. (2011) “A Free Database of Head-Related Impulse Response Measurements in the Horizontal Plane with Multiple Distances,” 130th AES Convention, eBrief 6</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252670
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:57Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252670
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Chani-Posse, Mariana
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 11 In An Illustrated Key To The New World Genera Of Philonthina Kirby (Coleoptera: Staphylinidae), With Morphological, Taxonomical And Distributional Notes
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Coleoptera
# {http://datacite.org/schema/kernel-3}subject
# Staphylinidae
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03EF879CFFAFFFBDFF37FA6191A71384
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3755.1.3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:FFD6FFE4FFA3FFB3FFA0FFFA943C1748
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 11. (A – J) Habitus: (A) Atopocentrum mirabile, (B) Belonuchus aluticollis (Bernhauer), (C) Cafius xantholoma, (D) Chroaptomus mexicanus Chani-Posse &amp; Navarrete-Heredia, (E) Delgadobius amazonensis Chani-Posse &amp; Couturier, (F) Ecitophytes coniceps Wasmann, (G) Flohria subcoerulea (LeConte), (H) Gabrius nidicola (Bernhauer), (I) Gabronthus maritimus (Motschulsky), (J), Hesperus fasciatus (Sharp).
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252388
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:01:55Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-icsu_wds
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252388
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Mustapha Mokrane
# {http://datacite.org/schema/kernel-3}affiliation
# ICSU World Data System
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Lesley Rickards
# {http://datacite.org/schema/kernel-3}affiliation
# BODC
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Sandra Harrison
# {http://datacite.org/schema/kernel-3}affiliation
# University of Reading
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Legacy And Future Of The World Data System Certification Of Data Services And Networks
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Trustworthy Data Repositories
# {http://datacite.org/schema/kernel-3}subject
# Data Management
# {http://datacite.org/schema/kernel-3}subject
# Certification
# {http://datacite.org/schema/kernel-3}subject
# World Data System
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-09-12
# {http://datacite.org/schema/kernel-3}resourceType
# Conference paper
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>The World Data System (WDS) was created in October 2008 as an Interdisciplinary Body of the International Council for Science (ICSU), building on the 50+ year legacy of the World Data Centres and Federation of Astronomical and Geophysical data analysis Services established by ICSU to manage data generated from the International Geophysical Year (1957–1958). ICSU-WDS is striving to build worldwide ‘communities of excellence’ for scientific data services by certifying holders and providers of data or data products—and networks of these—from wide-ranging scientific domains using internationally recognized standards. Certification criteria and a procedure for evaluating candidates for membership were developed by the WDS Scientific Committee (WDS-SC) to ensure the trustworthiness of WDS Members in terms of authenticity, integrity, confidentiality, and availability of data and services. Certification is important because it promotes confidence in the usability and persistence of shared data resources. It also helps data services improve their practices and procedures.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:165623
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:15Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.165623
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# S.A. Yatsenko
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Поминально-Погребальные Памятники, Малая Скифия, Сюжеты, Иконография, Региональная Специфика, Религия Иранских Народов / Funeral And Memorial Monuments, Scythia Minor, Subjects, Iconography, Regional Features, Religion Of Iranian-Speaking Peoples
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# поминально-погребальные  памятники,  Малая  Скифия,  сюжеты,  иконография, региональная специфика, религия иранских народов / funeral and memorial monuments, Scythia Minor, subjects, iconography, regional  features, religion of Iranian-speaking peoples
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Journal article
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Рассмотрены изображения на поминально-погребальных памятниках трех районов крымской Малой Скифии I — начала III вв. н. э., выявлено много новых важных деталей. Их иконография и семантика получают объяснение из религиозных доисламских верований иранских и индоиранских народов, преимущественно — алано-осетинской традиции. / The series of depictions on the Funeral and Memorial monuments in three regions of Crimean Scythia Minor in the 1st — early 3rd cc. AD were examined, many new important local details were came to light. Their iconography and semantics may be explained on a religious pre-Islamic believes of Iranian and Indo-Iranian peoples, first of all — on Alanian-Ossetian traditions.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:165112
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.165112
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# L. A. Radomska
# {http://datacite.org/schema/kernel-3}affiliation
# Vinnytsia National Technical University
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Terminological Noun-Juxtapositions With Correlative Relations
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# terminological noun-juxtaposition
# {http://datacite.org/schema/kernel-3}subject
# correlative relations
# {http://datacite.org/schema/kernel-3}subject
# unequal semantic and equal semantic components
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-11-07
# {http://datacite.org/schema/kernel-3}resourceType
# Journal article
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>The aim of the research is to analyze the correlative relations in the structure of terminological nounjuxtapositions.<br>
# Its actuality is connected with the need of complex analysis of the structure and<br>
# semantics of these specific lexical units, clarifying with a wide range of semantic relations between<br>
# their components compared to the relations between the one-word terms. The purpose of the work is<br>
# to find out the specifics of establishment of correlative relations between components terminological<br>
# noun-juxtapositions (TNJ). The achievement of this goal involves the following tasks: 1) to determine<br>
# the size of the concept JUXTAPOSITION; 2) to set types of TNJ by semantic criterion; 3) to<br>
# describe the specific structure and lexical-semantic groups of TNJ with correlative components.<br>
# The status of noun-juxtapositions as independent lexical and grammatical units is motivated<br>
# by such criteria as: constant nomination, semantic integrity, idiomatic lexical meaning, integrity of<br>
# design. It is determined that noun-juxtapositions with correlative relations are formed on the base<br>
# of overlapping semantics of their components: mutual meaning specification (the first component,<br>
# as a second, the second component a first) or complementary of meanings (and the meaning of the<br>
# first component and the meaning of the second component).</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:165647
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T03:55:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.165647
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Felix, Rob P. W. H.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Massa, Bruno
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 19 In Orthoptera (Insecta: Tettigonioidea, Pyrgomorphoidea, Acridoidea) Of Kafa Biosphere Reserve, Bale Mountains National Park And Other Areas Of Conservation Interest In Ethiopia
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Orthoptera
# {http://datacite.org/schema/kernel-3}subject
# Phaneropteridae
# {http://datacite.org/schema/kernel-3}subject
# Peropyrrhicia
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB6DFF9AC4FCFEAEFBDAD08E
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB6CFF86C4FCFADEFCA9D636
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB71FF87C4FCFE39FB4CD473
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB70FF85C4FCFCE7FC91D64E
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB72FF85C4FCFEFCFA6CD19B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB75FF81C4FCF96DFC0FD64F
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/03FD87C1FB7AFF88C4FCF8E1FDE9D1D8
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# ...
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURES 23 – 30. Encarsia huangi sp. nov., holotype ♀: 23, head, frontal view; 24, antenna; 25, mesosoma; 26, fore wing with stigmal vein enlarged; 27, mid tibial spur and tarsi; 28, mesosoma and metasoma; 29, sculpture on petiole; 30, ovipositor. Scale bars = 50 µm.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:190187
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T04:02:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.190187
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Riedel, Alexander
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figures 41 – 43 In Revision Of The Genus Penthoscapha Heller (Coleoptera, Curculionoidea, Entiminae, Eupholini) With Notes On The Genera Of Eupholini From New Guinea
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2009
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Coleoptera
# {http://datacite.org/schema/kernel-3}subject
# Curculionidae
# {http://datacite.org/schema/kernel-3}subject
# Penthoscapha
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2009-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C4FD16A03FD2A25FC7AFC5E
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C48D16A03FD2B8AFA1AF93F
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C5CD17A03FD28F7FC77F899
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.190177
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:741DFF894C4CD16E036A2860FF86FFCE
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C4FD16A03FD2A25FC7AFC5E
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C48D16A03FD2B8AFA1AF93F
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/882487F14C5CD17A03FD28F7FC77F899
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.190177
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:741DFF894C4CD16E036A2860FF86FFCE
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURES 41 – 43. Penthoscapha lorentzi, lectotype: (41) aedeagus, dorsal aspect; (42) aedeagus, lateral aspect; (43) endophallus with transfer apparatus.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:169132
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T04:02:16Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# openaire
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.169132
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Trivedi, Dahryn
# {http://datacite.org/schema/kernel-3}affiliation
# Trivedi Global Inc.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Branton, Alice
# {http://datacite.org/schema/kernel-3}affiliation
# Trivedi Global Inc.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Trivedi, Mahendra Kumar
# {http://datacite.org/schema/kernel-3}affiliation
# Trivedi Global Inc.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Nayak, Gopal
# {http://datacite.org/schema/kernel-3}affiliation
# Trivedi Global Inc.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Use Of Energy Healing Medicine Against Escherichia Coli For Antimicrobial Susceptibility, Biochemical Reaction And Biotyping
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2015
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Escherichia Coli Infections
# {http://datacite.org/schema/kernel-3}subject
# Escherichia Coli Urinary Tract Infections
# {http://datacite.org/schema/kernel-3}subject
# Escherichia Coli Infections in Urine
# {http://datacite.org/schema/kernel-3}subject
# Clinical Isolates of E. Coli
# {http://datacite.org/schema/kernel-3}subject
# Antimicrobial Sensitivity of E. Coli
# {http://datacite.org/schema/kernel-3}subject
# Pathogenic Isolates of E. Coli
# {http://datacite.org/schema/kernel-3}subject
# MDR Isolates of E. Coli
# {http://datacite.org/schema/kernel-3}subject
# Antimicrobial Susceptibility Assay/Test of E. Coli
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2015-11-09
# {http://datacite.org/schema/kernel-3}resourceType
# Journal article
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution Share-Alike 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Escherichia coli (E. coli) infections are the major health concern, as it causes infections in human mainly in urinary tract, ear, and wound infections. The present study evaluates the impact of biofield energy treatment on E. coli regarding antimicrobial sensitivity assay, biochemical study and biotype number. Four multidrug resistant (MDR) clinical lab isolates (LSs) of E. coli (LS 12, LS 13, LS 42, and LS 51) were taken in two groups i.e. control and treated. After treatment, above mentioned parameter were evaluated on day 10 in control and treated samples using MicroScan Walk-Away® system. The antimicrobial sensitivity assay was reported with 46.67% alteration (14 out of 30 tested antimicrobials) in treated group of MDR E. coli isolates. The minimum inhibitory concentration (MIC) study showed the alteration in MIC values of about 34.37% (11 out of 32) tested antimicrobials, after biofield treatment in clinical isolates of E. coli. Piperacillin/tazobactam was reported with improved sensitivity and four-fold decrease in the MIC value (64 to ≤16 μg/mL) in LS 42, as compared with the control. Amoxicillin/kclavulanate reported with improved sensitivity pattern from resistance to susceptible, with two-fold decrease in MIC value (&gt;16/8 to ≤8/4 μg/mL) in biofield treated LS 51. Further, biochemical study showed 24.24% alteration (8 out of 33) in tested biochemical reactions after treatment among four isolates of E. coli as compared to the control. A change in biotype number (7774 4272) was reported as compared to the control, (7311 4012), with new organism identified as Klebsiella pneumoniae in biofield treated LS 13 with respect to the control organism, E. coli. Overall, data suggested that Mr. Trivedi’s biofield energy treatment can be applied to alter the antimicrobial sensitivity, biochemical reactions and biotype number of E. coli.</p>
# {http://datacite.org/schema/kernel-3}description
# Mahendra Kumar Trivedi, Alice Branton, Dahryn Trivedi, Gopal Nayak, Mayank Gangwar, Snehasis Jana. Use of Energy Healing Medicine Against Escherichia coli for Antimicrobial Susceptibility, Biochemical Reaction and Biotyping. American Journal of Bioscience and Bioengineering. Vol. 3, No. 5, 2015, pp. 99-105. doi: 10.11648/j.bio.20150305.23
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:254758
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:04:05Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.254758
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Hamada, N.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Silva, J. O.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Pedroza, M. K.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figures 16 – 21. Enderleina Bifasciata N In A New Species Of Enderleina Jewett (Plecoptera, Perlidae) From Amazonas State, Brazil
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Plecoptera
# {http://datacite.org/schema/kernel-3}subject
# Perlidae
# {http://datacite.org/schema/kernel-3}subject
# Enderleina
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/FF4387CEFFE82775F5CBC21FFEDAFB02
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4098.2.11
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:037AFFB6FFE92772F55CC418FF81FF81
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/FF4387CEFFE82775F5CBC21FFEDAFB02
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4098.2.11
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:037AFFB6FFE92772F55CC418FF81FF81
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURES 16 – 21. Enderleina bifasciata n. sp., male. 16. Abdomen distal region, in ventral view. 17. Abdomen, distal region, in dorsal view. 18. Abdomen distal region, in lateral view. 19. Tergite X, lateral region of posterior margin; arrow indicates the sensilla basiconica. 20. Paraprocts, in postero-lateral view. 21. Paraprocto, lateral view, arrow indicates the subbasal spine.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:251614
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-05-30T05:00:52Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.251614
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Gupta, Ankita
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Fernández-Triana, José L.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 118 In Diversity, Host Association, And Cocoon Variability Of Reared Indian Microgastrinae (Hymenoptera: Braconidae)
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.3800.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:F64ACE0DA870FFEE4178FFA6FFE78148
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 118. Apanteles tachardiae (female, Punjab) — E. Profile view F. Fore wing G. Metasoma in lateral view.
# {http://www.openarchives.org/OAI/2.0/}resumptionToken
# .eJyFj7FugzAURf_Fa0llGwMFKVsh6oBTkIGWJXKMgygGInBERZR_rxMlU4dIT2-497wjvTOYpKxAAF8x8R3fIdAhvucTRFwLTGIclNo1pgfiK1eiVxnf5Ke0y-E3rj36PmH6ExLKPtx9phbeR0lcqKyCvqFLmxb0WG7e5oRNy5aFMGahG18zFqX7FqWspai0SzspsjmPhK6Why9-5rtzyTNu3s7rNbDAkdcSBNgC7czHegLBGRzGoTOPYYi8FURmGITBbV5u21x1UvOKa_45ykPza-CBN7trIBotTX_qdaMeDoRX9j_H5fIHcqZrrg.DRPLKQ.Y1NjeD6IMUL0R7p429fFEneZ39A

# %% [markdown]
# ### GetRecord
#
# This verb is used to retrieve an individual metadata record from a repository. Required arguments specify the identifier of the item from which the record is requested and the format of the metadata that should be included in the record. Depending on the level at which a repository tracks deletions, a header with a "deleted" value for the status attribute may be returned, in case the metadata format specified by the metadataPrefix is no longer available from the repository or from the specified item.
#
# Obtener objeto digital de ese recurso

# %%
import xml.etree.ElementTree as ET
import urllib
#https://zenodo.org/oai2d?verb=GetRecord&metadataPrefix=oai_dc&identifier=oai:zenodo.org:252670
oai = requests.get('https://zenodo.org/oai2d?verb=GetRecord&metadataPrefix=oai_datacite&identifier=oai:zenodo.org:252977')
xmlTree = ET.ElementTree(ET.fromstring(oai.text))
iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag)
    print(elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH
#
#
# {http://www.openarchives.org/OAI/2.0/}responseDate
# 2017-12-14T08:59:39Z
# {http://www.openarchives.org/OAI/2.0/}request
# https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}GetRecord
#
#
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:252977
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-08T08:01:40Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.252977
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Harzhauser, Mathias
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Landau, Bernard
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Figure 13 A 1 – A 5 In A Revision Of The Neogene Conidae And Conorbidae (Gastropoda) Of The Paratethys Sea
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Kalloconus
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}alternateIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}alternateIdentifier
# https://zenodo.org/record/oai:zenodo.org:252977
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDCFFCDFF5FA9D9FC3046B3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFCAFF5FA8E1FA0B4762
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFC8FF5FAE2DFDC5443D
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4210.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:CB06FFAFFF9FFF8EFFC8A876FF89416A
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDCFFCDFF5FA9D9FC3046B3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFCAFF5FA8E1FA0B4762
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/373F87D7FFDBFFC8FF5FAE2DFDC5443D
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4210.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:CB06FFAFFF9FFF8EFFC8A876FF89416A
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 13 A 1 – A 5. Kalloconus ponderovagus (Sacco, 1893), Niederkreuzstetten (Austria), NHMW 1849 / 0004 / 0016, holotype. 13 B 1 – B 3. Niederkreuzstetten (Austria), NHMW A 991. 13 C 1 – C 4. Kalloconus pseudohungaricus nov. sp., Lăpugiu de Sus (Romania), NHMW 1868 / 0001 / 0380 a, paratype. 13 D. Lăpugiu de Sus (Romania), Kalloconus pseudohungaricus nov. sp., NHMW 1868 / 0001 / 0380 d, paratype. 13 E 1 – E 3. Kalloconus pseudohungaricus nov. sp., Lăpugiu de Sus (Romania), NHMW 1868 / 0001 / 0380 b, holotype. 13 F 1 – F 2. Lăpugiu de Sus (Romania), Kalloconus pseudohungaricus nov. sp., NHMW 1868 / 0001 / 0380 c, paratype. 13 G 1 – G 5. Kalloconus tietzei (Hoernes &amp; Auinger, 1879), NHMW 1847 / 0046 / 0004, Szob (Hungary), holotype.

# %%
import xml.etree.ElementTree as ET
#https://zenodo.org/oai2d?verb=GetRecord&metadataPrefix=oai_dc&identifier=oai:zenodo.org:252670
headers = {'Accept': 'application/rdf+xml;q=0.5'} #Type of response accpeted
r = requests.post('https://dx.doi.org/10.5281/zenodo.252363', headers=headers) #POST with headers
print(r.text)
# Out:
# <?xml version='1.0' encoding='utf-8' ?>
# <rdf:RDF xmlns:rdf='http://www.w3.org/1999/02/22-rdf-syntax-ns#' xmlns:schema='http://schema.org/'>
# <rdf:Description rdf:about='http://treatment.plazi.org/id/03F926428F14B14F30BBFB1A56F23C5B'>
# <schema:citation>
# <schema:ImageObject rdf:about='https://doi.org/10.5281/zenodo.252363'>
# <schema:author>
# <schema:Person rdf:nodeID='b2'>
# <schema:familyName>Sääksjärvi</schema:familyName>
#
# <schema:givenName>Ilari E.</schema:givenName>
#
# <schema:name>Ilari E. Sääksjärvi</schema:name>
#
# </schema:Person>
#
# </schema:author>
#  <schema:author>
# <schema:Person rdf:nodeID='b0'>
# <schema:familyName>Veijalainen</schema:familyName>
#
# <schema:givenName>Anu</schema:givenName>
#
# <schema:name>Anu Veijalainen</schema:name>
#
# </schema:Person>
#
# </schema:author>
#  <schema:author>
# <schema:Person rdf:nodeID='b1'>
# <schema:familyName>Broad</schema:familyName>
#
# <schema:givenName>Gavin R.</schema:givenName>
#
# <schema:name>Gavin R. Broad</schema:name>
#
# </schema:Person>
#
# </schema:author>
#
# <schema:datePublished rdf:datatype='http://schema.org/Date'>2014-12-31</schema:datePublished>
#
# <schema:description>FIGURE 1. Lateral views: Orthocentrus shieldsi species-group (in part). A: anguillae, B: pentagonum, C: concrispus, D: hispidus, E: quercus, F: shieldsi. Scale 0.5 mm.</schema:description>
#
# <schema:isPartOf>
# <schema:CreativeWork rdf:about='https://doi.org/10.11646/zootaxa.3768.3.1'>
# </schema:CreativeWork>
#
# </schema:isPartOf>
#
# <schema:keywords>Biodiversity, Taxonomy, Animalia, Arthropoda, Insecta, Hymenoptera, Ichneumonidae, Orthocentrus</schema:keywords>
#
# <schema:name>Figure 1 In Twenty Seven New Species Of Orthocentrus (Hymenoptera: Ichneumonidae; Orthocentrinae) With A Key To The Neotropical Species Of The Genus</schema:name>
#
# <schema:provider>
# <schema:Organization rdf:nodeID='b4'>
# <schema:name>DataCite</schema:name>
#
# </schema:Organization>
#
# </schema:provider>
#
# <schema:publisher>
# <schema:Organization rdf:nodeID='b3'>
# <schema:name>Zenodo</schema:name>
#
# </schema:Organization>
#
# </schema:publisher>
#
# <schema:schemaVersion rdf:resource='http://datacite.org/schema/kernel-3' />
#
# </schema:ImageObject>
#
# </schema:citation>
#
# </rdf:Description>
#
# <rdf:Description rdf:about='http://treatment.plazi.org/id/03F926428F15B14C30BBFA8F57663DFF'>
# <schema:citation rdf:resource='https://doi.org/10.5281/zenodo.252363' />
#
# </rdf:Description>
#
# <rdf:Description rdf:about='http://treatment.plazi.org/id/03F926428F16B14D30BBFB2C54D53D07'>
# <schema:citation rdf:resource='https://doi.org/10.5281/zenodo.252363' />
#
# </rdf:Description>
#
# <rdf:Description rdf:about='http://treatment.plazi.org/id/03F926428F19B14030BBFDC25468381F'>
# <schema:citation rdf:resource='https://doi.org/10.5281/zenodo.252363' />
#
# </rdf:Description>
#
# <rdf:Description rdf:about='http://treatment.plazi.org/id/03F926428F1AB14130BBFE4C543C3BAF'>
# <schema:citation rdf:resource='https://doi.org/10.5281/zenodo.252363' />
#
# </rdf:Description>
#
# <rdf:Description rdf:about='http://treatment.plazi.org/id/03F926428F1BB14E30BBFC9C54B13D22'>
# <schema:citation rdf:resource='https://doi.org/10.5281/zenodo.252363' />
#
# </rdf:Description>
#
# </rdf:RDF>

# %% [markdown]
# # Ejercicio

# %% [markdown]
# * 1: Busca al menos dos repositorios digitales compatibles con OAI-PMH
# * 2: Utiliza los verbos del protocolo para encontrar los recursos de un tema en concreto (puedes buscar en la descripción o en las palabras clave.
# * 4: Obtén un listado de los títulos, identificadores (DOI o cualquier otro) y la dirección del recurso.
# * 5: ¿Qué problemas has encontrado? ¿Has tenido que manejar más de un formato de metadatos? ¿Qué limitaciones tiene el protocolo OAI-PMH? ¿Cómo lo mejorarías?
