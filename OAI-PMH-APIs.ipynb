# %% [markdown]
# # OAI-PMH
#
# Alumno: **Fernando Solar Iglesias**
#
# La documentación del protocolo la podéis encontrar aquí:
#
# https://www.openarchives.org/OAI/openarchivesprotocol.html
#
# ### Librerías necesarias para la práctica
#
# ```python
# import xml.etree.ElementTree as ET
# import requests
# import json
# ```

# %%
import xml.etree.ElementTree as ET
import requests
import json

# %% [markdown]
# ### Identify
#
# This verb is used to retrieve information about a repository. Some of the information returned is required as part of the OAI-PMH. Repositories may also employ the Identify verb to return additional descriptive information.

# %%
import xml.etree.ElementTree as ET
import requests

oai = requests.get('https://zenodo.org/oai2d?verb=Identify') #Peticion al servidor

#Para crear el arbol XML
xmlTree = ET.fromstring(oai.text)
print(oai.text)
#Iterator para recorrer todos los elementos (incluso anidados)
iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag+": "+elem.text)

#Findall para encontrar un elemento específico
namespaces = {'ns': 'http://www.openarchives.org/OAI/2.0/'} # add more as needed
elementos = xmlTree.findall('.//ns:baseURL',namespaces)
print(elementos) #Element
for e in elementos:
    print("BaseURL:", e.text)
# Out:
# <?xml version='1.0' encoding='UTF-8'?>
# <?xml-stylesheet type="text/xsl" href="/static/xsl/oai2.xsl"?>
# <OAI-PMH xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/ http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd">
#   <responseDate>2020-01-05T22:45:44Z</responseDate>
#   <request verb="Identify">https://zenodo.org/oai2d</request>
#   <Identify>
#     <repositoryName>Zenodo</repositoryName>
#     <baseURL>https://zenodo.org/oai2d</baseURL>
#     <protocolVersion>2.0</protocolVersion>
#     <adminEmail>info@zenodo.org</adminEmail>
#     <earliestDatestamp>2014-02-03T14:41:33Z</earliestDatestamp>
#     <deletedRecord>no</deletedRecord>
#     <granularity>YYYY-MM-DDThh:mm:ssZ</granularity>
#   </Identify>
# </OAI-PMH>
#
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH:
#
# {http://www.openarchives.org/OAI/2.0/}responseDate: 2020-01-05T22:45:44Z
# {http://www.openarchives.org/OAI/2.0/}request: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}Identify:
#
# {http://www.openarchives.org/OAI/2.0/}repositoryName: Zenodo
# {http://www.openarchives.org/OAI/2.0/}baseURL: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}protocolVersion: 2.0
# {http://www.openarchives.org/OAI/2.0/}adminEmail: info@zenodo.org
# {http://www.openarchives.org/OAI/2.0/}earliestDatestamp: 2014-02-03T14:41:33Z
# {http://www.openarchives.org/OAI/2.0/}deletedRecord: no
# {http://www.openarchives.org/OAI/2.0/}granularity: YYYY-MM-DDThh:mm:ssZ
# [<Element '{http://www.openarchives.org/OAI/2.0/}baseURL' at 0x7f019ef4d7c8>]
# BaseURL: https://zenodo.org/oai2d

# %% [markdown]
# ### Listar tipos de metadatos
#
# ListMetadataFormats
#
# This verb is used to retrieve the metadata formats available from a repository. An optional argument restricts the request to the formats available for a specific item.

# %%
import xml.etree.ElementTree as ET
import requests

oai = requests.get('https://zenodo.org/oai2d?verb=ListMetadataFormats') #Peticion al servidor

#Para crear el arbol XML
xmlTree = ET.fromstring(oai.text)

iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag+": "+elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH:
#
# {http://www.openarchives.org/OAI/2.0/}responseDate: 2020-01-05T22:45:45Z
# {http://www.openarchives.org/OAI/2.0/}request: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListMetadataFormats:
#
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marcxml
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://www.loc.gov/MARC21/slim
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite4
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-4
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_dc
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.openarchives.org/OAI/2.0/oai_dc.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://www.openarchives.org/OAI/2.0/oai_dc/
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: dcat
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: https://www.w3.org/ns/dcat
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-3
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marc21
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://www.loc.gov/MARC21/slim
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-4
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-3
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite4
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-4
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-3

# %% [markdown]
# Podemos capturar sólo la información relevante

# %%
iterator = xmlTree.iter()
for elem in iterator:
    if (elem.tag == '{http://www.openarchives.org/OAI/2.0/}metadataPrefix') or (elem.tag == '{http://www.openarchives.org/OAI/2.0/}schema'):
        print(elem.tag+": "+elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marcxml
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite4
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_dc
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.openarchives.org/OAI/2.0/oai_dc.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: dcat
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marc21
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite4
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd

# %% [markdown]
# O de forma más "elegante"

# %%
for e in xmlTree.findall('.//{http://www.openarchives.org/OAI/2.0/}metadataFormat'):
    metadataPrefix = e.find('{http://www.openarchives.org/OAI/2.0/}metadataPrefix').text
    schema = e.find('{http://www.openarchives.org/OAI/2.0/}schema').text
    print(metadataPrefix, ':', schema)
# Out:
# marcxml : http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# oai_datacite4 : http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# oai_dc : http://www.openarchives.org/OAI/2.0/oai_dc.xsd
# dcat : http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# oai_datacite : http://schema.datacite.org/meta/kernel-3/metadata.xsd
# marc21 : http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# datacite : http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# datacite3 : http://schema.datacite.org/meta/kernel-3/metadata.xsd
# datacite4 : http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# oai_datacite3 : http://schema.datacite.org/meta/kernel-3/metadata.xsd

# %% [markdown]
# Podemos describir el último schema

# %%
oai_datacite = requests.get('http://schema.datacite.org/meta/kernel-3/metadata.xsd') #Peticion al servidor
print(oai_datacite.text)

#Para crear el arbol XML
xmlTree = ET.fromstring(oai_datacite.text)

iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <!-- Revision history
#      2010-08-26   Complete revision according to new common specification by the metadata work group after review. AJH, DTIC
# 	 2010-11-17 Revised to current state of kernel review, FZ, TIB
# 	 2011-01-17 Complete revsion after community review. FZ, TIB
# 	 2011-03-17 Release of v2.1: added a namespace; mandatory properties got minLength; changes in the definitions of relationTypes
# 	 IsDocumentedBy/Documents and isCompiledBy/Compiles; changes type of property "Date" from xs:date to xs:string. FZ, TIB
# 	 2011-06-27 v2.2: namespace: kernel-2.2, additions to controlled lists "resourceType", "contributorType", "relatedIdentifierType", and "descriptionType". Removal of intermediate include-files.
#      2013-05 v3.0: namespace: kernel-3.0; delete LastMetadataUpdate & MetadateVersionNumber; additions to controlled lists "contributorType", "dateType", "descriptionType", "relationType", "relatedIdentifierType" & "resourceType"; deletion of "StartDate" & "EndDate" from list "dateType" and "Film" from "resourceType";  allow arbitrary order of elements; allow optional wrapper elements to be empty; include xml:lang attribute for title, subject & description; include attribute schemeURI for nameIdentifier of creator, contributor & subject; added new attributes "relatedMetadataScheme", "schemeURI" & "schemeType" to relatedIdentifier; included new property "geoLocation"
# 	 2014-08-20 v3.1: additions to controlled lists "relationType", contributorType" and "relatedIdentifierType"; introduction of new child element "affiliation" to "creator" and "contributor"-->
# <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns="http://datacite.org/schema/kernel-3" targetNamespace="http://datacite.org/schema/kernel-3" elementFormDefault="qualified" xml:lang="EN">
# 	<xs:import namespace="http://www.w3.org/XML/1998/namespace" schemaLocation="http://www.w3.org/2009/01/xml.xsd"/>
# 	<xs:include schemaLocation="include/datacite-titleType-v3.xsd"/>
# 	<xs:include schemaLocation="include/datacite-contributorType-v3.1.xsd"/>
# 	<xs:include schemaLocation="include/datacite-dateType-v3.xsd"/>
# 	<xs:include schemaLocation="include/datacite-resourceType-v3.xsd"/>
# 	<xs:include schemaLocation="include/datacite-relationType-v3.1.xsd"/>
# 	<xs:include schemaLocation="include/datacite-relatedIdentifierType-v3.1.xsd"/>
# 	<xs:include schemaLocation="include/datacite-descriptionType-v3.xsd"/>
# 	<xs:element name="resource">
# 		<xs:annotation>
# 			<xs:documentation>
# 	Root element of a single record. This wrapper element is for XML implementation only and is not defined in the DataCite DOI standard.
#         Note: This is the case for all wrapper elements within this schema!</xs:documentation>
# 			<xs:documentation>No content in this wrapper element.</xs:documentation>
# 		</xs:annotation>
# 		<xs:complexType>
# 			<xs:all>
# 				<!--REQUIRED FIELDS-->
# 				<xs:element name="identifier">
# 					<xs:annotation>
# 						<xs:documentation>A persistent identifier that identifies a resource.</xs:documentation>
# 						<xs:documentation>Currently, only DOI is allowed.</xs:documentation>
# 					</xs:annotation>
# 					<xs:complexType>
# 						<xs:simpleContent>
# 							<xs:extension base="doiType">
# 								<xs:attribute name="identifierType" use="required" fixed="DOI"/>
# 							</xs:extension>
# 						</xs:simpleContent>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="creators">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="creator" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>The main researchers involved working on the data, or the authors of the publication in priority order. May be a corporate/institutional or personal name.</xs:documentation>
# 									<xs:documentation>Format: Family, Given.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:sequence>
# 										<xs:element name="creatorName">
# 											<xs:simpleType>
# 												<xs:restriction base="nonemptycontentStringType"/>
# 											</xs:simpleType>
# 										</xs:element>
# 										<xs:element name="nameIdentifier" minOccurs="0">
# 											<xs:complexType>
# 												<xs:simpleContent>
# 													<xs:extension base="nonemptycontentStringType">
# 														<xs:attribute name="nameIdentifierScheme" use="required"/>
# 														<xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
# 													</xs:extension>
# 												</xs:simpleContent>
# 											</xs:complexType>
# 										</xs:element>
# 										<xs:element name="affiliation" minOccurs="0" maxOccurs="unbounded"/>
# 									</xs:sequence>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="titles">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="title" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>A name or title by which a resource is known.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="nonemptycontentStringType">
# 											<xs:attribute name="titleType" type="titleType" use="optional"/>
# 											<xs:attribute ref="xml:lang"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="publisher">
# 					<xs:annotation>
# 						<xs:documentation>The name of the entity that holds, archives, publishes prints, distributes, releases, issues, or produces the resource. This property will be used to formulate the citation, so consider the prominence of the role.</xs:documentation>
# 						<xs:documentation>In the case of datasets, "publish" is understood to mean making the data available to the community of researchers.</xs:documentation>
# 					</xs:annotation>
# 					<xs:simpleType>
# 						<xs:restriction base="nonemptycontentStringType"/>
# 					</xs:simpleType>
# 				</xs:element>
# 				<xs:element name="publicationYear">
# 					<xs:annotation>
# 						<xs:documentation>Year when the data is made publicly available. If an embargo period has been in effect, use the date when the embargo period ends.</xs:documentation>
# 						<xs:documentation>In the case of datasets, "publish" is understood to mean making the data available on a specific date to the community of researchers. If there is no standard publication year value, use the date that would be preferred from a citation perspective.</xs:documentation>
# 						<xs:documentation>YYYY</xs:documentation>
# 					</xs:annotation>
# 					<xs:simpleType>
# 						<xs:restriction base="yearType"/>
# 					</xs:simpleType>
# 				</xs:element>
# 				<!--OPTIONAL FIELDS-->
# 				<xs:element name="subjects" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="subject" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Subject, keywords, classification codes, or key phrases describing the resource.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="subjectScheme" use="optional"/>
# 											<xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
# 											<xs:attribute ref="xml:lang"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="contributors" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="contributor" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>The institution or person responsible for collecting, creating, or otherwise contributing to the developement of the dataset.</xs:documentation>
# 									<xs:documentation>The personal name format should be: Family, Given.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:sequence>
# 										<xs:element name="contributorName">
# 											<xs:simpleType>
# 												<xs:restriction base="xs:string">
# 													<xs:minLength value="1"/>
# 												</xs:restriction>
# 											</xs:simpleType>
# 										</xs:element>
# 										<xs:element name="nameIdentifier" minOccurs="0">
# 											<xs:complexType>
# 												<xs:simpleContent>
# 													<xs:extension base="xs:string">
# 														<xs:attribute name="nameIdentifierScheme" use="required"/>
# 														<xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
# 													</xs:extension>
# 												</xs:simpleContent>
# 											</xs:complexType>
# 										</xs:element>
# 										<xs:element name="affiliation" minOccurs="0" maxOccurs="unbounded"/>
# 									</xs:sequence>
# 									<xs:attribute name="contributorType" type="contributorType" use="required"/>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="dates" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="date" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Different dates relevant to the work.</xs:documentation>
# 									<xs:documentation>YYYY,YYYY-MM-DD, YYYY-MM-DDThh:mm:ssTZD or any other format or level of granularity described in W3CDTF. Use RKMS-ISO8601 standard for depicting date ranges.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="dateType" type="dateType" use="required"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="language" type="xs:language" minOccurs="0">
# 					<xs:annotation>
# 						<xs:documentation>Primary language of the resource. Allowed values are taken from  IETF BCP 47, ISO 639-1 language codes.</xs:documentation>
# 					</xs:annotation>
# 				</xs:element>
# 				<xs:element name="resourceType" minOccurs="0">
# 					<xs:annotation>
# 						<xs:documentation>The type of a resource. You may enter an additional free text description.</xs:documentation>
# 						<xs:documentation>The format is open, but the preferred format is a single term of some detail so that a pair can be formed with the sub-property.</xs:documentation>
# 					</xs:annotation>
# 					<xs:complexType>
# 						<xs:simpleContent>
# 							<xs:extension base="xs:string">
# 								<xs:attribute name="resourceTypeGeneral" type="resourceType" use="required"/>
# 							</xs:extension>
# 						</xs:simpleContent>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="alternateIdentifiers" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="alternateIdentifier" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>An identifier or identifiers other than the primary Identifier applied to the resource being registered. This may be any alphanumeric string which is unique within its domain of issue. May be used for local identifiers. AlternateIdentifier should be used for another identifier of the same instance (same location, same file).</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="alternateIdentifierType" use="required"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="relatedIdentifiers" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="relatedIdentifier" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Identifiers of related resources. Use this property to indicate subsets of properties, as appropriate.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="relatedIdentifierType" type="relatedIdentifierType" use="required"/>
# 											<xs:attribute name="relationType" type="relationType" use="required"/>
# 											<xs:attribute name="relatedMetadataScheme" use="optional"/>
# 											<xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
# 											<xs:attribute name="schemeType" use="optional"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="sizes" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="size" type="xs:string" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Unstructures size information about the resource.</xs:documentation>
# 								</xs:annotation>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="formats" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="format" type="xs:string" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Technical format of the resource.</xs:documentation>
# 									<xs:documentation>Use file extension or MIME type where possible.</xs:documentation>
# 								</xs:annotation>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="version" type="xs:string" minOccurs="0">
# 					<xs:annotation>
# 						<xs:documentation>Version number of the resource. If the primary resource has changed the version number increases.</xs:documentation>
# 						<xs:documentation>Register a new identifier for a major version change. Individual stewards need to determine which are major vs. minor versions. May be used in conjunction with properties 11 and 12 (AlternateIdentifier and RelatedIdentifier) to indicate various information updates. May be used in conjunction with property 17 (Description) to indicate the nature and file/record range of version.</xs:documentation>
# 					</xs:annotation>
# 				</xs:element>
# 				<xs:element name="rightsList" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="rights" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Any rights information for this resource. Provide a rights management statement for the resource or reference a service providing such information. Include embargo information if applicable.
# Use the complete title of a license and include version information if applicable.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="rightsURI" type="xs:anyURI" use="optional"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="descriptions" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="description" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>All additional information that does not fit in any of the other categories. May be used for technical information. It is a best practice to supply a description.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType mixed="true">
# 									<xs:choice>
# 										<xs:element name="br" minOccurs="0" maxOccurs="unbounded">
# 											<xs:simpleType>
# 												<xs:restriction base="xs:string">
# 													<xs:length value="0"/>
# 												</xs:restriction>
# 											</xs:simpleType>
# 										</xs:element>
# 									</xs:choice>
# 									<xs:attribute name="descriptionType" type="descriptionType" use="required"/>
# 									<xs:attribute ref="xml:lang"/>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="geoLocations" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="geoLocation" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Spatial region or named place where the data was gathered or about which the data is focused.</xs:documentation>
# 									<xs:documentation>A point contains a single latitude-longitude pair, separated by whitespace.</xs:documentation>
# 									<xs:documentation>A box contains two white space separated latitude-longitude pairs, with each pair separated by whitespace. The first pair is the lower corner, the second is the upper corner.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:sequence>
# 										<xs:element name="geoLocationPoint" type="point" minOccurs="0"/>
# 										<xs:element name="geoLocationBox" type="box" minOccurs="0"/>
# 										<xs:element name="geoLocationPlace" minOccurs="0"/>
# 									</xs:sequence>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 			</xs:all>
# 		</xs:complexType>
# 	</xs:element>
# 	<!-- TYPE DECLARATIONS -->
# 	<!-- defines the value for a DOI: DOI must start with "10."  -->
# 	<xs:simpleType name="doiType">
# 		<xs:restriction base="xs:token">
# 			<xs:pattern value="10\..+/.+"/>
# 		</xs:restriction>
# 	</xs:simpleType>
# 	<!-- defines value for mandatory fields -->
# 	<xs:simpleType name="nonemptycontentStringType">
# 		<xs:restriction base="xs:string">
# 			<xs:minLength value="1"/>
# 		</xs:restriction>
# 	</xs:simpleType>
# 	<xs:attributeGroup name="nameId">
# 		<xs:attribute name="nameIdentifier" type="xs:string" use="optional"/>
# 		<xs:attribute name="nameIdentifierScheme" type="xs:string" use="optional"/>
# 	</xs:attributeGroup>
# 	<!-- defines the value for a year -->
# 	<xs:simpleType name="yearType">
# 		<xs:restriction base="xs:token">
# 			<xs:pattern value="[\d]{4}"/>
# 		</xs:restriction>
# 		<!-- definitions for geoLocation -->
# 	</xs:simpleType>
# 	<xs:simpleType name="point">
# 		<xs:restriction base="listOfDoubles">
# 			<xs:minLength value="2"/>
# 			<xs:maxLength value="2"/>
# 		</xs:restriction>
# 	</xs:simpleType>
# 	<xs:simpleType name="box">
# 		<xs:restriction base="listOfDoubles">
# 			<xs:minLength value="4"/>
# 			<xs:maxLength value="4"/>
# 		</xs:restriction>
# 	</xs:simpleType>
# 	<xs:simpleType name="listOfDoubles">
# 		<xs:list itemType="xs:double"/>
# 	</xs:simpleType>
# </xs:schema>
#
# {http://www.w3.org/2001/XMLSchema}schema
# {http://www.w3.org/2001/XMLSchema}import
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}all
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minLength
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}choice
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}length
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}pattern
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minLength
# {http://www.w3.org/2001/XMLSchema}attributeGroup
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}pattern
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minLength
# {http://www.w3.org/2001/XMLSchema}maxLength
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minLength
# {http://www.w3.org/2001/XMLSchema}maxLength
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}list

# %% [markdown]
# Si analizamos la descripción del estándar, vemos que las etiquetas de los metadatos están almacenados en la etiqueta "element", en el atributo "name". Podemos obetener un listado de lo que esperamos encontrar

# %%
namespaces = {'xs' : 'http://www.w3.org/2001/XMLSchema'}
for tags in xmlTree.findall('.//xs:element',namespaces):
    print ('Metadato: ',tags.attrib['name'])
# Out:
# Metadato:  resource
# Metadato:  identifier
# Metadato:  creators
# Metadato:  creator
# Metadato:  creatorName
# Metadato:  nameIdentifier
# Metadato:  affiliation
# Metadato:  titles
# Metadato:  title
# Metadato:  publisher
# Metadato:  publicationYear
# Metadato:  subjects
# Metadato:  subject
# Metadato:  contributors
# Metadato:  contributor
# Metadato:  contributorName
# Metadato:  nameIdentifier
# Metadato:  affiliation
# Metadato:  dates
# Metadato:  date
# Metadato:  language
# Metadato:  resourceType
# Metadato:  alternateIdentifiers
# Metadato:  alternateIdentifier
# Metadato:  relatedIdentifiers
# Metadato:  relatedIdentifier
# Metadato:  sizes
# Metadato:  size
# Metadato:  formats
# Metadato:  format
# Metadato:  version
# Metadato:  rightsList
# Metadato:  rights
# Metadato:  descriptions
# Metadato:  description
# Metadato:  br
# Metadato:  geoLocations
# Metadato:  geoLocation
# Metadato:  geoLocationPoint
# Metadato:  geoLocationBox
# Metadato:  geoLocationPlace

# %% [markdown]
# ### ListIdentifiers
#
# This verb is an abbreviated form of ListRecords, retrieving only headers rather than records. Optional arguments permit selective harvesting of headers based on set membership and/or datestamp. Depending on the repository's support for deletions, a returned header may have a status attribute of "deleted" if a record matching the arguments specified in the request has been deleted.
#
# Devuelve la cabecera de los registros, para conocer la información esencial.
#
# Necesita el prefijo del formato de metadatos

# %%
#prefijo: oai_datacite
oai = requests.get('https://zenodo.org/oai2d?verb=ListIdentifiers&metadataPrefix=oai_datacite')
xmlTree = ET.fromstring(oai.text)

iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag+": "+elem.text) #Identifiers are really important because they are used to ask more information
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH:
#
# {http://www.openarchives.org/OAI/2.0/}responseDate: 2020-01-05T22:45:45Z
# {http://www.openarchives.org/OAI/2.0/}request: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListIdentifiers:
#
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3367294
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T15:29:35Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523810
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:38:59Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523800
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:38:35Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523790
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:38:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523788
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:38:06Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523784
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:37:55Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523782
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:37:51Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523780
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:37:46Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523778
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:37:42Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523776
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:37:37Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523770
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:37:18Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523768
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:37:13Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523766
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:37:07Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523764
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:37:02Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523762
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:36:56Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523760
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:36:52Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523758
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:36:46Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523756
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:36:40Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523754
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:36:35Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523752
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:36:30Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523750
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:36:26Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523748
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:36:21Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523746
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:36:16Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523742
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:36:06Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523740
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:36:01Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523738
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:35:56Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523736
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:35:51Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523734
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:35:46Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523732
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:35:41Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523730
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:35:36Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523728
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:35:31Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523726
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:35:26Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523724
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:35:21Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523722
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:35:15Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523720
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:35:10Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523718
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:35:06Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523710
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:34:44Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523708
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:34:39Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523706
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:34:34Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523692
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:33:57Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523690
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:33:52Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523688
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:33:46Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523682
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:33:30Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523680
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:33:25Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523678
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:33:20Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523676
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:33:15Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523674
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:33:11Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523672
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:33:06Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523668
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:32:56Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523666
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:32:51Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523664
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:32:47Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523660
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:32:37Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523656
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:32:27Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523654
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:32:22Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523646
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:32:01Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523638
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:31:40Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523636
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:31:35Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523634
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:31:30Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523632
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:31:26Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523628
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:31:15Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523626
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:31:10Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523624
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:31:05Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523622
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:31:00Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523620
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:30:55Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523618
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:30:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523616
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:30:44Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523614
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:30:39Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523612
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:30:33Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523610
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:30:28Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523608
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-31T05:30:23Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523044
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T14:37:38Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3523040
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T14:37:29Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522545
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:31:50Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522539
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:31:37Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522535
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:31:28Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522533
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:31:23Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522529
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:31:13Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522527
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:31:08Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522525
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:31:04Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522523
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:30:59Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522521
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:30:54Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522519
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:30:50Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522517
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:30:45Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522515
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:30:40Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522513
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:30:35Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522511
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:30:31Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522509
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:30:26Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522507
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:30:22Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522505
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:30:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3522503
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-30T05:30:13Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3520992
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-28T22:27:19Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3520990
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-28T22:27:13Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3520898
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-28T22:23:04Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3520894
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-28T22:22:55Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3520789
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-29T16:44:07Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3520762
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-28T16:17:13Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3520191
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-28T00:39:17Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3520183
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-27T23:15:36Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3519944
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-27T03:30:58Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3519468
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-10-26T21:48:23Z
# {http://www.openarchives.org/OAI/2.0/}resumptionToken: .eJwdjcsKgzAURP_lrqUkWosKLhRRKEhris-NRE01qFhMoEXx35t2NgNn4MwOgrEOHHTS8fmCbGRZumFbhioNRLsu01RztUNQhLgqrmaSmyOZM1Tqve_9g2NPiryJho2EU1rmA3lk3a1BlUmwH8XzuKWJ64IGL9ozcJR3fNO1F-DsMDNJOyrpfWVP_lE3C-X1D7RcMjiOL5GPMbA.XhJnGQ.ks_1hNXhXWaksE34aPoWCGTtjts

# %% [markdown]
# ### ListRecords
#
# Listar los registros
#
# This verb is used to harvest records from a repository. Optional arguments permit selective harvesting of records based on set membership and/or datestamp. Depending on the repository's support for deletions, a returned header may have a status attribute of "deleted" if a record matching the arguments specified in the request has been deleted. No metadata will be present for records with deleted status.

# %%
import xml.etree.ElementTree as ET
import requests

oai = requests.get('https://zenodo.org/oai2d?verb=ListRecords&metadataPrefix=oai_datacite')
xmlTree = ET.fromstring(oai.text)
iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag)
    print(elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH
#
#
# {http://www.openarchives.org/OAI/2.0/}responseDate
# 2020-01-05T22:45:46Z
# {http://www.openarchives.org/OAI/2.0/}request
# https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListRecords
#
#
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3234674
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.3234674
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Falko Hegerfeld
# {http://datacite.org/schema/kernel-3}affiliation
# Humboldt-Universität zu Berlin
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Florian Nelles
# {http://datacite.org/schema/kernel-3}affiliation
# Humboldt-Universität zu Berlin
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# hubhegnel/pace-2019: Release for zenodo
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# vertex cover
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-05-29
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/hubhegnel/pace-2019/tree/z1.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.3234673
# {http://datacite.org/schema/kernel-3}version
# z1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Submission for PACE 2019 Track 1a Vertex Cover Exact.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3234141
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.3234141
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Jorrit Poelen
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# beraute
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# beraute/Klamath-mountains: Klamath mountains eDNA interactions
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-05-28
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/beraute/Klamath-mountains/tree/v1.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.3234140
# {http://datacite.org/schema/kernel-3}version
# v1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>A table of organism interactions found in eDNA samples collected in the Klamath mountains in the summer of 2018.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3229933
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.3229933
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Marissa Lee
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# marissalee/MetaInvN: publication metadata
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-05-27
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/marissalee/MetaInvN/tree/v1.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.3229932
# {http://datacite.org/schema/kernel-3}version
# v1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# Invasive species' leaf traits and dissimilarity from natives shape their impact on nitrogen cycling: a meta-analysis
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3229408
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.3229408
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Etherington, T. R.
# {http://datacite.org/schema/kernel-3}nameIdentifier
# 0000-0002-3187-075X
# {http://datacite.org/schema/kernel-3}affiliation
# Manaaki Whenua - Landcare Research
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# [Re] Resampling methods for evaluating classification accuracy of wildlife habitat models
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-05-26
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.3229407
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# MIT License
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>ReScience C code to replicate the following article:</p>
#
# <p>Verbyla DL, Litvaitis JA (1989) Resampling methods for evaluating classification accuracy of wildlife habitat models. Environmental Management 13:783-787 <a href="https://doi.org/10.1007/BF01868317">https://doi.org/10.1007/BF01868317</a></p>
#
# <p>where the authors examined different resampling methods to test wildife habitat models.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3228524
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.3228524
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Jackson M. Tsuji
# {http://datacite.org/schema/kernel-3}affiliation
# @neufeld
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# jmtsuji/chlorobia-cyc2-genomics: First release
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-05-24
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/jmtsuji/chlorobia-cyc2-genomics/tree/v1.0.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.3228523
# {http://datacite.org/schema/kernel-3}version
# v1.0.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Project code is now available online.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3228104
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:31Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.3228104
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Thomas Koentges
# {http://datacite.org/schema/kernel-3}nameIdentifier
# 0000-0002-9425-5850
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Adrian Chitralla
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# ThomasK81/gocite: Phoenix
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-05-24
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/ThomasK81/gocite/tree/2.0.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1257466
# {http://datacite.org/schema/kernel-3}version
# 2.0.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Broke the API partially, restructured Work and Passage object. First and Last information is now in Works not in Passages. Improved SortPassages.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3228161
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:31Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.3228161
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Hijma, Pieter
# {http://datacite.org/schema/kernel-3}affiliation
# Vrije Universiteit Amsterdam
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Common Source Identification Cashmere Native
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Java
# {http://datacite.org/schema/kernel-3}subject
# GPU
# {http://datacite.org/schema/kernel-3}subject
# OpenCL
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-05-24
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/JungleComputing/common-source-identification-cashmere-native/tree/v1.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1326429
# {http://datacite.org/schema/kernel-3}version
# v1.1.1
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Apache License 2.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# Common Source Identification Cashmere Native
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2617377
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:31Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.2617377
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# David Schmidt
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# schmidii/data_experiment: Data Stewardship Project
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-03-30
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/schmidii/data_experiment/tree/1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.2617376
# {http://datacite.org/schema/kernel-3}version
# 1
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>First Relesase of the Data Stewardship Project</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2613564
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:31Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.2613564
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Peter Harrison
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# pmcharrison/voicer-analysis: Initial release
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-03-28
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/pmcharrison/voicer-analysis/tree/v0.1.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.2613563
# {http://datacite.org/schema/kernel-3}version
# v0.1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# Analyses for "A Computational Model for the Analysis and Generation of Chord Voicings"
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2605517
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:32Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.2605517
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Douglas Rosa
# {http://datacite.org/schema/kernel-3}affiliation
# Ética TI
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# douglasrosa0110/github-tests: First release
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-03-25
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/douglasrosa0110/github-tests/tree/v1.0.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.2605516
# {http://datacite.org/schema/kernel-3}version
# v1.0.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>The first release of the test app</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2605181
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:32Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.2605181
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Andrew McCluskey
# {http://datacite.org/schema/kernel-3}affiliation
# University of Bath/Diamond Light Source
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# arm61/fitoog: fitoog-0.1
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-03-25
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/arm61/fitoog/tree/0.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.2605180
# {http://datacite.org/schema/kernel-3}version
# 0.1
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# molecular SAS fitting with MPI
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2600509
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:33Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.2600509
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Reed A. Cartwright
# {http://datacite.org/schema/kernel-3}affiliation
# Arizona State University
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# reedacartwright/toycoati v0.2
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-03-21
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/reedacartwright/toycoati/tree/v0.2
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.2596172
# {http://datacite.org/schema/kernel-3}version
# v0.2
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# An FST for generating pairwise alignments
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:56551
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:35Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.56551
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Warwick Wainwright
# {http://datacite.org/schema/kernel-3}affiliation
# University of Edinburgh
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# planets: Version 1
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-06-28
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/wainwrigh/planets/tree/1.0
# {http://datacite.org/schema/kernel-3}version
# 1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Version 1 of document concerning Mars.  </p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:56583
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:35Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.56583
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# John Rugis
# {http://datacite.org/schema/kernel-3}affiliation
# University of Auckland
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Chris Scott
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# cellsim_34_vcl: The initial release.
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-06-29
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/jrugis/cellsim_34_vcl/tree/v1.0.0
# {http://datacite.org/schema/kernel-3}version
# v1.0.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# GNU General Public License v3.0 only
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>This release supports both linux (Ubuntu 14.04) and University of Auckland pan cluster builds.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:56124
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.56124
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Wenjie Lei
# {http://datacite.org/schema/kernel-3}affiliation
# Princeton University
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Xin Song
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Matthieu Lefebvre
# {http://datacite.org/schema/kernel-3}affiliation
# Princeton University
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# pycmt3d v1.0
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-06-21
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/wjlei1990/pycmt3d/tree/v1.0
# {http://datacite.org/schema/kernel-3}version
# v1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Doc:</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:56055
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.56055
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Will Landau
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# fbseqComputation: Release for version 0.0
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-06-20
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/wlandau/fbseqComputation/tree/0.0
# {http://datacite.org/schema/kernel-3}version
# 0.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>This release accompanies the first submission of a JASA case study.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:55838
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.55838
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Justin B. Kinney
# {http://datacite.org/schema/kernel-3}affiliation
# Cold Spring Harbor Laboratory
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# irelandb
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# mpathic: First release, second attempt
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-06-17
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/jbkinney/mpathic/tree/v0.01.02
# {http://datacite.org/schema/kernel-3}version
# v0.01.02
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>First release of the MPAthic software package</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:11998
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-zenodo
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.11998
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Will Mayner
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# cyphi 0.1.0
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-10-08
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/wmayner/cyphi/tree/0.1.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/zenodo
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>A Python library for computing integrated information.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:55556
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.55556
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Arulalan.T
# {http://datacite.org/schema/kernel-3}affiliation
# National Centre for Medium Range Weather Forecasting
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Raghavendra Sreevathsa Mupparthy
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# UMRider: UMRider v1.0.2
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-06-14
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/arulalant/UMRider/tree/v1.0.2
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.594847
# {http://datacite.org/schema/kernel-3}version
# v1.0.2
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>NCMRWF's in-house development pleased to release UMRider's next operational release <strong>v1.0.2</strong> by focusing on NCUM ensembles post production along with other few new support.</p>
#
# <p><a href="https://zenodo.org/badge/latestdoi/20796/NCMRWF/UMRider"></a></p>
#
#
# <a class="anchor" href="#what-is-new-"><span class="octicon octicon-link"></span></a>what is new ?
#
# <ul>
# <li>Bugs fix</li>
# <li>12 extra user arguments features</li>
# <li>New extra vars </li>
# <li>checkout the <a href="https://github.com/NCMRWF/UMRider/blob/master/CHANGELOG.md#v102-2016-06-14">changlogs</a> and <a href="https://github.com/NCMRWF/UMRider/issues?q=milestone%3Av1.0.2+is%3Aclosed">milestone</a> of v1.0.2</li>
# <li>This v1.0.2 mainly target the following post productions along with the existing v1.0.1 supports
#
# <ul>
# <li><strong>NCUM EPS Global Post Production</strong></li>
# <li><strong>NCUM Tropical Cyclone Tracker input Production</strong></li>
# <li><strong>NCUM Regional Model Wind Energy Input Production</strong></li>
# <li><strong>NCUM Global Solar Energy Input Production</strong></li>
# </ul>
# </li>
# <li>Existing <em>v1.0.1</em> supports
#
# <ul>
# <li>NCUM Indian Region Post Production</li>
# <li>NCUM Global OSF Model Input Production</li>
# <li>NCUM Global HYCOM Model Input Production </li>
# <li>NCUM VSDB Input Production</li>
# <li>NCUM IMD MFI Input Production</li>
# </ul>
# </li>
# </ul>
#
#
# <a class="anchor" href="#v102-supports"><span class="octicon octicon-link"></span></a>v1.0.2 supports
#
# <ul>
# <li>
# <p>In this version v1.0.2 user will be able to control the following 37 arguments by exporting setup.cfg file into their environment variable called <strong>UMRIDER_SETUP</strong>. New arguments in this release are highlighted with bold. </p>
#
# <ul>
# <li><strong>UMtype</strong></li>
# <li><strong>UMInAnlFiles</strong></li>
# <li><strong>UMInShortFcstFiles</strong></li>
# <li>
# <strong>UMInLongFcstFiles</strong>,<br>
# </li>
# <li>inPath</li>
# <li>outPath</li>
# <li>tmpPath</li>
# <li> anl_step_hour</li>
# <li><strong>anl_aavars_reference_time</strong></li>
# <li><strong>anl_aavars_time_bounds</strong></li>
# <li><strong>fcst_step_hour</strong></li>
# <li><strong>start_long_fcst_hour</strong></li>
# <li><strong>end_long_fcst_hours_at_00z</strong></li>
# <li><strong>end_long_fcst_hours_at_12z</strong></li>
# <li>latitude</li>
# <li>longitude</li>
# <li>targetGridResolution</li>
# <li><strong>targetGridFile</strong></li>
# <li><strong>extraPolateMethod</strong></li>
# <li>pressureLevels</li>
# <li><strong>fillFullyMaskedVars</strong></li>
# <li><strong>soilFirstSecondFixedSurfaceUnit</strong></li>
# <li>startdate</li>
# <li>enddate</li>
# <li>loadg2utils</li>
# <li>overwriteFiles</li>
# <li>anlOutGrib2FilesNameStructure</li>
# <li>fcstOutGrib2FilesNameStructure</li>
# <li>createGrib2CtlIdxFiles</li>
# <li>convertGrib2FilestoGrib1Files</li>
# <li>grib1FilesNameSuffix</li>
# <li>removeGrib2FilesAfterGrib1FilesCreated</li>
# <li>createGrib1CtlIdxFiles</li>
# <li>debug </li>
# <li>setGrib2TableParameters</li>
# <li><strong>wgrib2Arguments</strong></li>
# <li>callBackScript</li>
# </ul>
# </li>
# <li><p>Also in this version v1.0.2 user will be able to control the variables by exporting vars.cfg file into their environment variable called <strong>UMRIDER_VARS</strong> . User defined variables and ordered will be retained in the out grib2 files (but pressure level variables comes first and followed by non-pressure level variables)</p></li>
# <li><p>User will be able to control would they like to get 1-hourly or 3-hourly or 6-hourly or 24-hourly <strong>analysis</strong> and/or <strong>forecast</strong> files. (Note that NCUM model produces every 3-hourly instantaneous/ average/ accumulated data. Depends upon user choice it will be  instantaneous or accumulated or averaged properly)</p></li>
# <li>
# <p>This v1.0.2 supports for </p>
#
# <ul>
# <li><strong>NCUM EPS Global Post Production</strong></li>
# <li><strong>NCUM Tropical Cyclone Tracker input Production</strong></li>
# <li><strong>NCUM Regional Model Wind Energy Input Production</strong></li>
# <li><strong>NCUM Global Solar Energy Input Production</strong></li>
# <li>NCUM Global Post Production</li>
# <li>NCUM Indian Region Post Production</li>
# <li>NCUM Global OSF Model Input Production</li>
# <li>NCUM Global HYCOM Model Input Production </li>
# <li>NCUM VSDB Input Production</li>
# <li>NCUM IMD MFI Input Production</li>
# </ul>
# </li>
# </ul>
#
# <p>Regards,</p>
#
# <p>Arulalan.T</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:55241
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.55241
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Luis Antonio Garnica
# {http://datacite.org/schema/kernel-3}affiliation
# University of Texas at El Paso
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# dbowlizer-app: DBOwlizer
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-06-08
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/cybershare/dbowlizer-app/tree/1.0
# {http://datacite.org/schema/kernel-3}version
# 1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Initial release version of DBOWlizer</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:51325
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:37Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.51325
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Mihaljević-Brandt, Helena
# ...
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Massimiliano Assante
# {http://datacite.org/schema/kernel-3}affiliation
# Istituto di Scienza e Tecnologie dell'Informazione "A. Faedo" - CNR, Italy
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# gCube 4.7.0 - Custom Portal Handler v. 2.1.0
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Java
# {http://datacite.org/schema/kernel-3}subject
# Hybrid Data Infrastructure
# {http://datacite.org/schema/kernel-3}subject
# Social Networking
# {http://datacite.org/schema/kernel-3}subject
# gCube
# {http://datacite.org/schema/kernel-3}subject
# Graphical User Interface
# {http://datacite.org/schema/kernel-3}subject
# Data Management System
# {http://datacite.org/schema/kernel-3}subject
# Human Computer Interaction
# {http://datacite.org/schema/kernel-3}contributors
#
#
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/283644/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/675680/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654142/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654119/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/239019/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/288754/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654182/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/212488/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/283465/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654024/
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-10-13
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/gcube-team/gcube-releases/tree/master/portal/custom-portal-handler/2.1.0-4.7.0-131316
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.910468
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:gcube:mvn:org.gcube.portal:custom-portal-handler:2.1.0-4.7.0-131316
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1010650
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/gcube-system
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# European Union Public License 1.1
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>
# The gCube System - Custom Portal Handler<br>
# --------------------------------------------------<br>
#  <br>
# gCube Custom Portal Handler is a component that all portlets need to use to set the context where they running. <br>
# 		It also contains utils from creating community and organization with their layouts into liferay portal.<br>
#  <br>
#  <br>
# This software is part of the gCube Framework (https://www.gcube-system.org/): an<br>
# open-source software toolkit used for building and operating Hybrid Data<br>
# Infrastructures enabling the dynamic deployment of Virtual Research Environments<br>
# by favouring the realisation of reuse oriented policies.<br>
#  <br>
# The projects leading to this software have received funding from a series of<br>
# European Union programmes including:<br>
# * the Sixth Framework Programme for Research and Technological Development -<br>
# DILIGENT (grant no. 004260);<br>
# * the Seventh Framework Programme for research, technological development and<br>
# demonstration - D4Science (grant no. 212488), D4Science-II (grant no.<br>
# 239019),ENVRI (grant no. 283465), EUBrazilOpenBio (grant no. 288754), iMarine<br>
# (grant no. 283644);<br>
# * the H2020 research and innovation programme - BlueBRIDGE (grant no. 675680),<br>
# EGIEngage (grant no. 654142), ENVRIplus (grant no. 654182), Parthenos (grant<br>
# no. 654119), SoBigData (grant no. 654024);<br>
#  <br>
#  <br>
# Version<br>
# --------------------------------------------------<br>
#  <br>
# 2.1.0-4.7.0-131316 (2017-10-12)<br>
#  <br>
# Please see the file named "changelog.xml" in this directory for the release notes.<br>
#  <br>
#  <br>
# Authors<br>
# --------------------------------------------------<br>
#  <br>
# * Massimiliano Assante (massimiliano.assante-AT-isti.cnr.it), Istituto di Scienza e Tecnologie dell'Informazione "A. Faedo" - CNR, Pisa (Italy).<br>
# <br>
#  <br>
#  <br>
# Maintainers<br>
# -----------<br>
#  <br>
# * Massimiliano Assante (massimiliano.assante-AT-isti.cnr.it), Istituto di Scienza e Tecnologie dell'Informazione "A. Faedo" - CNR, Pisa (Italy).<br>
#  <br>
#  <br>
# Download information<br>
# --------------------------------------------------<br>
#  <br>
# Source code is available from SVN: <br>
#     http://svn.research-infrastructures.eu/public/d4science/gcube/trunk/portlal/custom-portal-handler<br>
#  <br>
# Binaries can be downloaded from the gCube website: <br>
#    https://www.gcube-system.org/<br>
#  <br>
#  <br>
# Installation<br>
# --------------------------------------------------<br>
#  <br>
# Installation documentation is available on-line in the gCube Wiki:<br>
#     https://wiki.gcube-system.org/gcube/index.php/<br>
#  <br>
#  <br>
# Documentation <br>
# --------------------------------------------------<br>
#  <br>
# Documentation is available on-line in the gCube Wiki:<br>
#     https://wiki.gcube-system.org/gcube/index.php/<br>
#     https://wiki.gcube-system.org/gcube/index.php/<br>
#  <br>
# Support <br>
# --------------------------------------------------<br>
#  <br>
# Bugs and support requests can be reported in the gCube issue tracking tool:<br>
#     https://support.d4science.org/projects/gcube/<br>
#  <br>
#  <br>
# Licensing<br>
# --------------------------------------------------<br>
#  <br>
# This software is licensed under the terms you may find in the file named "LICENSE" in this directory.<br>
#
# </p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1010639
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:45Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-gcube-system
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1010639
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Massimiliano Assante
# {http://datacite.org/schema/kernel-3}affiliation
# Istituto di Scienza e Tecnologie dell'Informazione "A. Faedo" - CNR, Italy
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# gCube 4.7.0 - social-dockbar-hook Hook v. 6.3.0
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Java
# {http://datacite.org/schema/kernel-3}subject
# Hybrid Data Infrastructure
# {http://datacite.org/schema/kernel-3}subject
# Social Networking
# {http://datacite.org/schema/kernel-3}subject
# gCube
# {http://datacite.org/schema/kernel-3}subject
# Graphical User Interface
# {http://datacite.org/schema/kernel-3}subject
# Data Management System
# {http://datacite.org/schema/kernel-3}subject
# Human Computer Interaction
# {http://datacite.org/schema/kernel-3}contributors
#
#
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/283644/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/675680/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654142/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654119/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/239019/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/288754/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654182/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/212488/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/283465/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654024/
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-10-13
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:gcube:mvn:org.gcube.portal.plugins:social-dockbar-hook:6.3.0-4.7.0-130375
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/gcube-team/gcube-releases/tree/master/portal/social-dockbar-hook/6.3.0-4.7.0-130375
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1001454
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1010638
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/gcube-system
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# European Union Public License 1.1
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>
# The gCube System<br>
# ------------------------------------------------------------<br>
# <br>
# This software is part of the gCube Framework (https://www.gcube-system.org/): an<br>
# open-source software toolkit used for building and operating Hybrid Data<br>
# Infrastructures enabling the dynamic deployment of Virtual Research Environments<br>
# by favouring the realisation of reuse oriented policies.<br>
#  <br>
# The projects leading to this software have received funding from a series of<br>
# European Union programmes including:<br>
# * the Sixth Framework Programme for Research and Technological Development -<br>
# DILIGENT (grant no. 004260);<br>
# * the Seventh Framework Programme for research, technological development and<br>
# demonstration - D4Science (grant no. 212488), D4Science-II (grant no.<br>
# 239019),ENVRI (grant no. 283465), EUBrazilOpenBio (grant no. 288754), iMarine<br>
# (grant no. 283644);<br>
# * the H2020 research and innovation programme - BlueBRIDGE (grant no. 675680),<br>
# EGIEngage (grant no. 654142), ENVRIplus (grant no. 654182), Parthenos (grant<br>
# no. 654119), SoBigData (grant no. 654024);<br>
# <br>
# <br>
# Version<br>
# --------------------------------------------------<br>
# 6.3.0-4.7.0-130375 (2017-10-13)<br>
#  <br>
# Please see the file named "changelog.xml" in this directory for the release notes.<br>
# <br>
# <br>
# Authors<br>
# -------<br>
# <br>
#  <br>
# Massimiliano Assante (massimiliano.assante-AT-isti.cnr.it), Istituto di Scienza e Tecnologie dell'Informazione "A. Faedo" - CNR, Pisa (Italy).<br>
# <br>
# <br>
# Maintainers<br>
# -----------<br>
#  <br>
# Massimiliano Assante (massimiliano.assante-AT-isti.cnr.it), Istituto di Scienza e Tecnologie dell'Informazione "A. Faedo" - CNR, Pisa (Italy).<br>
#  <br>
#  <br>
# Documentation<br>
# -------------<br>
# <br>
# Documentation is available on - line from the Projects Documentation wiki:<br>
# <br>
#  {gcube.wikiRoot}/gcube/index.php/UserManagement_Core<br>
# <br>
# <br>
# Support <br>
# --------------------------------------------------<br>
# Bugs and support requests can be reported in the gCube issue tracking tool:<br>
#     https://support.d4science.org/projects/gcube/<br>
#  <br>
#  <br>
# Licensing<br>
# --------------------------------------------------<br>
# This software is licensed under the terms you may find in the file named "LICENSE" in this directory.<br>
#
# </p>
# {http://www.openarchives.org/OAI/2.0/}resumptionToken
# .eJwdjb0OgjAYAN_lm9EULFVJGETFhEkQ5WchFSppSkNTmmAkvLvojXfDTTAw1oCH1pjYe4KwQwgiuw0hWwuGWvddV_GlwykP7TKP3DhzRSIfqHDa4PDns9IXnD1lZ5KzQfFd3RoZHtM0UKlQuLCjsBx9HyxQtGXgORaIkep2AG8CyQxtqKFXzV78vWx6yqufqLlhMM9fnYsx1g.XhJnGg.vc-rsG6PHjQWh6ArEzIi67BlpTQ

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Muestra sólo el identificador y las palabras clave (subject)

# %%
# Se puede hacer mejor; findall de identifier
oai = requests.get('https://zenodo.org/oai2d?verb=ListRecords&metadataPrefix=oai_datacite')
xmlTree = ET.fromstring(oai.text)
iterator = xmlTree.iter()
for elem in iterator:
    if(elem.tag == "{http://datacite.org/schema/kernel-3}identifier" or elem.tag == "{http://datacite.org/schema/kernel-3}subject"):
        print(elem.tag, elem.text)
# Out:
# {http://datacite.org/schema/kernel-3}identifier 10.5281/zenodo.3367294
# {http://datacite.org/schema/kernel-3}subject civil service
# {http://datacite.org/schema/kernel-3}subject public service law
# {http://datacite.org/schema/kernel-3}subject government administration
# {http://datacite.org/schema/kernel-3}subject state
# {http://datacite.org/schema/kernel-3}subject law
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523810
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Chordata
# {http://datacite.org/schema/kernel-3}subject Actinopterygii
# {http://datacite.org/schema/kernel-3}subject Characiformes
# {http://datacite.org/schema/kernel-3}subject Characidae
# {http://datacite.org/schema/kernel-3}subject Aphyocharax
# {http://datacite.org/schema/kernel-3}subject Freshwater
# {http://datacite.org/schema/kernel-3}subject integrative taxonomy
# {http://datacite.org/schema/kernel-3}subject Neotropical ichthyology
# {http://datacite.org/schema/kernel-3}subject sexual dimorphism
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523800
# {http://datacite.org/schema/kernel-3}subject hybrid
# {http://datacite.org/schema/kernel-3}subject molecular
# {http://datacite.org/schema/kernel-3}subject Nepeta
# {http://datacite.org/schema/kernel-3}subject phylogeny
# {http://datacite.org/schema/kernel-3}subject Turkey
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523790
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Ericales
# {http://datacite.org/schema/kernel-3}subject Ericaceae
# {http://datacite.org/schema/kernel-3}subject Rhododendron
# {http://datacite.org/schema/kernel-3}subject Ericaceae
# {http://datacite.org/schema/kernel-3}subject new species
# {http://datacite.org/schema/kernel-3}subject phylogeny
# {http://datacite.org/schema/kernel-3}subject Rhododendron
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523788
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Ericales
# {http://datacite.org/schema/kernel-3}subject Ericaceae
# {http://datacite.org/schema/kernel-3}subject Rhododendron
# {http://datacite.org/schema/kernel-3}subject Ericaceae
# {http://datacite.org/schema/kernel-3}subject new species
# {http://datacite.org/schema/kernel-3}subject phylogeny
# {http://datacite.org/schema/kernel-3}subject Rhododendron
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523784
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Ericales
# {http://datacite.org/schema/kernel-3}subject Ericaceae
# {http://datacite.org/schema/kernel-3}subject Rhododendron
# {http://datacite.org/schema/kernel-3}subject Rhododendron tschonoskii
# {http://datacite.org/schema/kernel-3}subject Ericaceae
# {http://datacite.org/schema/kernel-3}subject new species
# {http://datacite.org/schema/kernel-3}subject phylogeny
# {http://datacite.org/schema/kernel-3}subject Rhododendron
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523782
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Ericales
# {http://datacite.org/schema/kernel-3}subject Ericaceae
# {http://datacite.org/schema/kernel-3}subject Rhododendron
# {http://datacite.org/schema/kernel-3}subject Rhododendron tschonoskii
# {http://datacite.org/schema/kernel-3}subject Ericaceae
# {http://datacite.org/schema/kernel-3}subject new species
# {http://datacite.org/schema/kernel-3}subject phylogeny
# {http://datacite.org/schema/kernel-3}subject Rhododendron
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523780
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Ericales
# {http://datacite.org/schema/kernel-3}subject Ericaceae
# {http://datacite.org/schema/kernel-3}subject Rhododendron
# {http://datacite.org/schema/kernel-3}subject Rhododendron tschonoskii
# {http://datacite.org/schema/kernel-3}subject Ericaceae
# {http://datacite.org/schema/kernel-3}subject new species
# {http://datacite.org/schema/kernel-3}subject phylogeny
# {http://datacite.org/schema/kernel-3}subject Rhododendron
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523778
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Ericales
# {http://datacite.org/schema/kernel-3}subject Ericaceae
# {http://datacite.org/schema/kernel-3}subject Rhododendron
# {http://datacite.org/schema/kernel-3}subject Rhododendron tschonoskii
# {http://datacite.org/schema/kernel-3}subject Rhododendron tanakae
# {http://datacite.org/schema/kernel-3}subject Rhododendron tschonoskii trinerve
# {http://datacite.org/schema/kernel-3}subject Ericaceae
# {http://datacite.org/schema/kernel-3}subject new species
# {http://datacite.org/schema/kernel-3}subject phylogeny
# {http://datacite.org/schema/kernel-3}subject Rhododendron
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523776
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Ericales
# {http://datacite.org/schema/kernel-3}subject Ericaceae
# {http://datacite.org/schema/kernel-3}subject Rhododendron
# {http://datacite.org/schema/kernel-3}subject Ericaceae
# {http://datacite.org/schema/kernel-3}subject new species
# {http://datacite.org/schema/kernel-3}subject phylogeny
# {http://datacite.org/schema/kernel-3}subject Rhododendron
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523770
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola elongata
# {http://datacite.org/schema/kernel-3}subject Virola guatemalensis
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523768
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola elongata
# {http://datacite.org/schema/kernel-3}subject Virola guatemalensis
# {http://datacite.org/schema/kernel-3}subject Virola koschnyi
# {http://datacite.org/schema/kernel-3}subject Virola megacarpa
# {http://datacite.org/schema/kernel-3}subject Malpighiales
# {http://datacite.org/schema/kernel-3}subject Violaceae
# {http://datacite.org/schema/kernel-3}subject Viola
# {http://datacite.org/schema/kernel-3}subject Viola canina ruppii
# {http://datacite.org/schema/kernel-3}subject Viola stagnina
# {http://datacite.org/schema/kernel-3}subject Viola lobata
# {http://datacite.org/schema/kernel-3}subject Viola pumila
# {http://datacite.org/schema/kernel-3}subject Viola elatior
# {http://datacite.org/schema/kernel-3}subject Virola multiflora
# {http://datacite.org/schema/kernel-3}subject Virola surinamensis
# {http://datacite.org/schema/kernel-3}subject Virola sebifera
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523766
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola macrocarpa
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523764
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523762
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523760
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola macrocarpa
# {http://datacite.org/schema/kernel-3}subject Virola koschnyi
# {http://datacite.org/schema/kernel-3}subject Virola guatemalensis
# {http://datacite.org/schema/kernel-3}subject Malpighiales
# {http://datacite.org/schema/kernel-3}subject Violaceae
# {http://datacite.org/schema/kernel-3}subject Viola
# {http://datacite.org/schema/kernel-3}subject Viola canina ruppii
# {http://datacite.org/schema/kernel-3}subject Viola stagnina
# {http://datacite.org/schema/kernel-3}subject Viola lobata
# {http://datacite.org/schema/kernel-3}subject Viola pumila
# {http://datacite.org/schema/kernel-3}subject Viola elatior
# {http://datacite.org/schema/kernel-3}subject Virola multiflora
# {http://datacite.org/schema/kernel-3}subject Virola sebifera
# {http://datacite.org/schema/kernel-3}subject Virola elongata
# {http://datacite.org/schema/kernel-3}subject Virola surinamensis
# {http://datacite.org/schema/kernel-3}subject Virola megacarpa
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523758
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola elongata
# {http://datacite.org/schema/kernel-3}subject Virola guatemalensis
# {http://datacite.org/schema/kernel-3}subject Virola koschnyi
# {http://datacite.org/schema/kernel-3}subject Virola megacarpa
# {http://datacite.org/schema/kernel-3}subject Malpighiales
# {http://datacite.org/schema/kernel-3}subject Violaceae
# {http://datacite.org/schema/kernel-3}subject Viola
# {http://datacite.org/schema/kernel-3}subject Viola canina ruppii
# {http://datacite.org/schema/kernel-3}subject Viola stagnina
# {http://datacite.org/schema/kernel-3}subject Viola lobata
# {http://datacite.org/schema/kernel-3}subject Viola pumila
# {http://datacite.org/schema/kernel-3}subject Viola elatior
# {http://datacite.org/schema/kernel-3}subject Virola multiflora
# {http://datacite.org/schema/kernel-3}subject Virola surinamensis
# {http://datacite.org/schema/kernel-3}subject Virola sebifera
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523756
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola sebifera
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523754
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola sebifera
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523752
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523750
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola surinamensis
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523748
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola surinamensis
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523746
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola surinamensis
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523742
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Malpighiales
# {http://datacite.org/schema/kernel-3}subject Violaceae
# {http://datacite.org/schema/kernel-3}subject Viola
# {http://datacite.org/schema/kernel-3}subject Viola canina ruppii
# {http://datacite.org/schema/kernel-3}subject Viola stagnina
# {http://datacite.org/schema/kernel-3}subject Viola lobata
# {http://datacite.org/schema/kernel-3}subject Viola pumila
# {http://datacite.org/schema/kernel-3}subject Viola elatior
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523740
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola megacarpa
# {http://datacite.org/schema/kernel-3}subject Virola surinamensis
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523738
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523736
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola guatemalensis
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523734
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola koschnyi
# {http://datacite.org/schema/kernel-3}subject Virola guatemalensis
# {http://datacite.org/schema/kernel-3}subject Virola megacarpa
# {http://datacite.org/schema/kernel-3}subject Malpighiales
# {http://datacite.org/schema/kernel-3}subject Violaceae
# {http://datacite.org/schema/kernel-3}subject Viola
# {http://datacite.org/schema/kernel-3}subject Viola canina ruppii
# {http://datacite.org/schema/kernel-3}subject Viola stagnina
# {http://datacite.org/schema/kernel-3}subject Viola lobata
# {http://datacite.org/schema/kernel-3}subject Viola pumila
# {http://datacite.org/schema/kernel-3}subject Viola elatior
# {http://datacite.org/schema/kernel-3}subject Virola multiflora
# {http://datacite.org/schema/kernel-3}subject Virola surinamensis
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523732
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola koschnyi
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523730
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523728
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523726
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523724
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523722
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523720
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523718
# {http://datacite.org/schema/kernel-3}subject Plantae
# {http://datacite.org/schema/kernel-3}subject Tracheophyta
# {http://datacite.org/schema/kernel-3}subject Magnoliopsida
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject Myristicaceae
# {http://datacite.org/schema/kernel-3}subject Virola
# {http://datacite.org/schema/kernel-3}subject Virola calophylla
# {http://datacite.org/schema/kernel-3}subject Virola elongata
# {http://datacite.org/schema/kernel-3}subject Virola guatemalensis
# {http://datacite.org/schema/kernel-3}subject Costa Rica
# {http://datacite.org/schema/kernel-3}subject Flora Mesoamericana
# {http://datacite.org/schema/kernel-3}subject hallucinogenic
# {http://datacite.org/schema/kernel-3}subject Magnoliales
# {http://datacite.org/schema/kernel-3}subject nutmeg
# {http://datacite.org/schema/kernel-3}subject Panama
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523710
# {http://datacite.org/schema/kernel-3}subject Aristolochia
# {http://datacite.org/schema/kernel-3}subject Isotrema
# {http://datacite.org/schema/kernel-3}subject morphology
# {http://datacite.org/schema/kernel-3}subject subgenus Siphisia
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523708
# {http://datacite.org/schema/kernel-3}subject Aristolochia
# {http://datacite.org/schema/kernel-3}subject Isotrema
# {http://datacite.org/schema/kernel-3}subject morphology
# {http://datacite.org/schema/kernel-3}subject subgenus Siphisia
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523706
# {http://datacite.org/schema/kernel-3}subject Aristolochia
# {http://datacite.org/schema/kernel-3}subject Isotrema
# {http://datacite.org/schema/kernel-3}subject morphology
# {http://datacite.org/schema/kernel-3}subject subgenus Siphisia
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523692
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Liphistiidae
# {http://datacite.org/schema/kernel-3}subject Liphistius
# {http://datacite.org/schema/kernel-3}subject Liphistius
# {http://datacite.org/schema/kernel-3}subject Myanmar
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}subject trapdoor spiders
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523690
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Liphistiidae
# {http://datacite.org/schema/kernel-3}subject Liphistius
# {http://datacite.org/schema/kernel-3}subject Liphistius
# {http://datacite.org/schema/kernel-3}subject Myanmar
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}subject trapdoor spiders
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523688
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Liphistiidae
# {http://datacite.org/schema/kernel-3}subject Liphistius
# {http://datacite.org/schema/kernel-3}subject Liphistius
# {http://datacite.org/schema/kernel-3}subject Myanmar
# {http://datacite.org/schema/kernel-3}subject taxonomy
# {http://datacite.org/schema/kernel-3}subject trapdoor spiders
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523682
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Chordata
# {http://datacite.org/schema/kernel-3}subject Actinopterygii
# {http://datacite.org/schema/kernel-3}subject Perciformes
# {http://datacite.org/schema/kernel-3}subject Gobiidae
# {http://datacite.org/schema/kernel-3}subject Coryphopterus
# {http://datacite.org/schema/kernel-3}subject Coryphopterus punctipectophorus
# {http://datacite.org/schema/kernel-3}subject Georeferenced aggregator records
# {http://datacite.org/schema/kernel-3}subject literature review
# {http://datacite.org/schema/kernel-3}subject nomenclature
# {http://datacite.org/schema/kernel-3}subject observations
# {http://datacite.org/schema/kernel-3}subject photography vouchers
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523680
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Chordata
# {http://datacite.org/schema/kernel-3}subject Actinopterygii
# {http://datacite.org/schema/kernel-3}subject Perciformes
# {http://datacite.org/schema/kernel-3}subject Chaenopsidae
# {http://datacite.org/schema/kernel-3}subject Emblemaria
# {http://datacite.org/schema/kernel-3}subject Emblemaria pandionis
# {http://datacite.org/schema/kernel-3}subject Georeferenced aggregator records
# {http://datacite.org/schema/kernel-3}subject literature review
# {http://datacite.org/schema/kernel-3}subject nomenclature
# {http://datacite.org/schema/kernel-3}subject observations
# {http://datacite.org/schema/kernel-3}subject photography vouchers
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523678
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Chordata
# {http://datacite.org/schema/kernel-3}subject Actinopterygii
# {http://datacite.org/schema/kernel-3}subject Tetraodontiformes
# {http://datacite.org/schema/kernel-3}subject Tetraodontidae
# {http://datacite.org/schema/kernel-3}subject Canthigaster
# {http://datacite.org/schema/kernel-3}subject Canthigaster jamestyleri
# {http://datacite.org/schema/kernel-3}subject Georeferenced aggregator records
# {http://datacite.org/schema/kernel-3}subject literature review
# {http://datacite.org/schema/kernel-3}subject nomenclature
# {http://datacite.org/schema/kernel-3}subject observations
# {http://datacite.org/schema/kernel-3}subject photography vouchers
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523676
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Chordata
# {http://datacite.org/schema/kernel-3}subject Actinopterygii
# {http://datacite.org/schema/kernel-3}subject Perciformes
# {http://datacite.org/schema/kernel-3}subject Sparidae
# {http://datacite.org/schema/kernel-3}subject Calamus
# {http://datacite.org/schema/kernel-3}subject Calamus nodosus
# {http://datacite.org/schema/kernel-3}subject Georeferenced aggregator records
# {http://datacite.org/schema/kernel-3}subject literature review
# {http://datacite.org/schema/kernel-3}subject nomenclature
# {http://datacite.org/schema/kernel-3}subject observations
# {http://datacite.org/schema/kernel-3}subject photography vouchers
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523674
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Chordata
# {http://datacite.org/schema/kernel-3}subject Actinopterygii
# {http://datacite.org/schema/kernel-3}subject Perciformes
# {http://datacite.org/schema/kernel-3}subject Haemulidae
# {http://datacite.org/schema/kernel-3}subject Haemulon
# {http://datacite.org/schema/kernel-3}subject Haemulon boschmae
# {http://datacite.org/schema/kernel-3}subject Georeferenced aggregator records
# {http://datacite.org/schema/kernel-3}subject literature review
# {http://datacite.org/schema/kernel-3}subject nomenclature
# {http://datacite.org/schema/kernel-3}subject observations
# {http://datacite.org/schema/kernel-3}subject photography vouchers
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523672
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Chordata
# {http://datacite.org/schema/kernel-3}subject Actinopterygii
# {http://datacite.org/schema/kernel-3}subject Perciformes
# {http://datacite.org/schema/kernel-3}subject Pomacentridae
# {http://datacite.org/schema/kernel-3}subject Neopomacentrus
# {http://datacite.org/schema/kernel-3}subject Neopomacentrus cyanomos
# {http://datacite.org/schema/kernel-3}subject Chromis
# {http://datacite.org/schema/kernel-3}subject Chromis multilineata
# {http://datacite.org/schema/kernel-3}subject Georeferenced aggregator records
# {http://datacite.org/schema/kernel-3}subject literature review
# {http://datacite.org/schema/kernel-3}subject nomenclature
# {http://datacite.org/schema/kernel-3}subject observations
# {http://datacite.org/schema/kernel-3}subject photography vouchers
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523668
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Chordata
# {http://datacite.org/schema/kernel-3}subject Actinopterygii
# {http://datacite.org/schema/kernel-3}subject Perciformes
# {http://datacite.org/schema/kernel-3}subject Serranidae
# {http://datacite.org/schema/kernel-3}subject Hypoplectrus
# {http://datacite.org/schema/kernel-3}subject Hypoplectrus floridae
# {http://datacite.org/schema/kernel-3}subject Hypoplectrus puella
# {http://datacite.org/schema/kernel-3}subject Hypoplectrus unicolor
# {http://datacite.org/schema/kernel-3}subject Georeferenced aggregator records
# {http://datacite.org/schema/kernel-3}subject literature review
# {http://datacite.org/schema/kernel-3}subject nomenclature
# {http://datacite.org/schema/kernel-3}subject observations
# {http://datacite.org/schema/kernel-3}subject photography vouchers
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523666
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Chordata
# {http://datacite.org/schema/kernel-3}subject Actinopterygii
# {http://datacite.org/schema/kernel-3}subject Perciformes
# {http://datacite.org/schema/kernel-3}subject Serranidae
# {http://datacite.org/schema/kernel-3}subject Hypoplectrus
# {http://datacite.org/schema/kernel-3}subject Hypoplectrus atlahua
# {http://datacite.org/schema/kernel-3}subject Hypoplectrus nigricans
# {http://datacite.org/schema/kernel-3}subject Hypoplectrus unicolor
# {http://datacite.org/schema/kernel-3}subject Georeferenced aggregator records
# {http://datacite.org/schema/kernel-3}subject literature review
# {http://datacite.org/schema/kernel-3}subject nomenclature
# {http://datacite.org/schema/kernel-3}subject observations
# {http://datacite.org/schema/kernel-3}subject photography vouchers
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523664
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Chordata
# {http://datacite.org/schema/kernel-3}subject Actinopterygii
# {http://datacite.org/schema/kernel-3}subject Perciformes
# {http://datacite.org/schema/kernel-3}subject Serranidae
# {http://datacite.org/schema/kernel-3}subject Hypoplectrus
# {http://datacite.org/schema/kernel-3}subject Hypoplectrus castroaguirrei
# {http://datacite.org/schema/kernel-3}subject Hypoplectrus unicolor
# {http://datacite.org/schema/kernel-3}subject Hypoplectrus puella
# {http://datacite.org/schema/kernel-3}subject Georeferenced aggregator records
# {http://datacite.org/schema/kernel-3}subject literature review
# {http://datacite.org/schema/kernel-3}subject nomenclature
# {http://datacite.org/schema/kernel-3}subject observations
# {http://datacite.org/schema/kernel-3}subject photography vouchers
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523660
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Chordata
# {http://datacite.org/schema/kernel-3}subject Actinopterygii
# {http://datacite.org/schema/kernel-3}subject Perciformes
# {http://datacite.org/schema/kernel-3}subject Serranidae
# {http://datacite.org/schema/kernel-3}subject Hypoplectrus
# {http://datacite.org/schema/kernel-3}subject Hypoplectrus atlahua
# {http://datacite.org/schema/kernel-3}subject Georeferenced aggregator records
# {http://datacite.org/schema/kernel-3}subject literature review
# {http://datacite.org/schema/kernel-3}subject nomenclature
# {http://datacite.org/schema/kernel-3}subject observations
# {http://datacite.org/schema/kernel-3}subject photography vouchers
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523656
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Chordata
# {http://datacite.org/schema/kernel-3}subject Actinopterygii
# {http://datacite.org/schema/kernel-3}subject Perciformes
# {http://datacite.org/schema/kernel-3}subject Gobiidae
# {http://datacite.org/schema/kernel-3}subject Elacatinus
# {http://datacite.org/schema/kernel-3}subject Elacatinus jarocho
# {http://datacite.org/schema/kernel-3}subject Georeferenced aggregator records
# {http://datacite.org/schema/kernel-3}subject literature review
# {http://datacite.org/schema/kernel-3}subject nomenclature
# {http://datacite.org/schema/kernel-3}subject observations
# {http://datacite.org/schema/kernel-3}subject photography vouchers
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523654
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Chordata
# {http://datacite.org/schema/kernel-3}subject Actinopterygii
# {http://datacite.org/schema/kernel-3}subject Perciformes
# {http://datacite.org/schema/kernel-3}subject Chaenopsidae
# {http://datacite.org/schema/kernel-3}subject Emblemariopsis
# {http://datacite.org/schema/kernel-3}subject Emblemariopsis diaphana
# {http://datacite.org/schema/kernel-3}subject Georeferenced aggregator records
# {http://datacite.org/schema/kernel-3}subject literature review
# {http://datacite.org/schema/kernel-3}subject nomenclature
# {http://datacite.org/schema/kernel-3}subject observations
# {http://datacite.org/schema/kernel-3}subject photography vouchers
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3523646
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Insecta
# {http://datacite.org/schema/kernel-3}subject Lepidoptera
# {http://datacite.org/schema/kernel-3}subject Papilionoidea
# {http://datacite.org/schema/kernel-3}subject Nymphalidae
# {http://datacite.org/schema/kernel-3}subject Acraea
# {http://datacite.org/schema/kernel-3}subject Acraea oscari
# {http://datacite.org/schema/kernel-3}subject Bombycoidea
# {http://datacite.org/schema/kernel-3}subject Saturniidae
# {http://datacite.org/schema/kernel-3}subject Epiphora
# {http://datacite.org/schema/kernel-3}subject Epiphora fournierae
# {http://datacite.org/schema/kernel-3}subject Geometroidea
# {http://datacite.org/schema/kernel-3}subject Geometridae
# {http://datacite.org/schema/kernel-3}subject Pingasa
# {http://datacite.org/schema/kernel-3}subject Pingasa pallidata
# {http://datacite.org/schema/kernel-3}subject Cephalornis
# {http://datacite.org/schema/kernel-3}subject Coelenterata
# {http://datacite.org/schema/kernel-3}subject Bilateria
# {http://datacite.org/schema/kernel-3}subject Nephrozoa
# {http://datacite.org/schema/kernel-3}subject Protostomia
# {http://datacite.org/schema/kernel-3}subject Ecdysozoa
# {http://datacite.org/schema/kernel-3}subject Circumscriptional names of the taxon under
# {http://datacite.org/schema/kernel-3}subject Notchia
# {http://datacite.org/schema/kernel-3}subject Carbotriplurida
# {http://datacite.org/schema/kernel-3}subject Boltonocostidae
# {http://datacite.org/schema/kernel-3}subject Circumscriptional names
# {http://datacite.org/schema/kernel-3}subject Pterygota
# {http://datacite.org/schema/kernel-3}subject Circumscriptional name
# {http://datacite.org/schema/kernel-3}subject Basal
# {http://datacite.org/schema/kernel-3}subject Eumetabola
# {http://datacite.org/schema/kernel-3}subject Strashila incredibilis
# {http://datacite.org/schema/kernel-3}subject Panorpida
# {http://datacite.org/schema/kernel-3}subject Amphiesmenoptera
# {http://datacite.org/schema/kernel-3}subject Porina
# {http://datacite.org/schema/kernel-3}subject Galacticoidea
# {http://datacite.org/schema/kernel-3}subject Heteroneura
# {http://datacite.org/schema/kernel-3}subject Ditrysia
# {http://datacite.org/schema/kernel-3}subject Cossina
# ...
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522535
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha bogotensis
# {http://datacite.org/schema/kernel-3}subject Tetragnatha ramboi
# {http://datacite.org/schema/kernel-3}subject Tetragnatha bemalcuei
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522533
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha bogotensis
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522529
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha bogotensis
# {http://datacite.org/schema/kernel-3}subject Tetragnatha nitens
# {http://datacite.org/schema/kernel-3}subject Tetragnatha boydi praedator
# {http://datacite.org/schema/kernel-3}subject Tetragnatha bemalcuei
# {http://datacite.org/schema/kernel-3}subject Tetragnatha ramboi
# {http://datacite.org/schema/kernel-3}subject Tetragnatha keyserlingi
# {http://datacite.org/schema/kernel-3}subject Tetragnatha kochi
# {http://datacite.org/schema/kernel-3}subject Tetragnatha maxillosa
# {http://datacite.org/schema/kernel-3}subject Tetragnatha nigrita
# {http://datacite.org/schema/kernel-3}subject Tetragnatha mandibulata
# {http://datacite.org/schema/kernel-3}subject Tetragnatha confraterna
# {http://datacite.org/schema/kernel-3}subject Tetragnatha necatoria
# {http://datacite.org/schema/kernel-3}subject Tetragnatha boydi
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522527
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha bogotensis
# {http://datacite.org/schema/kernel-3}subject Tetragnatha elongata
# {http://datacite.org/schema/kernel-3}subject Tetragnatha keyserlingi
# {http://datacite.org/schema/kernel-3}subject Tetragnatha mandibulata
# {http://datacite.org/schema/kernel-3}subject Tetragnatha nitens
# {http://datacite.org/schema/kernel-3}subject Tetragnatha vermiformis
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522525
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha bogotensis
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522523
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha vermiformis
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522521
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha vermiformis
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522519
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha vermiformis
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522517
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha nitens
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522515
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha nitens
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522513
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha nitens
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522511
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha mandibulata
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522509
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha mandibulata
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522507
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha mandibulata
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522505
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha keyserlingi
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier https://zenodo.org/record/3522503
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Arachnida
# {http://datacite.org/schema/kernel-3}subject Araneae
# {http://datacite.org/schema/kernel-3}subject Tetragnathidae
# {http://datacite.org/schema/kernel-3}subject Tetragnatha
# {http://datacite.org/schema/kernel-3}subject Tetragnatha bogotensis
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Araneoidea
# {http://datacite.org/schema/kernel-3}subject Systematics
# {http://datacite.org/schema/kernel-3}subject Tetragnathinae
# {http://datacite.org/schema/kernel-3}identifier 10.5281/zenodo.3520992
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Taxonomy
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Cnidaria
# {http://datacite.org/schema/kernel-3}subject Hydrozoa
# {http://datacite.org/schema/kernel-3}subject Anthoathecata
# {http://datacite.org/schema/kernel-3}subject Candelabridae
# {http://datacite.org/schema/kernel-3}subject Candelabrum
# {http://datacite.org/schema/kernel-3}identifier 10.5281/zenodo.3520990
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Taxonomy
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Cnidaria
# {http://datacite.org/schema/kernel-3}subject Hydrozoa
# {http://datacite.org/schema/kernel-3}subject Anthoathecata
# {http://datacite.org/schema/kernel-3}subject Candelabridae
# {http://datacite.org/schema/kernel-3}subject Candelabrum
# {http://datacite.org/schema/kernel-3}identifier 10.5281/zenodo.3520898
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Taxonomy
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Insecta
# {http://datacite.org/schema/kernel-3}subject Plecoptera
# {http://datacite.org/schema/kernel-3}identifier 10.5281/zenodo.3520894
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Taxonomy
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Insecta
# {http://datacite.org/schema/kernel-3}subject Plecoptera
# {http://datacite.org/schema/kernel-3}identifier 10.5281/zenodo.3520789
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Taxonomy
# {http://datacite.org/schema/kernel-3}subject Animalia
# {http://datacite.org/schema/kernel-3}subject Arthropoda
# {http://datacite.org/schema/kernel-3}subject Insecta
# {http://datacite.org/schema/kernel-3}subject Odonata
# {http://datacite.org/schema/kernel-3}subject Lestidae
# {http://datacite.org/schema/kernel-3}subject Lestes
# {http://datacite.org/schema/kernel-3}identifier 10.5281/zenodo.3520762
# {http://datacite.org/schema/kernel-3}subject Biodiversity
# {http://datacite.org/schema/kernel-3}subject Taxonomy
# {http://datacite.org/schema/kernel-3}identifier 10.5281/zenodo.3520191
# {http://datacite.org/schema/kernel-3}subject educomunicação
# {http://datacite.org/schema/kernel-3}subject inclusão
# {http://datacite.org/schema/kernel-3}subject acessibilidade
# {http://datacite.org/schema/kernel-3}identifier 10.5281/zenodo.3520183
# {http://datacite.org/schema/kernel-3}subject educomunicação
# {http://datacite.org/schema/kernel-3}subject inclusão
# {http://datacite.org/schema/kernel-3}subject acessibilidade
# {http://datacite.org/schema/kernel-3}identifier 10.5281/zenodo.3519944
# {http://datacite.org/schema/kernel-3}identifier 10.5281/zenodo.3519468
# {http://datacite.org/schema/kernel-3}subject traditional narrative

# %% [markdown]
# ## Filtros

# %% [markdown]
# Registros entre dos fechas

# %%
import xml.etree.ElementTree as ET

bounds = "&from='2017-01-01'&until='2017-12-31'" #Para filtrar por fechas
oai = requests.get('https://zenodo.org/oai2d?verb=ListRecords&metadataPrefix=oai_datacite'+bounds)
xmlTree = ET.fromstring(oai.text)
iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag)
    print(elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH
#
#
# {http://www.openarchives.org/OAI/2.0/}responseDate
# 2020-01-05T22:45:51Z
# {http://www.openarchives.org/OAI/2.0/}request
# https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListRecords
#
#
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:34632
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T06:56:30Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.34632
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shanahan, Hugh
# {http://datacite.org/schema/kernel-3}affiliation
# Royal Holloway, University of London
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Presentation on Hadoop and the Map=-Reduce formalism
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2015
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Hadoop, Map-Reduce
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2015-12-03
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0 International
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>This is a talk on Hadoop and Map-Reduce given at the ISI in Bangalore.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:34633
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T06:56:31Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.34633
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shanahan, Hugh
# {http://datacite.org/schema/kernel-3}affiliation
# Royal Holloway, University of London
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Presentation on R
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2015
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# R
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2015-12-03
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0 International
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>This is a general and basic introduction to R given at the ISI in Bangalore, India.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:11358
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T06:47:04Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-zenodo
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.11358
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shore
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Writing a scientic papers
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-08-20
# {http://datacite.org/schema/kernel-3}resourceType
# Presentation
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/zenodo
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Closed Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Writing a scientific paper</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:10321
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T06:46:18Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-zenodo
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# https://zenodo.org/record/10321
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Segata, Michele
# {http://datacite.org/schema/kernel-3}affiliation
# DISI, University of Trento, Italy
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Supporting Platooning Maneuvers through IVC: An Initial Protocol Analysis for the Join Maneuver
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Platooning, Cooperative Driving, Vehicular Communications
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-06-04
# {http://datacite.org/schema/kernel-3}resourceType
# Conference paper
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.1109/WONS.2014.6814733
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/zenodo
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Closed Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Driving<em> </em>vehicles in platoons has the potential to improve traffic efficiency, increase safety, reduce fuel consumption, and make driving experience more enjoyable. A lot of effort is being spent in the development of technologies, like radars, enabling automated cruise control following and ensuring emergency braking if the driver does not react in time; but these technologies alone do not empower real platooning. The initial idea of building dedicated infrastructures for platoons, has been set aside favouring the philosophy that foresees scenarios, where automated vehicles share the road with human-driven ones. This arises interesting new questions regarding the interactions between the two categories of vehicles. In this paper we focus on the analysis of interferences caused by non-automated vehicles during a JOIN maneuver. We define the application layer protocol to support the maneuver, together with situations that can prevent successful termination, and describe how they can be detected. The validity of the approach is proven by means of simulations, showing either that the maneuver can successfully be performed, or safely be aborted. Finally, we analyze the impact of the Packet Error Rate (PER) on the failure rate of the maneuver, showing that packet losses mainly affect the maneuver from a coordination point of view, rather than stability of the system, i.e., even at high loss rates, cars never violated a minimum safety distance.</p>
# {http://datacite.org/schema/kernel-3}description
# Published in:   2014 11th Annual Conference on Wireless On-demand Network Systems and Services (WONS),
# Date of Conference: 2-4 April 2014
# Page(s): 130 - 137
# Conference Location : Obergurgl, Austria
# Publisher: IEEE
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:8567
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T07:09:29Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-5400
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.8567
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# coisa
# {http://datacite.org/schema/kernel-3}affiliation
# linda
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Nexus 7 available sensors
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Nexus7  Android
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-03-30
# {http://datacite.org/schema/kernel-3}resourceType
# Presentation
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/5400
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Closed Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>The list of available sensors in the nexus 7 2013 device. Collected from the android own API</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:6923
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T07:08:55Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-zenodo
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# https://zenodo.org/record/6923
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Torbinio, Claudio
# {http://datacite.org/schema/kernel-3}affiliation
# Università Politecnica delle Marche
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Degano, Andrea
# {http://datacite.org/schema/kernel-3}affiliation
# Università Politecnica delle Marche
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Open source software in the healthcare system: a Case History Europe.
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2013
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Open source
# {http://datacite.org/schema/kernel-3}subject
# re-ingegnerizzazione
# {http://datacite.org/schema/kernel-3}subject
# sistemi informativi aziendali
# {http://datacite.org/schema/kernel-3}subject
# HIS
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2013-02-28
# {http://datacite.org/schema/kernel-3}language
# it
# {http://datacite.org/schema/kernel-3}resourceType
# Journal article
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/zenodo
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Closed Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# In Informatics, open source indicates a software whose authors (specifically, the rights holders) allow, indeed, and favor the free study and the modifications made by other independent programmers .
# This article describes the process of re-engineering the infrastructure and information systems, primarily or exclusively using open source software, in a large organization of the public sector in Ireland, Beaumont Hospital, Dublin at.
# The study identifies the main drivers of the organization: principle and pragmatism. It also offers an overview of the Italian background.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:45873
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T07:01:28Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-zenodo
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.45873
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Aigrain, Suzanne
# {http://datacite.org/schema/kernel-3}affiliation
# University of Oxford
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Parviainen, Hannu
# {http://datacite.org/schema/kernel-3}affiliation
# University of Oxford
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Pope, Benjamin
# {http://datacite.org/schema/kernel-3}affiliation
# University of Oxford
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# EPIC212521166: a transiting planet candidate discovered in Campaign 6 data from the K2 Mission
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-02-10
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/zenodo
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0 International
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>In the process of visually inspecting&nbsp;a random selection of targets with Kepler magnitude Kp&lt;12 from K2 campaign 6, we identified&nbsp;EPIC 212521166 as a transiting planet candidate.&nbsp;&nbsp;</p>
#
# <p>The figure shows the K2 light curve of this object. The top and bottom panels show the SAP and PDC versions of the light curve, respectively. Both have been normalised by dividing them by their median, and only observations with null quality flag are shown.</p>
#
# <p>&nbsp;</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:45263
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T07:01:10Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.45263
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Hennings, Michael
# {http://datacite.org/schema/kernel-3}affiliation
# RWTH Aachen University
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Krämer, Jan-Peter
# {http://datacite.org/schema/kernel-3}affiliation
# RWTH Aachen University
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Brandt, Joel
# {http://datacite.org/schema/kernel-3}affiliation
# Creative Technologies Lab, Adobe Research
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Borchers, Jan
# {http://datacite.org/schema/kernel-3}affiliation
# RWTH Aachen University
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Programmatic Animations - Cheat Sheets
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Animations
# {http://datacite.org/schema/kernel-3}subject
# Programming paradigms
# {http://datacite.org/schema/kernel-3}subject
# Empirical studies
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-01-29
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0 International
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Complimentary material for the paper &quot;An empirical study of programming paradigms for animation&quot;:&nbsp;Cheat Sheets handed to participants in the study to explain the required APIs.&nbsp;</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:45144
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T07:01:07Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-intercrossing
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.45144
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Jan,Habib
# {http://datacite.org/schema/kernel-3}affiliation
# Plant Breeding Department Giessen
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# NHM London Live
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Genomic Selection,Genetics,Plant Breeding
# {http://datacite.org/schema/kernel-3}contributors
#
#
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# Jan,Habib
# {http://datacite.org/schema/kernel-3}affiliation
# Plant Breeding Department Giessen
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-01-25
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/intercrossing
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0 International
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Public outreach activity in NHM London Live.<br />
# &nbsp;</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:44730
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T07:00:55Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.44730
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Cousin IT
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Mystery
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-01-14
# {http://datacite.org/schema/kernel-3}resourceType
# Photo
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Zero v1.0 Universal
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Unknown</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:45308
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-11-02T15:12:59Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.45308
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Graham Findlay
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Bo Marchman
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Giulio Tononi
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# iit-pseudocode v1.0
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-01-29
# {http://datacite.org/schema/kernel-3}resourceType
# Technical note
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/CSC-UW/iit-pseudocode/tree/v1.0
# {http://datacite.org/schema/kernel-3}version
# v1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Closed Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Pseudocode for the major algorithms of Integrated Information Theory</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:44962
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T07:01:02Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.44962
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Miozzo, Marco
# {http://datacite.org/schema/kernel-3}affiliation
# CTTC
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Giupponi, Lorenza
# {http://datacite.org/schema/kernel-3}affiliation
# CTTC
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Rossi, Michele
# {http://datacite.org/schema/kernel-3}affiliation
# University of Padova
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Dini, Paolo
# {http://datacite.org/schema/kernel-3}affiliation
# CTTC
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Smart Energy Management in Mobile Networks Powered with Renewable Energies
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2015
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# energy efficiency
# {http://datacite.org/schema/kernel-3}subject
# energy harvesting
# {http://datacite.org/schema/kernel-3}subject
# energy trading
# {http://datacite.org/schema/kernel-3}subject
# ICT
# {http://datacite.org/schema/kernel-3}subject
# mobile networks
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2015-07-07
# {http://datacite.org/schema/kernel-3}resourceType
# Conference paper
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Closed Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Energy efficiency in cellular networks is becoming a key requirement for network operators to reduce their cost and to mitigate the carbon footprint of Information and Communication Technologies (ICT) on the environment. Costs and greenhouse gases emissions due to ICT grew in the last few years due to the escalation of traffic demand from mobile devices such as smartphones and tablets [1]. Network designers have been addressing this by considering hierarchical cell structures, through the so called heterogeneous networks (HetNets), where small cells are deployed to increase network capacity and decrease the overall energy consumption [2].<br />
# This paper aims to present new scenarios where harvested ambient energy is employed to steer HetNets toward nearly-zero energy consumption paradigm. With the term nearly-zero we mean that, in the long run, the costs incurred in operating the network are counterbalanced by the revenue from either grid energy savings or energy trading. The viability of a self-sustainable small cell networks has been discussed in [3] and can be achieved through the addition of rechargeable batteries and energy harvesting devices, such as solar panels. Here, we approach HetNets design from two different perspectives:<br />
#  Smart energy management for self-powering part of the network with auto-configuration capabilities thanks to machine learning techniques. The intermittent and erratic nature typical of renewable energies together with the variable traffic demand can be used for optimizing the network elements usage according to the actual network behavior, avoiding the over dimensioning of the system, thus reducing the cost of the equipment, deployment and maintenance. We show that machine learning solution can effectively adapt to changing environmental conditions and improve the energy efficiency of the system.<br />
#  Energy trading with the electricity grid or with other network elements. HetNets will operate within an energy market where the price of energy changes hourly and is set a day-ahead (as already done in Illinois nowadays). This allows for several new optimizations related to the way energy is consumed, purchased and possibly sold to the grid operator. Thus, we analyze whether the costs of providing these BSs with the needed solar add-on can be amortized and how long it takes to return the initial investments.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:44786
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T07:00:57Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.44786
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Cuevas-González, Maria
# {http://datacite.org/schema/kernel-3}affiliation
# CTTC
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Devanthéry, Núria
# {http://datacite.org/schema/kernel-3}affiliation
# CTTC
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Crosetto, Michele
# {http://datacite.org/schema/kernel-3}affiliation
# CTTC
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Monserrat, Oriol
# {http://datacite.org/schema/kernel-3}affiliation
# CTTC
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Crippa, Bruno
# {http://datacite.org/schema/kernel-3}affiliation
# University of Milan
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# The PSIG procedure to Persistent Scatterer Interferometry (PSI) using X-band and C-band Sentinel-1 data
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2015
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# PSI
# {http://datacite.org/schema/kernel-3}subject
# C-band
# {http://datacite.org/schema/kernel-3}subject
# Sentinel-1
# {http://datacite.org/schema/kernel-3}subject
# Terrasar-X
# {http://datacite.org/schema/kernel-3}subject
# deformation measurement
# {http://datacite.org/schema/kernel-3}subject
# X-band
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2015-09-21
# {http://datacite.org/schema/kernel-3}resourceType
# Conference paper
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Closed Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>A new approach to Persistent Scatterer Interferometry (PSI) data processing and analysis implemented in the PSI chain of the Geomatics (PSIG) Division of CTTC is used in this work. The flexibility of the PSIG procedure allowed evaluating two different processing chains of the PSIG procedure. A full PSIG procedure was implemented in the TerraSAR-X dataset while a reduced PSIG procedure was applied to the nine Sentinel-1 images available at the time of processing. The performance of the PSIG procedure is illustrated using X-band and C-band Sentinel-1 data and several examples of deformation maps covering different types of deformation phenomena are shown.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:32390
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T06:55:34Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-ecfunded
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-naclim
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.32390
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Royal Netherlands Institute for Sea Research
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# NACLIM | North Atlantic Climate, EU FP7 project (2012 - 2017)
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# OSNAP - Overturning in the Subpolar North Atlantic Programme
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# ‘Go with the flow': Research on the current in the subpolar North Atlantic
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2015
# {http://datacite.org/schema/kernel-3}contributors
#
#
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/308299/
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2015-10-19
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/naclim
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/ecfunded
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p><strong>Contribution from NIOZ<sup>1)</sup> - NACLIM - OSNAP<sup>2)</sup></strong> | Summer 2015, a film made to demonstrate the work carried out in the subpolar gyre by scientists from various large-scale collaborative projects, and to raise social awareness of the&nbsp;significance of observation/the role of North Atlantic ocean in our life.<br />
# Summary about the film (NIOZ): Oceanographic research carried out in the North Atlantic Ocean is of great importance to understand the role of the ocean in our climate and future climate change. Scientists collaborate in large international projects in order to <strong>continuously measure</strong> the subpolar Atlantic at key geographical locations.</p>
# {http://datacite.org/schema/kernel-3}description
# Visit the film on YouTube: https://youtu.be/a-lhCIQjE4c
# Contact person: Laura de Steur, NIOZ
#
# 1) NIOZ: Royal Netherlands Institute for Sea Research
#
# 2) OSNAP:Overturning in the Subpolar North Atlantic Program - an international program designed to provide a continuous record of the full-water column, trans-basin fluxes of heat, mass and freshwater in the subpolar North Atlantic.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:30653
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T06:54:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# https://zenodo.org/record/30653
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Lopes, Duarte Barroso
# {http://datacite.org/schema/kernel-3}affiliation
# School of Engineering – Polytechnic of Porto, Rua Dr. António Bernardino de Almeida 431, 4200-072 Porto, Portugal; Wood Biology and Wood Products, Büsgenweg 4 - 37077, Germany
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Mai, Carsten
# {http://datacite.org/schema/kernel-3}affiliation
# Wood Biology and Wood Products, Büsgenweg 4 - 37077, Germany
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Militz, Holger
# {http://datacite.org/schema/kernel-3}affiliation
# Wood Biology and Wood Products, Büsgenweg 4 - 37077, Germany
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Bending creep of Maritime pine wood (Pinus pinaster Ait.) chemically modified
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2013
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# chemical modification
# {http://datacite.org/schema/kernel-3}subject
# creep factor
# {http://datacite.org/schema/kernel-3}subject
#  indoor climate
# {http://datacite.org/schema/kernel-3}subject
# saturated conditions
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2013-09-01
# {http://datacite.org/schema/kernel-3}resourceType
# Journal article
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.2478/ffp-2013-0013
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Closed Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>The long-term performance of a structural member is determined by its durability and deformation with time. The bending creep behaviour of modified wood was assessed experimentally over a period of 35 days (840 hours). Four chemical modification processes were used: 1,3-dimethylol-4,5-dihydroxyethyleneurea (DMDHEU), mmethylated melamine formaldehyde resin (MMF), tetraethoxysilane (TEOS) and amid wax (WA). Wood stakes with 20.10.200 mm RTL dimensions of Portuguese Maritime pine (Pinus pinaster Ait.) from sapwood part of the stem<br />
# were used for evaluated the primary creep. Experiments were conducted at bending stresses amounting to 0.1, 0.2, 0.4 of the mean immediate wood bending strength obtained at equilibrium moisture content (EMC). Applying the same stress level (SL, 0.2), wood creep was also determined at the constant low and high moisture content. As results: Between low and medium SL (8 and 16 N/mm2), unmodified wood at indoors conditions did not show any effect in the creep factors (kc). However, at high SL (35 N/mm2) a slight increase (not significant) in the kc was found. It seems that the kc was nearly independent of the SL. In the lumen fill modification (TEOS and wax), the deposited material has not affected the creep behaviour under various SL. The cell wall modification (with DMDHEU and MMF resins) did not show any differences in the kc for low and<br />
# medium SL (8 and 16 N/mm2). However, resin modification under high SL (35 N/mm2) has shown a significant reduction related to unmodified wood. Between both types of resin (DMDHEU and MMF) and levels of modification (WPG), significant effect was not found. At saturated conditions, lumen fill modification (TEOS and wax) did not show any effect on creep. In the cell wall modification (DMDHEU and MMF resin), significant reduction was recorded due to the embrittlement effect imparted by the modification (deposit of resin in the cell wall)</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:35748
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T06:57:01Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.35748
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Nemo
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Non
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2015
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2015-12-28
# {http://datacite.org/schema/kernel-3}resourceType
# Presentation
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.44460
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Closed Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>null</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:44421
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-08T08:01:05Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.44421
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Kartsakli, Elli
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Antonopoulos, Angelos
# {http://datacite.org/schema/kernel-3}affiliation
# CTTC
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Verikoukis, Christos
# ...
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:12607
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T06:47:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-zenodo
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.12607
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Schmid, Moritz
# {http://datacite.org/schema/kernel-3}affiliation
# Takuvik Joint International Laboratory (U. Laval, Canada & CNRS, France) and Québec-Océan, Département de Biologie, Université Laval
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Aubry, Cyril
# {http://datacite.org/schema/kernel-3}affiliation
# Takuvik Joint International Laboratory (U. Laval, Canada & CNRS, France) and Québec-Océan, Département de Biologie, Université Laval
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Grigor, Jordan
# {http://datacite.org/schema/kernel-3}affiliation
# Takuvik Joint International Laboratory (U. Laval, Canada & CNRS, France) and Québec-Océan, Département de Biologie, Université Laval
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Fortier, Louis
# {http://datacite.org/schema/kernel-3}affiliation
# Takuvik Joint International Laboratory (U. Laval, Canada & CNRS, France) and Québec-Océan, Département de Biologie, Université Laval
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Zooplankton imaging with the Lightframe On-sight Keyspecies Investigation (LOKI) system
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Optical imaging
# {http://datacite.org/schema/kernel-3}subject
# Oceanography
# {http://datacite.org/schema/kernel-3}subject
# Zooplankton
# {http://datacite.org/schema/kernel-3}subject
# Automatic identification
# {http://datacite.org/schema/kernel-3}subject
# Machine learning
# {http://datacite.org/schema/kernel-3}subject
# Random Forest
# {http://datacite.org/schema/kernel-3}subject
# Lightframe On-sight Keyspecies Investigation (LOKI) System
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-11-06
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/zenodo
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution Non Commercial Share Alike 4.0 International
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>A video presentation on how to build detailed automatic identification models from LOKI zooplankton imagery&nbsp;and how to validate them as well as an introduction to the double filtering algorithm that was developed in our lab. Concluding with some ecological data.&nbsp;This presentation was recorded for the&nbsp;5&egrave;me Rencontre des Technologies Marines.</p>
#
# <p>https://projets.dt.insu.cnrs.fr/formations/2014_techmar/</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:18421
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T06:51:02Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.18421
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# 5
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# h
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2015
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2015-06-09
# {http://datacite.org/schema/kernel-3}resourceType
# Photo
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.610239
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0 International
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>5</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:18329
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T06:50:58Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-nescent
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.18329
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# NESCent Directors
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# NESCent's NSF Site Visit Documents for 2006-2013
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2013
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# site visit
# {http://datacite.org/schema/kernel-3}subject
# synthesis center
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2013-06-06
# {http://datacite.org/schema/kernel-3}resourceType
# Report
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/nescent
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Restricted Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Documents from the 2006, 2008, 2009, 2011, and 2013 site visits to NESCent of the National Science Foundation (NSF). The documents include&nbsp;self-study (2008), site visit team reports, and NESCent&#39;s responses to site visit team&nbsp;reports.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:18322
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T06:50:59Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.18322
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Dunn
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Folketonemesse - Credo
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2015
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2015-06-05
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Restricted Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>SATB + Solo</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:18320
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T06:50:58Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-cng
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.18320
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Dunn
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Folketonemesse - Agnus dei
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2015
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2015-06-05
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/cng
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Closed Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>SATB</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:18317
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T06:50:58Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-cng
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.18317
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Dunn
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Folketonemesse - Kyrie
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2015
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2015-06-05
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/cng
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0 International
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>SATB</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:18318
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-09-06T06:50:58Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-cng
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.18318
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Dunn
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Folketonemesse - Gloria
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2015
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2015-06-05
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/cng
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>SATB</p>
# {http://www.openarchives.org/OAI/2.0/}resumptionToken
# .eJxVjM0KgkAYRd_lW1uMv5DgIisJIUiztDYy6SiDTg4zU0biu6ftust7zr0DSEJKcNHSRo7pGI6JjJVtIcvUQBaia9ucThi2WaDfstCOUruJ2QVdjdpf__JZiP0hvbNWxTuFojM_lSzYJInPk4ZbVz0Mbr3ngQYc1wRcQ4Omx6KW4A5QiY5N55wIRqWkLzJpjChcYoWPglT0PdEO03wuCqpm_nwo2v6PxvELf_8_9A.XhJnHw.wPSgAkSowiEO1xr_2bdXyos70j0

# %% [markdown]
# ### GetRecord
#
# This verb is used to retrieve an individual metadata record from a repository. Required arguments specify the identifier of the item from which the record is requested and the format of the metadata that should be included in the record. Depending on the level at which a repository tracks deletions, a header with a "deleted" value for the status attribute may be returned, in case the metadata format specified by the metadataPrefix is no longer available from the repository or from the specified item.
#
# Obtener objeto digital de ese recurso

# %%
import xml.etree.ElementTree as ET
import urllib
#https://zenodo.org/oai2d?verb=GetRecord&metadataPrefix=oai_dc&identifier=oai:zenodo.org:252670
oai = requests.get('https://zenodo.org/oai2d?verb=GetRecord&metadataPrefix=oai_datacite&identifier=oai:zenodo.org:252977')
xmlTree = ET.fromstring(oai.text)
ns = {'oai' : 'http://www.openarchives.org/OAI/2.0/'}

#iterator = xmlTree.iter()
#for elem in iterator:
 #   print(elem.tag)
 #   print(elem.text)

for tags in xmlTree.findall('.//',ns):
    print (tags.tag+": ",tags.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}responseDate:  2020-01-05T22:45:53Z
# {http://www.openarchives.org/OAI/2.0/}request:  https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}GetRecord:
#
# {http://www.openarchives.org/OAI/2.0/}record:
#
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier:  oai:zenodo.org:252977
# {http://www.openarchives.org/OAI/2.0/}datestamp:  2019-04-10T04:00:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec:  user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata:
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite:
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality:  true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion:  3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol:  CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload:
#
# {http://datacite.org/schema/kernel-3}resource:
#
# {http://datacite.org/schema/kernel-3}identifier:  10.5281/zenodo.252977
# {http://datacite.org/schema/kernel-3}creators:
#
# {http://datacite.org/schema/kernel-3}creator:
#
# {http://datacite.org/schema/kernel-3}creatorName:  Harzhauser, Mathias
# {http://datacite.org/schema/kernel-3}creator:
#
# {http://datacite.org/schema/kernel-3}creatorName:  Landau, Bernard
# {http://datacite.org/schema/kernel-3}titles:
#
# {http://datacite.org/schema/kernel-3}title:  FIGURE 13A 1 –A 5 in A revision of the Neogene Conidae and Conorbidae (Gastropoda) of the Paratethys Sea
# {http://datacite.org/schema/kernel-3}publisher:  Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear:  2016
# {http://datacite.org/schema/kernel-3}subjects:
#
# {http://datacite.org/schema/kernel-3}subject:  Biodiversity
# {http://datacite.org/schema/kernel-3}subject:  Taxonomy
# {http://datacite.org/schema/kernel-3}subject:  Animalia
# {http://datacite.org/schema/kernel-3}subject:  Kalloconus
# {http://datacite.org/schema/kernel-3}dates:
#
# {http://datacite.org/schema/kernel-3}date:  2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType:  Figure
# {http://datacite.org/schema/kernel-3}alternateIdentifiers:
#
# {http://datacite.org/schema/kernel-3}alternateIdentifier:  https://zenodo.org/record/252977
# {http://datacite.org/schema/kernel-3}relatedIdentifiers:
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  http://treatment.plazi.org/id/373F87D7FFDCFFCDFF5FA9D9FC3046B3
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  http://treatment.plazi.org/id/373F87D7FFDBFFCAFF5FA8E1FA0B4762
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  http://treatment.plazi.org/id/373F87D7FFDBFFC8FF5FAE2DFDC5443D
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  10.11646/zootaxa.4210.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  urn:lsid:plazi.org:pub:CB06FFAFFF9FFF8EFFC8A876FF89416A
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  https://zenodo.org/record/252966
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  10.11646/zootaxa.4210.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  https://zenodo.org/record/252966
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-3}rightsList:
#
# {http://datacite.org/schema/kernel-3}rights:  Open Access
# {http://datacite.org/schema/kernel-3}descriptions:
#
# {http://datacite.org/schema/kernel-3}description:  FIGURE 13A 1 –A 5. Kalloconus ponderovagus (Sacco, 1893), Niederkreuzstetten (Austria), NHMW 1849/0004/0016, holotype. 13B 1 –B 3. Niederkreuzstetten (Austria), NHMW A991. 13C 1 –C 4. Kalloconus pseudohungaricus nov. sp., Lăpugiu de Sus (Romania), NHMW 1868/0001/0380a, paratype. 13D. Lăpugiu de Sus (Romania), Kalloconus pseudohungaricus nov. sp., NHMW 1868/0001/0380d, paratype. 13E 1 –E 3. Kalloconus pseudohungaricus nov. sp., Lăpugiu de Sus (Romania), NHMW 1868/0001/0380b, holotype. 13F 1 –F 2. Lăpugiu de Sus (Romania), Kalloconus pseudohungaricus nov. sp., NHMW 1868/0001/ 0380c, paratype. 13G 1 –G 5. Kalloconus tietzei (Hoernes &amp; Auinger, 1879), NHMW 1847/0046/0004, Szob (Hungary), holotype.

# %%
import xml.etree.ElementTree as ET
#https://zenodo.org/oai2d?verb=GetRecord&metadataPrefix=oai_dc&identifier=oai:zenodo.org:252670
headers = {'Accept': 'application/rdf+xml;q=0.5'} #Type of response accpeted
r = requests.post('https://dx.doi.org/10.5281/zenodo.252363', headers=headers) #POST with headers
print(r.text)

# %% [markdown]
# ## APIs específicas

# %% [markdown]
# El protocolo OAI-PMH ofrece una serie de funcionalidades genéricas e interoperables entre distintos repositorios. Sin embargo, existen ciertas limitaciones que no nos permiten automatizar todo lo necesario para analizar un gran número de dataset. Para ello, tenemos que recurrir a APIs específicas de los repositorios con los que trabajamos.
#
# Zenodo proporciona una API bastante completa que complementa al protocolo OAI-PMH. En el siguiente enlace podemos ver su especificación y algunos ejemplos con curl y python.
#
# http://developers.zenodo.org/
#
# Entre otras cosas, podemos automatizar el proceso de publicación, descargar archivos, etc.
#
# También, obteniendo el DOI de un recurso, podemos resolverlo para obtener cierta información específica, como la URL del objeto digital entre otras.

# %%
import json
#Buscamos datasets específicos-
oai = requests.get('https://zenodo.org/oai2d?verb=ListRecords&metadataPrefix=datacite3')
oaiTree = ET.fromstring(oai.text)
#for i in oaiTree.iter():
#    print(i.tag)
records = oaiTree.findall('.//{http://www.openarchives.org/OAI/2.0/}record')
for e in records:
    for subject in e.findall('.//{http://datacite.org/schema/kernel-3}subject'):
        if "Animalia" in subject.text:
            print("Title: "+e.findall('.//{http://datacite.org/schema/kernel-3}title')[0].text)
            identifier = e.findall('.//{http://datacite.org/schema/kernel-3}identifier')[0].text
            print(identifier)
            print('\n')
            
headers = {'accept': 'application/json'}
r = requests.get('https://zenodo.org/api/records/958140',headers)
record = json.loads(r.text)
print(record['files'])
# Out:
# [{'bucket': 'b645a5fb-e996-42a3-aaf5-a3f7ce75e853', 'checksum': 'md5:89a9f58721a73523c1ae855025b81ad4', 'key': 'oo_32747.jpg', 'links': {'self': 'https://zenodo.org/api/files/b645a5fb-e996-42a3-aaf5-a3f7ce75e853/oo_32747.jpg'}, 'size': 1085074, 'type': 'jpg'}]

# %% [markdown]
# # Ejercicio

# %%
# Función para extraer el título, identificador y dirección de un recurso respecto en base a la url OAI de un repositorio y un término referente a un tema
def oaiSummary(url, term = None):
    oai = requests.get(url)
    oaiTree = ET.fromstring(oai.text)
    namespaces = {'xmlns': 'http://www.openarchives.org/OAI/2.0/', 
              'oai_dc': 'http://www.openarchives.org/OAI/2.0/oai_dc/', 
              'dc': 'http://purl.org/dc/elements/1.1/'}
    records = oaiTree.findall(".//xmlns:record", namespaces)
    for record in records:
        description = record.findall('.//xmlns:metadata/oai_dc:dc/dc:description', namespaces)
        identifier = record.findall('.//xmlns:header/xmlns:identifier', namespaces)
        title = record.findall('.//xmlns:metadata/oai_dc:dc/dc:title', namespaces)
        url = record.findall('.//xmlns:metadata/oai_dc:dc/dc:identifier', namespaces)
        if( (term is None) or ((term is not None) and (term.lower() in (description[0].text.lower() if (len(description) > 0) else ""))) ):
            print("Identificador: ", identifier[0].text if (len(identifier) > 0) else "")
            print("Título: ", title[0].text if (len(title) > 0) else "")
            print("Dirección recurso: ", url[0].text if (len(url) > 0) else "")
            print()

# %% [markdown]
# **1: Busca al menos dos repositorios digitales compatibles con OAI-PMH**

# %% [markdown]
# - UCrea Repositorio abierto de la Universidad de Cantabria: http://repositorio.unican.es/oai/request?verb=Identify
# - E-Prints Complutense http://eprints.ucm.es/cgi/oai2?verb=Identify

# %% [markdown]
# **2: Utiliza los verbos del protocolo para encontrar los recursos de un tema en concreto (puedes buscar en la descripción o en las palabras clave)**

# %%
# Repositorio UNICAN con tema "web"
oaiSummary("https://repositorio.unican.es/oai/request?verb=ListRecords&metadataPrefix=oai_dc", "web")
# Out:
# Identificador:  oai:repositorio.unican.es:10902/436
# Título:  Propuesta de plataforma para la medición y el análisis del impacto de las herramientas 2.0 en los resultados empresariales
# Dirección recurso:  http://hdl.handle.net/10902/436
#
# Identificador:  oai:repositorio.unican.es:10902/437
# Título:  Web 2.0: blogs, redes sociales y microblogging en las empresas de telefonía móvil en España
# Dirección recurso:  http://hdl.handle.net/10902/437
#
# Identificador:  oai:repositorio.unican.es:10902/443
# Título:  Capital relacional virtual: una nueva aproximación al desarrollo tecnológico y su aplicación a la UE-15 y las regiones de los países del arco atlántico
# Dirección recurso:  http://hdl.handle.net/10902/443
#
# Identificador:  oai:repositorio.unican.es:10902/446
# Título:  Comunicuo*, agencia de publicidad
# Dirección recurso:  http://hdl.handle.net/10902/446
#
# Identificador:  oai:repositorio.unican.es:10902/445
# Título:  Social customer relationship management - CRM social
# Dirección recurso:  http://hdl.handle.net/10902/445
#
# Identificador:  oai:repositorio.unican.es:10902/496
# Título:  La conducta suicida en la mujer
# Dirección recurso:  http://hdl.handle.net/10902/496
#
# Identificador:  oai:repositorio.unican.es:10902/497
# Título:  Conducta suicida en las mujeres
# Dirección recurso:  http://hdl.handle.net/10902/497

# %%
# Repositorio Eprints UCM con tema "Unión Europea"
oaiSummary("http://eprints.ucm.es/cgi/oai2?verb=ListRecords&metadataPrefix=oai_dc", "Unión Europea")
# Out:
# Identificador:  oai:www.ucm.es:1525
# Título:  Turquía y la Unión Europea
# Dirección recurso:  https://eprints.ucm.es/1525/1/Turqu%C3%ADa_y_Uni%C3%B3n_Europea.pdf

# %% [markdown]
# **3: Obtén un listado de los títulos, identificadores (DOI o cualquier otro) y la dirección del recurso**

# %%
# Repositorio UNICAN
oaiSummary("https://repositorio.unican.es/oai/request?verb=ListRecords&metadataPrefix=oai_dc")
# Out:
# Identificador:  oai:repositorio.unican.es:10902/436
# Título:  Propuesta de plataforma para la medición y el análisis del impacto de las herramientas 2.0 en los resultados empresariales
# Dirección recurso:  http://hdl.handle.net/10902/436
#
# Identificador:  oai:repositorio.unican.es:10902/437
# Título:  Web 2.0: blogs, redes sociales y microblogging en las empresas de telefonía móvil en España
# Dirección recurso:  http://hdl.handle.net/10902/437
#
# Identificador:  oai:repositorio.unican.es:10902/442
# Título:  Vigilancia tecnológica: diseño e implantación de un sistema de vigilancia tecnológica en una empresa del sector de los ascensores
# Dirección recurso:  http://hdl.handle.net/10902/442
#
# Identificador:  oai:repositorio.unican.es:10902/443
# Título:  Capital relacional virtual: una nueva aproximación al desarrollo tecnológico y su aplicación a la UE-15 y las regiones de los países del arco atlántico
# Dirección recurso:  http://hdl.handle.net/10902/443
#
# Identificador:  oai:repositorio.unican.es:10902/446
# Título:  Comunicuo*, agencia de publicidad
# Dirección recurso:  http://hdl.handle.net/10902/446
#
# Identificador:  oai:repositorio.unican.es:10902/445
# Título:  Social customer relationship management - CRM social
# Dirección recurso:  http://hdl.handle.net/10902/445
#
# Identificador:  oai:repositorio.unican.es:10902/448
# Título:  Plan de marketing "La Alquitara"
# Dirección recurso:  http://hdl.handle.net/10902/448
#
# Identificador:  oai:repositorio.unican.es:10902/447
# Título:  Plan de marketing "Enotours"
# Dirección recurso:  http://hdl.handle.net/10902/447
#
# Identificador:  oai:repositorio.unican.es:10902/449
# Título:  Plan de marketing Hotel-Restaurante El Castillo
# Dirección recurso:  http://hdl.handle.net/10902/449
#
# Identificador:  oai:repositorio.unican.es:10902/444
# Título:  El rol enfermero. Cambios más significativos entre ayudante técnico sanitario y diplomado universitario en Enfermería
# Dirección recurso:  http://hdl.handle.net/10902/444
#
# Identificador:  oai:repositorio.unican.es:10902/450
# Título:  Plan de cuidados estandarizado para pacientes operados de cataratas con facoemulsificación en cirugía mayor ambulatoria
# Dirección recurso:  http://hdl.handle.net/10902/450
#
# Identificador:  oai:repositorio.unican.es:10902/451
# Título:  Plan de cuidados estandarizado en la mujer con cáncer de mama sometida a mastectomía radical modificada
# Dirección recurso:  http://hdl.handle.net/10902/451
#
# Identificador:  oai:repositorio.unican.es:10902/452
# Título:  Estudio de viabilidad de una empresa de atención infantil a domicilio
# Dirección recurso:  http://hdl.handle.net/10902/452
#
# Identificador:  oai:repositorio.unican.es:10902/453
# Título:  El turismo rural como alternativa a la crisis económica
# Dirección recurso:  http://hdl.handle.net/10902/453
#
# Identificador:  oai:repositorio.unican.es:10902/454
# Título:  Revisiones bibliográficas: ventajas e inconvenientes de la aplicación de los modelos de enfermería en la práctica
# Dirección recurso:  http://hdl.handle.net/10902/454
#
# Identificador:  oai:repositorio.unican.es:10902/455
# Título:  Influencia de los determinantes sociales en la salud: impacto en la población española
# Dirección recurso:  http://hdl.handle.net/10902/455
#
# Identificador:  oai:repositorio.unican.es:10902/456
# Título:  Responsabilidad social corporativa: un análisis de incentivos de mercado
# Dirección recurso:  http://hdl.handle.net/10902/456
#
# Identificador:  oai:repositorio.unican.es:10902/457
# Título:  Concentración y eficiencia bancaria en el nuevo entorno competitivo
# Dirección recurso:  http://hdl.handle.net/10902/457
#
# Identificador:  oai:repositorio.unican.es:10902/458
# Título:  Monografía del dolor agudo postoperatorio
# Dirección recurso:  http://hdl.handle.net/10902/458
#
# Identificador:  oai:repositorio.unican.es:10902/459
# Título:  Monografía de vías clínicas
# Dirección recurso:  http://hdl.handle.net/10902/459
#
# Identificador:  oai:repositorio.unican.es:10902/470
# Título:  Constitución de un restaurante de pinchos
# Dirección recurso:  http://hdl.handle.net/10902/470
#
# Identificador:  oai:repositorio.unican.es:10902/460
# Título:  Monografía sobre las emociones en el parto
# Dirección recurso:  http://hdl.handle.net/10902/460
#
# Identificador:  oai:repositorio.unican.es:10902/461
# Título:  Importancia del apego en la etapa infantil
# Dirección recurso:  http://hdl.handle.net/10902/461
#
# Identificador:  oai:repositorio.unican.es:10902/462
# Título:  Plan de cuidados estandarizado de un paciente con EPOC
# Dirección recurso:  http://hdl.handle.net/10902/462
#
# Identificador:  oai:repositorio.unican.es:10902/463
# Título:  Monografía sobre la prevención del sobrepeso y la obesidad infanto-juvenil entre niños de 2-17 años
# Dirección recurso:  http://hdl.handle.net/10902/463
#
# Identificador:  oai:repositorio.unican.es:10902/464
# Título:  La seguridad clínica del paciente: la importancia de una cirugía segura
# Dirección recurso:  http://hdl.handle.net/10902/464
#
# Identificador:  oai:repositorio.unican.es:10902/465
# Título:  Biología celular del folículo tiroideo
# Dirección recurso:  http://hdl.handle.net/10902/465
#
# Identificador:  oai:repositorio.unican.es:10902/466
# Título:  Monografía sobre caidas en el anciano
# Dirección recurso:  http://hdl.handle.net/10902/466
#
# Identificador:  oai:repositorio.unican.es:10902/467
# Título:  Hipertensión arterial y disfunción endotelial: un barómetro de la salud cardiovascular
# Dirección recurso:  http://hdl.handle.net/10902/467
#
# Identificador:  oai:repositorio.unican.es:10902/468
# Título:  Incontinencia urinaria femenina
# Dirección recurso:  http://hdl.handle.net/10902/468
#
# Identificador:  oai:repositorio.unican.es:10902/469
# Título:  Monografía sobre desarrollo disciplinar y rol enfermero en la atención gerontológica
# Dirección recurso:  http://hdl.handle.net/10902/469
#
# Identificador:  oai:repositorio.unican.es:10902/471
# Título:  Seguridad en el paciente quirúrgico
# Dirección recurso:  http://hdl.handle.net/10902/471
#
# Identificador:  oai:repositorio.unican.es:10902/472
# Título:  Terapia renal sustitutiva
# Dirección recurso:  http://hdl.handle.net/10902/472
#
# Identificador:  oai:repositorio.unican.es:10902/476
# Título:  Errores de medicación: calidad de cuidados
# Dirección recurso:  http://hdl.handle.net/10902/476
#
# Identificador:  oai:repositorio.unican.es:10902/478
# Título:  Monografía sobre la violencia de género
# Dirección recurso:  http://hdl.handle.net/10902/478
#
# Identificador:  oai:repositorio.unican.es:10902/475
# Título:  Análisis de la biocontaminación de las superficies hospitalarias
# Dirección recurso:  http://hdl.handle.net/10902/475
#
# Identificador:  oai:repositorio.unican.es:10902/474
# Título:  Monografía sobre el consentimiento informado
# Dirección recurso:  http://hdl.handle.net/10902/474
#
# Identificador:  oai:repositorio.unican.es:10902/473
# Título:  Barreras de acceso al sistema sanitario para el colectivo inmigrante
# Dirección recurso:  http://hdl.handle.net/10902/473
#
# Identificador:  oai:repositorio.unican.es:10902/479
# Título:  La cesárea : ¿qué hay detrás de la intervención?
# Dirección recurso:  http://hdl.handle.net/10902/479
#
# Identificador:  oai:repositorio.unican.es:10902/477
# Título:  Motivación y satisfacción de los profesionales de enfermería : investigación aplicada en un área quirúrgica
# Dirección recurso:  http://hdl.handle.net/10902/477
#
# Identificador:  oai:repositorio.unican.es:10902/480
# Título:  El duelo : cuidados enfermeros en el duelo hospitalario
# Dirección recurso:  http://hdl.handle.net/10902/480
#
# Identificador:  oai:repositorio.unican.es:10902/481
# Título:  Monografía sobre la biología de la celula parietal del estómago
# Dirección recurso:  http://hdl.handle.net/10902/481
#
# Identificador:  oai:repositorio.unican.es:10902/482
# Título:  Estudio de viabilidad de la concesión de una terminal de contenedores en el puerto de Santander
# Dirección recurso:  http://hdl.handle.net/10902/482
#
# Identificador:  oai:repositorio.unican.es:10902/483
# Título:  Hábitos alimentarios de la población inmigrante en España
# Dirección recurso:  http://hdl.handle.net/10902/483
#
# Identificador:  oai:repositorio.unican.es:10902/484
# Título:  Plan de cuidados estándar de enfermería en pacientes cistectomizados: neovejiga tipo studer
# Dirección recurso:  http://hdl.handle.net/10902/484
#
# Identificador:  oai:repositorio.unican.es:10902/485
# Título:  Los determinantes de salud de las cuidadoras informales de personas dependientes: repercusiones y desigualdades en salud
# Dirección recurso:  http://hdl.handle.net/10902/485
#
# Identificador:  oai:repositorio.unican.es:10902/486
# Título:  La adherencia al tratamiento: el caso de la diabetes mellitus tipo 2
# Dirección recurso:  http://hdl.handle.net/10902/486
#
# Identificador:  oai:repositorio.unican.es:10902/487
# Título:  La enfermería comunitaria ante una enfermedad crónica: la hipertensión arterial
# Dirección recurso:  http://hdl.handle.net/10902/487
#
# Identificador:  oai:repositorio.unican.es:10902/488
# Título:  Equidad de género: nuevas perspectivas sobre la salud
# Dirección recurso:  http://hdl.handle.net/10902/488
#
# Identificador:  oai:repositorio.unican.es:10902/489
# Título:  Trasplante de médula ósea
# Dirección recurso:  http://hdl.handle.net/10902/489
#
# Identificador:  oai:repositorio.unican.es:10902/490
# Título:  Regulación del peso corporal : aspectos genéticos
# Dirección recurso:  http://hdl.handle.net/10902/490
#
# Identificador:  oai:repositorio.unican.es:10902/498
# Título:  Creación de una consultora de compras para microempresas y pequeñas empresas en Cantabria. Ats Consulting
# Dirección recurso:  http://hdl.handle.net/10902/498
#
# Identificador:  oai:repositorio.unican.es:10902/491
# Título:  El entrenamiento de los equipos quirúrgicos mediante la simulación, mejora la seguridad del paciente
# Dirección recurso:  http://hdl.handle.net/10902/491
#
# Identificador:  oai:repositorio.unican.es:10902/492
# Título:  Errores relacionados con la administración de medicación en el Servicio de Urgencias del Hospital Universitario Marques de Valdecilla
# Dirección recurso:  http://hdl.handle.net/10902/492
#
# Identificador:  oai:repositorio.unican.es:10902/493
# Título:  Monografía de carga mundial de enfermedad cardiovascular
# Dirección recurso:  http://hdl.handle.net/10902/493
#
# Identificador:  oai:repositorio.unican.es:10902/494
# Título:  Maltrato en el anciano
# Dirección recurso:  http://hdl.handle.net/10902/494
#
# Identificador:  oai:repositorio.unican.es:10902/495
# Título:  Condición física en niños y adolescentes con sobrepeso u obesidad
# Dirección recurso:  http://hdl.handle.net/10902/495
#
# Identificador:  oai:repositorio.unican.es:10902/496
# Título:  La conducta suicida en la mujer
# Dirección recurso:  http://hdl.handle.net/10902/496
#
# Identificador:  oai:repositorio.unican.es:10902/497
# Título:  Conducta suicida en las mujeres
# Dirección recurso:  http://hdl.handle.net/10902/497
#
# Identificador:  oai:repositorio.unican.es:10902/499
# Título:  First-order nature of the ferromagnetism in CeIn2 investigated using muon spin rotation and by systematic substitution of La for Ce
# Dirección recurso:  1098-0121
#
# Identificador:  oai:repositorio.unican.es:10902/503
# Título:  Sinusoidal magnetic structure in a three-dimensional antiferromagnetic Co2(OH)AsO4: Incommensurate-commensurate magnetic phase transition
# Dirección recurso:  1098-0121
#
# Identificador:  oai:repositorio.unican.es:10902/520
# Título:  Reduction of the Yb valence in YbAl3 nanoparticles
# Dirección recurso:  1098-0121
#
# Identificador:  oai:repositorio.unican.es:10902/500
# Título:  Proyecto de viabilidad Centro Enoturístico Valle de Mencía
# Dirección recurso:  http://hdl.handle.net/10902/500
#
# Identificador:  oai:repositorio.unican.es:10902/501
# Título:  Ahorro y data centers : un estudio sobre sostenibilidad, implantación y viabilidad
# Dirección recurso:  http://hdl.handle.net/10902/501
#
# Identificador:  oai:repositorio.unican.es:10902/502
# Título:  Plan de viabilidad : nuevo concepto de restaurante al cuidado de tu salud
# Dirección recurso:  http://hdl.handle.net/10902/502
#
# Identificador:  oai:repositorio.unican.es:10902/509
# Título:  Origin of the (2)E <->(4)T(2) Fano resonance in Cr(3+)-doped LiCaAlF(6): Pressure-induced excited-state crossover.
# Dirección recurso:  1098-0121
#
# Identificador:  oai:repositorio.unican.es:10902/504
# Título:  Pressure-induced Jahn-Teller suppression in Rb2CuCl4( H2O )2: Pseudo-Jahn-Teller effect
# Dirección recurso:  1098-0121
#
# Identificador:  oai:repositorio.unican.es:10902/505
# Título:  Pressure effects on NaMnF4: Structural correlations and Jahn-Teller effect from crystal-field spectroscopy
# Dirección recurso:  1098-0121
#
# Identificador:  oai:repositorio.unican.es:10902/506
# Título:  Pressure-Induced Two-Color Photoluminescence in MnF2 at Room Temperature
# Dirección recurso:  0031-9007
#
# Identificador:  oai:repositorio.unican.es:10902/507
# Título:  Pressure-induced Jahn-Teller suppression and simultaneous high-spin to low-spin transition in the layered perovskite CsMnF4
# Dirección recurso:  1098-0121
#
# Identificador:  oai:repositorio.unican.es:10902/508
# Título:  Cluster model with random anisotropy for hysteresis jumps in CeNi1-xCux alloys
# Dirección recurso:  1098-0121
#
# Identificador:  oai:repositorio.unican.es:10902/510
# Título:  Influencia del polimorfismo Gln223Arg del receptor de leptina en el sobrepeso
# Dirección recurso:  http://hdl.handle.net/10902/510
#
# Identificador:  oai:repositorio.unican.es:10902/512
# Título:  Messaging performance of FIPA interaction protocols in networked embedded controllers
# Dirección recurso:  1687-3963
#
# Identificador:  oai:repositorio.unican.es:10902/511
# Título:  Embedded XML DOM parser: an approach for XML data processing on networked embedded systems with real-time requirements
# Dirección recurso:  1687-3963
#
# Identificador:  oai:repositorio.unican.es:10902/513
# Título:  Influencia del polimorfismo genético inserción/deleción del gen del enzima convertidor de la Angiotensina (ACE) sobre variables antropométricas y somatotipos en jugadores de balonmano
# Dirección recurso:  http://hdl.handle.net/10902/513
#
# Identificador:  oai:repositorio.unican.es:10902/514
# Título:  MAC and baseband processors for RF-MIMO WLAN
# Dirección recurso:  1687-1499
#
# Identificador:  oai:repositorio.unican.es:10902/518
# Título:  Code combination for blind channel estimation in general MIMO-STBC systems
# Dirección recurso:  1687-6180
#
# Identificador:  oai:repositorio.unican.es:10902/515
# Título:  Performance analysis of SNR-based scheduling policies in asymmetric broadcast ergodic fading channel
# Dirección recurso:  1687-1499
#
# Identificador:  oai:repositorio.unican.es:10902/517
# Título:  Adaptive kernel canonical correlation analysis algorithms for nonparametric identification of Wiener and Hammerstein systems
# Dirección recurso:  1687-6180
#
# Identificador:  oai:repositorio.unican.es:10902/519
# Título:  Modeling nonlinear power amplifiers in OFDM systems from subsampled data: a comparative study using real measurements
# Dirección recurso:  1687-6180
#
# Identificador:  oai:repositorio.unican.es:10902/516
# Título:  Adaptive access and rate control of CSMA for energy, rate and delay optimization
# Dirección recurso:  1687-1499
#
# Identificador:  oai:repositorio.unican.es:10902/521
# Título:  Accurate simulation of 802.11 indoor links: a “bursty” channel model based on real measurements
# Dirección recurso:  1687-1499
#
# Identificador:  oai:repositorio.unican.es:10902/522
# Título:  Imagen corporal y sobrecarga ponderal
# Dirección recurso:  http://hdl.handle.net/10902/522
#
# Identificador:  oai:repositorio.unican.es:10902/523
# Título:  Eficacia y fiabilidad de las pruebas diagnósticas de alergias alimentarias en niños madrileños: aspectos clínicos y dietéticos
# Dirección recurso:  http://hdl.handle.net/10902/523
#
# Identificador:  oai:repositorio.unican.es:10902/524
# Título:  Hábitos alimentarios de la población adolescente autóctona e inmigrante en España
# Dirección recurso:  http://hdl.handle.net/10902/524
#
# Identificador:  oai:repositorio.unican.es:10902/525
# Título:  Hábitos alimentarios en los adolescentes
# Dirección recurso:  http://hdl.handle.net/10902/525
#
# Identificador:  oai:repositorio.unican.es:10902/526
# Título:  Análisis transcripcional de Rhodococcus jostii durante la acumulación de triglicéridos
# Dirección recurso:  http://hdl.handle.net/10902/526
#
# Identificador:  oai:repositorio.unican.es:10902/529
# Título:  Efectos de la sobreexpresión de A1 en células T sobre el desarrollo de enfermedades autoinmunes
# Dirección recurso:  http://hdl.handle.net/10902/529
#
# Identificador:  oai:repositorio.unican.es:10902/528
# Título:  Construcción de una genoteca en "Phage Display" para la selección de efectores inmunes de Drosophila melanogaster
# Dirección recurso:  http://hdl.handle.net/10902/528
#
# Identificador:  oai:repositorio.unican.es:10902/527
# Título:  Relación entre vitamina D y péptidos antimicrobianos (Catelicidina y [beta]2 Defensina) en pacientes con trastornos de la conducta alimentaria
# Dirección recurso:  http://hdl.handle.net/10902/527
#
# Identificador:  oai:repositorio.unican.es:10902/530
# Título:  Bridging MoCs in SystemC specifications of heterogeneous systems
# Dirección recurso:  1687-3963
#
# Identificador:  oai:repositorio.unican.es:10902/531
# Título:  The lp13.3 genomic region -rs599839- is associated with endothelial dysfunction in patients with rheumatoid arthritis
# Dirección recurso:  1478-6354
#
# Identificador:  oai:repositorio.unican.es:10902/533
# Título:  CCR5Δ32 variant and cardiovascular disease in patients with rheumatoid arthritis: a cohort study
# Dirección recurso:  1478-6354
#
# Identificador:  oai:repositorio.unican.es:10902/534
# Título:  Association of acid phosphatase locus 1*C allele with the risk of cardiovascular events in rheumatoid arthritis patients
# Dirección recurso:  1478-6354
#
# Identificador:  oai:repositorio.unican.es:10902/535
# Título:  Correlation between endothelial function and carotid atherosclerosis in rheumatoid arthritis patients with long-standing disease
# Dirección recurso:  1478-6354
#
# Identificador:  oai:repositorio.unican.es:10902/536
# Título:  Response to 'Infliximab therapy increases body fat mass in early rheumatoid arthritis independently of changes in disease activity and levels of leptin and adiponectin: a randomized study over 21 months'
# Dirección recurso:  1478-6354
#
# Identificador:  oai:repositorio.unican.es:10902/537
# Título:  Role of carotid ultrasonography in the evaluation of cardiovascular risk in patients with rheumatoid arthritis
# Dirección recurso:  1478-6354
#
# Identificador:  oai:repositorio.unican.es:10902/538
# Título:  A1298C polymorphism in the MTHFR gene predisposes to cardiovascular risk in rheumatoid arthritis
# Dirección recurso:  1478-6354
#
# Identificador:  oai:repositorio.unican.es:10902/539
# Título:  Decrease in tobacco consumption after treatment with topiramate and aripiprazole: a case report
# Dirección recurso:  1752-1947
#
# Identificador:  oai:repositorio.unican.es:10902/540
# Título:  Carotid intima-media thickness and endothelial function: useful surrogate markers for establishing cardiovascular risk in patients with inflammatory rheumatic disease
# Dirección recurso:  1478-6354

# %%
# Repositorio Eprints UCM
oaiSummary("http://eprints.ucm.es/cgi/oai2?verb=ListRecords&metadataPrefix=oai_dc")
# Out:
# Identificador:  oai:www.ucm.es:45355
# Título:  La construcción del concepto de post-rock en España (1995-2001): el caso de Manta Ray
# Dirección recurso:  https://eprints.ucm.es/45355/1/Fellone%2C%20Ugo%20-%20Trabajo%20Fin%20de%20Master%20ePrints.pdf
#
# Identificador:  oai:www.ucm.es:45083
# Título:  The economic role of the State on the Spanish democratization and "development" process. A case of success?
# Dirección recurso:  https://eprints.ucm.es/45083/1/OP02-17.pdf
#
# Identificador:  oai:www.ucm.es:1
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:3
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:12
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:13
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:14
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:15
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:16
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:17
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:19
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:20
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:21
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:22
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:23
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:24
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1416
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1424
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1425
# Título:  La biblioteca pública en la sociedad de la información
# Dirección recurso:  https://eprints.ucm.es/1425/1/La_biblioteca_publica_en_la_sociedad_de_la_informacion.pdf
#
# Identificador:  oai:www.ucm.es:1428
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1429
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1442
# Título:  La dinámica de la justicia hasta 2001
# Dirección recurso:  https://eprints.ucm.es/1442/1/Dinamica_de_la_Justicia.pdf
#
# Identificador:  oai:www.ucm.es:1443
# Título:  Dynamic modality: English and Spanish contrasted
# Dirección recurso:  https://eprints.ucm.es/1443/3/Dynamic_modality.pdf
#
# Identificador:  oai:www.ucm.es:1444
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1446
# Título:  Disposiciones generales reguladoras de los tributos en la Ley General Tributaria
# Dirección recurso:  https://eprints.ucm.es/1446/1/Calvo_Ortega.pdf
#
# Identificador:  oai:www.ucm.es:1447
# Título:  El interés de demora en la nueva Ley General Tributaria
# Dirección recurso:  https://eprints.ucm.es/1447/1/Cayon_Galiardo.pdf
#
# Identificador:  oai:www.ucm.es:1448
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1452
# Título:  Devengo y determinación de la norma aplicable en la nueva ley general tributaria
# Dirección recurso:  https://eprints.ucm.es/1452/1/pon_3.pdf
#
# Identificador:  oai:www.ucm.es:1453
# Título:  La aplicación de los tributos en la ley general tributaria
# Dirección recurso:  https://eprints.ucm.es/1453/1/pon_4.pdf
#
# Identificador:  oai:www.ucm.es:1454
# Título:  Principales modificaciones relativas al pago de la deuda tributaria en la nueva ley general tributaria
# Dirección recurso:  https://eprints.ucm.es/1454/1/pon_5.pdf
#
# Identificador:  oai:www.ucm.es:1455
# Título:  La caducidad de los procedimientos
# Dirección recurso:  https://eprints.ucm.es/1455/1/pon_6.pdf
#
# Identificador:  oai:www.ucm.es:1456
# Título:  El nuevo régimen jurídico de las consultas tributarias
# Dirección recurso:  https://eprints.ucm.es/1456/1/pon_7.pdf
#
# Identificador:  oai:www.ucm.es:1457
# Título:  La responsabilidad por transmisión de empresa
# Dirección recurso:  https://eprints.ucm.es/1457/1/pon_8.pdf
#
# Identificador:  oai:www.ucm.es:1458
# Título:  La responsabilidad de los administradores en la nueva ley general tributaria
# Dirección recurso:  https://eprints.ucm.es/1458/1/pon_9.pdf
#
# Identificador:  oai:www.ucm.es:1459
# Título:  Derecho tributario sancionador: divorcio y reconciliación
# Dirección recurso:  https://eprints.ucm.es/1459/1/pon_10.pdf
#
# Identificador:  oai:www.ucm.es:1460
# Título:  La graduación de las sanciones en la nueva ley general tributaria
# Dirección recurso:  https://eprints.ucm.es/1460/1/pon_11.pdf
#
# Identificador:  oai:www.ucm.es:1461
# Título:  La sanción de los ingresos realizados fuera de plazo sin requerimiento previo: relaciones entre los arts. 27 y 191 de la nueva ley general tributaria
# Dirección recurso:  https://eprints.ucm.es/1461/1/pon_12.pdf
#
# Identificador:  oai:www.ucm.es:1462
# Título:  Principio de responsabilidad en materia de infracciones tributarias : causas eximentes
# Dirección recurso:  https://eprints.ucm.es/1462/1/pon_13.pdf
#
# Identificador:  oai:www.ucm.es:1463
# Título:  La iniciación a instancia del interesado de los procedimientos tributarios especiales de revisión
# Dirección recurso:  https://eprints.ucm.es/1463/1/pon_14.pdf
#
# Identificador:  oai:www.ucm.es:1464
# Título:  Esbozo sobre la revisión en la nueva ley general tributaria
# Dirección recurso:  https://eprints.ucm.es/1464/1/pon_15.pdf
#
# Identificador:  oai:www.ucm.es:1465
# Título:  Limitaciones a la impugnación de las liquidaciones derivadas de las actas con acuerdo
# Dirección recurso:  https://eprints.ucm.es/1465/1/pon_16.pdf
#
# Identificador:  oai:www.ucm.es:1466
# Título:  El defensor del contribuyente : ¿procedimiento para dar respuesta al principio de participación ciudadana, procedimiento de gestión o de revisión?
# Dirección recurso:  https://eprints.ucm.es/1466/1/pon_17.pdf
#
# Identificador:  oai:www.ucm.es:1469
# Título:  Estudio de la Duración de los Casos Civiles Presentados en los Juzgados de Argentina, Utilizando Análisis de Supervivencia. Una Primera Aproximación.
# Dirección recurso:  https://eprints.ucm.es/1469/1/Duracion_Asuntos_Civiles_Argentinos_Supervivencia.pdf
#
# Identificador:  oai:www.ucm.es:1473
# Título:  Complementation in english and spanish possessive verbs. Cognitive and contrastive study
# Dirección recurso:  https://eprints.ucm.es/1473/1/Articulo_rioja_8_International_cognitive_linguistics_confere.pdf
#
# Identificador:  oai:www.ucm.es:1475
# Título:  Metaphor in scientific language: a study on medical texts
# Dirección recurso:  https://eprints.ucm.es/1475/1/version_publicac.pdf
#
# Identificador:  oai:www.ucm.es:1483
# Título:  El aula del saber de Arequipa como formación de adultos para la creación de microempresas en el Perú
# Dirección recurso:  https://eprints.ucm.es/1483/1/Articulo_Revista_Cuadernos_de_Trabajo_Socail_08_%28revisado%29.pdf
#
# Identificador:  oai:www.ucm.es:1487
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1492
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1495
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1499
# Título:  EL "Examen de Ingenios" de Huarte de San Juan en la "Bibliotheca Selecta" de Antonio Possevino
# Dirección recurso:  https://eprints.ucm.es/1499/1/huarte-possevino.pdf
#
# Identificador:  oai:www.ucm.es:1500
# Título:  Huarte de San Juan, un adelantado a la teoría modular de la mente
# Dirección recurso:  https://eprints.ucm.es/1500/1/HUARTE_DE_SAN__JUAN.pdf
#
# Identificador:  oai:www.ucm.es:1501
# Título:  Neuropsicología y género
# Dirección recurso:  https://eprints.ucm.es/1501/1/NEUROPSICOLa.pdf
#
# Identificador:  oai:www.ucm.es:1502
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1503
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1504
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1505
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1506
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1507
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1508
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1509
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1510
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1511
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1512
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1513
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1514
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1515
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1516
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1517
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1518
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1520
# Título:  Seguimiento de la infección por el virus de maedivisna en una explotación de ganado ovino
# Dirección recurso:  https://eprints.ucm.es/1520/1/Tesina_Nieves.pdf
#
# Identificador:  oai:www.ucm.es:1525
# Título:  Turquía y la Unión Europea
# Dirección recurso:  https://eprints.ucm.es/1525/1/Turqu%C3%ADa_y_Uni%C3%B3n_Europea.pdf
#
# Identificador:  oai:www.ucm.es:1526
# Título:  Matrimonios entre homosexuales: imitando a Procustro
# Dirección recurso:  https://eprints.ucm.es/1526/1/Procustro.PDF
#
# Identificador:  oai:www.ucm.es:1527
# Título:  Los negocios de Banesto sobre sus acciones a examen judicial (STS, de 28 de mayo de 2001 y sus precedentes de Instancias)
#
# Dirección recurso:  https://eprints.ucm.es/1527/1/PA_AFBANESTO.pdf
#
# Identificador:  oai:www.ucm.es:1528
# Título:  La adquisición derivativa de acciones propias para su ofrecimiento a los administradores de las sociedades anóminas
# Dirección recurso:  https://eprints.ucm.es/1528/1/PA_APREF2000.pdf
#
# Identificador:  oai:www.ucm.es:1529
# Título:  "Acciones propias-reducción de capital" y el principio de paridad de trato de los accionistas
# Dirección recurso:  https://eprints.ucm.es/1529/1/PA_APYREDUCC.pdf
#
# Identificador:  oai:www.ucm.es:1530
# Título:  Nombres de dominio en Internet
# Dirección recurso:  https://eprints.ucm.es/1530/1/PA_CISSDOMIO2.pdf
#
# Identificador:  oai:www.ucm.es:1532
# Título:  Conflicto entre dominio en Internet y denominación de sociedad española
# Dirección recurso:  https://eprints.ucm.es/1532/1/PA_DSOCYDOMINIO.pdf
#
# Identificador:  oai:www.ucm.es:1533
# Título:  El leasing financiero internacional en el tratado UNIDROIT
# Dirección recurso:  https://eprints.ucm.es/1533/1/PA_LHDuque.pdf
#
# Identificador:  oai:www.ucm.es:1535
# Título:  Autocartera por persona interpuesta (Art. 88 del TRLSA, de 1989)
# Dirección recurso:  https://eprints.ucm.es/1535/1/PA_LHSCalero.pdf
#
# Identificador:  oai:www.ucm.es:1537
# Título:  Infraccion del deber de  promover una oferta publica de adquisicion de acciones y el juego de la suspensión de  derechos
# Dirección recurso:  https://eprints.ucm.es/1537/1/PA_OPAANACIONAL.pdf
#
# Identificador:  oai:www.ucm.es:1538
# Título:  Transparencia del mercado: adquisición de participaciones significativas en sociedades cotizadas
# Dirección recurso:  https://eprints.ucm.es/1538/1/PA_PSAB98.pdf
#
# Identificador:  oai:www.ucm.es:1539
# Título:  En torno a la concurrencia de relaciones laborales y societarias (Orientaciones de la jurisprudencia laboral)
# Dirección recurso:  https://eprints.ucm.es/1539/1/PA_SAPERSONAL.pdf
#
# Identificador:  oai:www.ucm.es:1541
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1542
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1543
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1545
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1546
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1547
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1548
# Título:  Convenio Concursal y reorganización de la Sociedad Anónima (Temario para un debate)
# Dirección recurso:  https://eprints.ucm.es/1548/1/comunicacion_msierra.pdf
#
# Identificador:  oai:www.ucm.es:1549
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1556
# Título:  Padres, alumnos, maestros.
# Cada uno en su lugar para poder educar
#
# Dirección recurso:  https://eprints.ucm.es/1556/1/articulo_revista_colegio_Cristo_Rey.pdf
#
# Identificador:  oai:www.ucm.es:1566
# Título:  Carta de una mujer y madre maltratada a su maltratador
# Dirección recurso:  https://eprints.ucm.es/1566/1/CARTA_DE_UNA_MUJER_Y_MADRE_MALTRATADA_A_SU_MALTRATADOR.pdf
#
# Identificador:  oai:www.ucm.es:1568
# Título:  Elementos epistemológicos para una metodología sistémico-relacional
# Dirección recurso:  https://eprints.ucm.es/1568/1/eprint2.pdf
#
# Identificador:  oai:www.ucm.es:1569
# Título:  El Trabajo Social desde el paradigma de la complejidad
# Dirección recurso:  https://eprints.ucm.es/1569/1/articulosin.pdf
#
# Identificador:  oai:www.ucm.es:1570
# Título:  Lo fenomenológico en la intervención socio-familiar
# Dirección recurso:  https://eprints.ucm.es/1570/1/eprint4.pdf
#
# Identificador:  oai:www.ucm.es:1571
# Título:  El Trabajador Social como coordinador de las Escuelas de Padres
# Dirección recurso:  https://eprints.ucm.es/1571/1/eprint5.pdf
#
# Identificador:  oai:www.ucm.es:1572
# Título:  El trabajo social clínico
# Dirección recurso:  https://eprints.ucm.es/1572/1/eprint3.pdf
#
# Identificador:  oai:www.ucm.es:1573
# Título:  Programas para la convivencia familiar y social desde una cultura de la paz
# Dirección recurso:  https://eprints.ucm.es/1573/1/PROGRAMAS_PARA_LA_CONVIVENCIA_FAMILIAR_Y_SOCIAL_DESDE_UNA_CULTURA_DE_LA_PAZ.pdf
#
# Identificador:  oai:www.ucm.es:1580
# Título:
# Dirección recurso:
#
# Identificador:  oai:www.ucm.es:1585
# Título:
# Dirección recurso:

# %% [markdown]
# **4: ¿Qué problemas has encontrado? ¿Has tenido que manejar más de un formato de metadatos? ¿Qué limitaciones tiene el protocolo OAI-PMH? ¿Cómo lo mejorarías?**

# %% [markdown]
# Uno de los problemas encontrados se da por la limitación que impone la operación findall de ElementTree, pues no recoge todos los predicados posibles de xPath, sino solo un subconjunto ( https://docs.python.org/3/library/xml.etree.elementtree.html#xpath-support ). De esta forma, en vez de poder filtrar directamente en la query (`dc:description[text()='tema']`), la búsqueda debe hacerse programáticamente en Python de manera menos óptima.
#
# Otro problema encontrado viene de los origenes de datos. A pesar de seguir estrictamente el protocolo, algunos repositorios devuelven elementos con datos incompletos. Esto puede observarse en el último ejemplo, en el que para algunos elementos se obtiene únicamente el identificador sin el resto de detalles.
#
# Sin embargo, gracias al protocolo OAI-PMH se ha podido realizar una función que puede ser reutilizada para obtener detalles de distintos repositorios. Como se ha comprobado a lo largo de la práctica, no ha sido necesario manejar más de un formato de datos, pues las mismas líneas de código son funcionales para diferentes origenes de datos que soporten el mismo esquema (en este caso oai_dc: http://www.openarchives.org/OAI/2.0/oai_dc.xsd ).
#
# No obstante, la variedad de formatos de metadatos es amplia, cada uno de ellos con diferente cantidad y tipo de datos. Ya que la finalidad es lograr un estandar, una posible mejora podría ser la reducción o consenso entre los diferentes esquemas de XML. Igualmente, la interpretación de tipos por parte del repositorio puede variar; por ejemplo, la dirección del recurso: mientras que unas fuentes proporcionan el acceso directo al fichero final (pdf, csv...), otras ofrecen la dirección del portal web donde se encuentra el acceso al recurso. Este aspecto podría mejorarse siguiendo siempre una misma regla, ya que en caso contrario puede resultar ambiguo a la hora de realizar procesos de manera automatizada.

# %% [markdown]
# **5: A través de los distintos métodos vistos (Uso de PID/DOI, OAI-PMH o APIs concretas de repositorios) intenta llegar al fichero de un dataset para mostrarlo (gráfica, imagen...)**

# %%
# Función para extraer la respuesta de un recurso (en base a su ID) desde la API de Zenodo
def zenodoResource(resource_id):
    api_base_url = "https://zenodo.org/api/records/"
    headers = {'accept': 'application/json'}
    r = requests.get(api_base_url+str(resource_id),headers)
    return json.loads(r.text)

# %%
# Recurso: https://zenodo.org/record/376497#.XhJP-S1Dnyg
resource = zenodoResource(376497)
print(resource)
# Out:
# {'conceptrecid': '788158', 'created': '2017-03-10T10:40:00.737267+00:00', 'doi': '10.5281/zenodo.376497', 'files': [{'bucket': '32e1b5b0-e8f6-49c1-9c8c-e3aaeb390da8', 'checksum': 'md5:ef3be134c03554d9cf6f53601ef042d6', 'key': 'Photonics4All_Bookmark_Chip_ES.png', 'links': {'self': 'https://zenodo.org/api/files/32e1b5b0-e8f6-49c1-9c8c-e3aaeb390da8/Photonics4All_Bookmark_Chip_ES.png'}, 'size': 584891, 'type': 'png'}], 'id': 376497, 'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.376497.svg', 'bucket': 'https://zenodo.org/api/files/32e1b5b0-e8f6-49c1-9c8c-e3aaeb390da8', 'doi': 'https://doi.org/10.5281/zenodo.376497', 'html': 'https://zenodo.org/record/376497', 'latest': 'https://zenodo.org/api/records/376497', 'latest_html': 'https://zenodo.org/record/376497', 'self': 'https://zenodo.org/api/records/376497', 'thumb250': 'https://zenodo.org/api/iiif/v2/32e1b5b0-e8f6-49c1-9c8c-e3aaeb390da8:6aa11fd9-72f4-4335-8a38-b5fbfd4a6483:Photonics4All_Bookmark_Chip_ES.png/full/250,/0/default.png', 'thumbs': {'10': 'https://zenodo.org/record/376497/thumb10', '100': 'https://zenodo.org/record/376497/thumb100', '1200': 'https://zenodo.org/record/376497/thumb1200', '250': 'https://zenodo.org/record/376497/thumb250', '50': 'https://zenodo.org/record/376497/thumb50', '750': 'https://zenodo.org/record/376497/thumb750'}}, 'metadata': {'access_right': 'open', 'access_right_category': 'success', 'creators': [{'affiliation': 'Delft University of Technology', 'name': 'Dr. Adam, Aurèle'}], 'description': '<p>The purpose of the bookmarks for the project Photonics4All is to increase the public awareness of photonics and especially of the technological advances of photonics which have changed and improved everyday life (basic technology introduction).<br>\n<br>\nHow light makes computers and phones smaller and faster?</p>\n\n<p>Did you know that we use light to fabricate the electronic chips in computers and mobile phones? Recent developments in photolithography where light is used to control where conductive metal is placed on the chips - have enabled us to put more transistors than there are people on earth!\xa0 Transistors are responsible for controlling the path of electricity/information through a chip.\xa0 These technological developments have led to improving the speed, size and energy consumption of our chips, making them smaller and more efficient.</p>\n\n<p>\xa0</p>', 'doi': '10.5281/zenodo.376497', 'grants': [{'acronym': 'Photonics4All', 'code': '644606', 'funder': {'acronyms': [], 'doi': '10.13039/501100000780', 'links': {'self': 'https://zenodo.org/api/funders/10.13039/501100000780'}, 'name': 'European Commission'}, 'links': {'self': 'https://zenodo.org/api/grants/10.13039/501100000780::644606'}, 'program': 'H2020', 'title': 'EU-wide outreach for promoting photonics to young people, entrepreneurs and the general public'}], 'keywords': ['Photonics', 'Chip', 'computer', 'mobile phone', 'electronics', 'photolithography', 'science communication', 'outreach', 'Bookmark'], 'license': {'id': 'CC-BY-4.0'}, 'publication_date': '2015-07-31', 'relations': {'version': [{'count': 1, 'index': 0, 'is_last': True, 'last_child': {'pid_type': 'recid', 'pid_value': '376497'}, 'parent': {'pid_type': 'recid', 'pid_value': '788158'}}]}, 'resource_type': {'subtype': 'other', 'title': 'Other', 'type': 'image'}, 'title': 'Photonics4All Bookmark Chip (Spanish)'}, 'owners': [28677], 'revision': 4, 'stats': {'downloads': 0.0, 'unique_downloads': 0.0, 'unique_views': 3.0, 'version_downloads': 0.0, 'version_unique_downloads': 0.0, 'version_unique_views': 3.0, 'version_views': 3.0, 'version_volume': 0.0, 'views': 3.0, 'volume': 0.0}, 'updated': '2017-09-08T08:03:34.521493+00:00'}

# %%
# Visualizar la imagen
img_url = resource["files"][0]["links"]["self"]
from IPython.display import Image
Image(url=img_url)
# Out:
# <img src="https://zenodo.org/api/files/32e1b5b0-e8f6-49c1-9c8c-e3aaeb390da8/Photonics4All_Bookmark_Chip_ES.png"/>
